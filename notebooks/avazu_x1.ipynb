# %%
# !git clone https://github.com/sn09/ranking.git
# Out:
# Cloning into 'ranking'...
# remote: Enumerating objects: 354, done.
# remote: Counting objects: 100% (354/354), done.
# remote: Compressing objects: 100% (209/209), done.
# remote: Total 354 (delta 170), reused 294 (delta 119), pack-reused 0 (from 0)
# Receiving objects: 100% (354/354), 230.55 KiB | 2.99 MiB/s, done.
# Resolving deltas: 100% (170/170), done.

# %%
import sys

import lightgbm as lgb
import numpy as np
import pandas as pd
from lightgbm import LGBMClassifier, LGBMRanker
from sklearn.metrics import log_loss, roc_auc_score
from torch import nn

sys.path.append("./ranking/models/")

from dcnv2.model import DCNv2
from finalnet.model import FinalNet

# %%
base_path = "/kaggle/input/avazu-x1"

df_train = pd.read_csv(f"{base_path}/train.csv")
df_test = pd.read_csv(f"{base_path}/test.csv")
df_val = pd.read_csv(f"{base_path}/valid.csv")

df_train.head()
# Out:
#    label  feat_1  feat_2  feat_3  feat_4  feat_5  feat_6  feat_7  feat_8  \
# 0      0       1       9      18    3582    7908    7931   12997   13304
# 1      0       1       9      18    3582    7908    7931   12997   13304
# 2      0       1       9      18    3582    7908    7931   12997   13304
# 3      0       1       9      18    3582    7908    7931   12997   13304
# 4      0       1      10     177    3712    7918    7931   12997   13304
#
#    feat_9  ...  feat_13  feat_14  feat_15  feat_16  feat_17  feat_18  feat_19  \
# 0   13335  ...  1541008  1541030  1543495  1543504  1543514  1543945  1543950
# 1   13335  ...  1541007  1541026  1543495  1543504  1543514  1543945  1543950
# 2   13335  ...  1541007  1541026  1543495  1543504  1543514  1543945  1543950
# 3   13335  ...  1541007  1541030  1543495  1543504  1543514  1543945  1543950
# 4   13335  ...  1541007  1541250  1543495  1543504  1543628  1543945  1543950
#
#    feat_20  feat_21  feat_22
# 0  1544018  1544189  1544270
# 1  1544019  1544189  1544270
# 2  1544019  1544189  1544270
# 3  1544019  1544189  1544270
# 4  1544018  1544193  1544270
#
# [5 rows x 23 columns]

# %%
feature_columns = df_train.columns.difference(["label"]).tolist()
for df in [df_train, df_val, df_test]:
    df[feature_columns] = df[feature_columns].astype("category")

# %% [markdown]
# # LightGBM

# %% [markdown]
# ## LGBMClassifier

# %%
booster_clf = LGBMClassifier(
    objective="binary",
    max_depth=8,
    learning_rate=1e-1,
    n_estimators=2000,
)

# %%
feature_names = df_train.columns.difference(["label"]).tolist()

booster_clf = booster_clf.fit(
    X=df_train.drop(columns="label"),
    y=df_train["label"],
    eval_set=(df_val.drop(columns="label"), df_val["label"]),
    feature_name=df_train.drop(columns="label").columns.tolist(),
    categorical_feature=feature_columns,
    callbacks=[lgb.early_stopping(stopping_rounds=10), lgb.log_evaluation()],
)
# Out:
# [LightGBM] [Warning] Categorical features with more bins than the configured maximum bin number found.
# [LightGBM] [Warning] For categorical features, max_bin and max_bin_by_feature may be ignored with a large number of categories.
# [LightGBM] [Info] Number of positive: 4953382, number of negative: 23346894
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 2.553294 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 14346
# [LightGBM] [Info] Number of data points in the train set: 28300276, number of used features: 22
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.175029 -> initscore=-1.550393
# [LightGBM] [Info] Start training from score -1.550393
# [1]	valid_0's binary_logloss: 0.445751
# Training until validation scores don't improve for 10 rounds
# [2]	valid_0's binary_logloss: 0.440344
# [3]	valid_0's binary_logloss: 0.436194
# [4]	valid_0's binary_logloss: 0.432942
# [5]	valid_0's binary_logloss: 0.43024
# [6]	valid_0's binary_logloss: 0.428063
# [7]	valid_0's binary_logloss: 0.426096
# [8]	valid_0's binary_logloss: 0.424563
# [9]	valid_0's binary_logloss: 0.423314
# [10]	valid_0's binary_logloss: 0.422244
# [11]	valid_0's binary_logloss: 0.421209
# [12]	valid_0's binary_logloss: 0.420475
# [13]	valid_0's binary_logloss: 0.419651
# [14]	valid_0's binary_logloss: 0.418899
# [15]	valid_0's binary_logloss: 0.418432
# [16]	valid_0's binary_logloss: 0.41808
# [17]	valid_0's binary_logloss: 0.417541
# [18]	valid_0's binary_logloss: 0.417166
# [19]	valid_0's binary_logloss: 0.417022
# [20]	valid_0's binary_logloss: 0.416547
# [21]	valid_0's binary_logloss: 0.416292
# [22]	valid_0's binary_logloss: 0.416055
# [23]	valid_0's binary_logloss: 0.41582
# [24]	valid_0's binary_logloss: 0.41561
# [25]	valid_0's binary_logloss: 0.415401
# [26]	valid_0's binary_logloss: 0.415123
# [27]	valid_0's binary_logloss: 0.414963
# [28]	valid_0's binary_logloss: 0.414888
# [29]	valid_0's binary_logloss: 0.41465
# [30]	valid_0's binary_logloss: 0.414517
# [31]	valid_0's binary_logloss: 0.414338
# [32]	valid_0's binary_logloss: 0.413905
# [33]	valid_0's binary_logloss: 0.41369
# [34]	valid_0's binary_logloss: 0.413573
# [35]	valid_0's binary_logloss: 0.41347
# [36]	valid_0's binary_logloss: 0.413154
# [37]	valid_0's binary_logloss: 0.413056
# [38]	valid_0's binary_logloss: 0.412951
# [39]	valid_0's binary_logloss: 0.412751
# [40]	valid_0's binary_logloss: 0.412641
# [41]	valid_0's binary_logloss: 0.412321
# [42]	valid_0's binary_logloss: 0.41218
# [43]	valid_0's binary_logloss: 0.412047
# [44]	valid_0's binary_logloss: 0.411687
# [45]	valid_0's binary_logloss: 0.411615
# [46]	valid_0's binary_logloss: 0.411521
# [47]	valid_0's binary_logloss: 0.411412
# [48]	valid_0's binary_logloss: 0.411117
# [49]	valid_0's binary_logloss: 0.411048
# [50]	valid_0's binary_logloss: 0.410855
# [51]	valid_0's binary_logloss: 0.410832
# [52]	valid_0's binary_logloss: 0.410794
# [53]	valid_0's binary_logloss: 0.410571
# [54]	valid_0's binary_logloss: 0.410511
# [55]	valid_0's binary_logloss: 0.410446
# [56]	valid_0's binary_logloss: 0.410288
# [57]	valid_0's binary_logloss: 0.410153
# [58]	valid_0's binary_logloss: 0.409953
# [59]	valid_0's binary_logloss: 0.409737
# [60]	valid_0's binary_logloss: 0.409658
# [61]	valid_0's binary_logloss: 0.409591
# [62]	valid_0's binary_logloss: 0.409535
# [63]	valid_0's binary_logloss: 0.409469
# [64]	valid_0's binary_logloss: 0.409419
# [65]	valid_0's binary_logloss: 0.409366
# [66]	valid_0's binary_logloss: 0.409146
# [67]	valid_0's binary_logloss: 0.409022
# [68]	valid_0's binary_logloss: 0.409013
# [69]	valid_0's binary_logloss: 0.408874
# [70]	valid_0's binary_logloss: 0.408716
# [71]	valid_0's binary_logloss: 0.408595
# [72]	valid_0's binary_logloss: 0.408468
# [73]	valid_0's binary_logloss: 0.40844
# [74]	valid_0's binary_logloss: 0.408174
# [75]	valid_0's binary_logloss: 0.408161
# [76]	valid_0's binary_logloss: 0.407954
# [77]	valid_0's binary_logloss: 0.407901
# [78]	valid_0's binary_logloss: 0.407884
# [79]	valid_0's binary_logloss: 0.407866
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [80]	valid_0's binary_logloss: 0.407865
# [81]	valid_0's binary_logloss: 0.407803
# [82]	valid_0's binary_logloss: 0.407769
# [83]	valid_0's binary_logloss: 0.40775
# [84]	valid_0's binary_logloss: 0.407703
# [85]	valid_0's binary_logloss: 0.407614
# [86]	valid_0's binary_logloss: 0.407469
# [87]	valid_0's binary_logloss: 0.4073
# [88]	valid_0's binary_logloss: 0.407251
# [89]	valid_0's binary_logloss: 0.407227
# [90]	valid_0's binary_logloss: 0.407157
# [91]	valid_0's binary_logloss: 0.407143
# [92]	valid_0's binary_logloss: 0.407054
# [93]	valid_0's binary_logloss: 0.407037
# [94]	valid_0's binary_logloss: 0.407002
# [95]	valid_0's binary_logloss: 0.406991
# [96]	valid_0's binary_logloss: 0.406977
# [97]	valid_0's binary_logloss: 0.406964
# [98]	valid_0's binary_logloss: 0.406934
# [99]	valid_0's binary_logloss: 0.406876
# [100]	valid_0's binary_logloss: 0.406785
# [101]	valid_0's binary_logloss: 0.406699
# [102]	valid_0's binary_logloss: 0.406596
# [103]	valid_0's binary_logloss: 0.406549
# [104]	valid_0's binary_logloss: 0.406558
# [105]	valid_0's binary_logloss: 0.406343
# [106]	valid_0's binary_logloss: 0.406341
# [107]	valid_0's binary_logloss: 0.40633
# [108]	valid_0's binary_logloss: 0.406241
# [109]	valid_0's binary_logloss: 0.406212
# [110]	valid_0's binary_logloss: 0.406172
# [111]	valid_0's binary_logloss: 0.406151
# [112]	valid_0's binary_logloss: 0.406143
# [113]	valid_0's binary_logloss: 0.406
# [114]	valid_0's binary_logloss: 0.405997
# [115]	valid_0's binary_logloss: 0.40598
# [116]	valid_0's binary_logloss: 0.405948
# [117]	valid_0's binary_logloss: 0.405939
# [118]	valid_0's binary_logloss: 0.405848
# [119]	valid_0's binary_logloss: 0.405731
# [120]	valid_0's binary_logloss: 0.405747
# [121]	valid_0's binary_logloss: 0.405716
# [122]	valid_0's binary_logloss: 0.405643
# [123]	valid_0's binary_logloss: 0.405571
# [124]	valid_0's binary_logloss: 0.405534
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [125]	valid_0's binary_logloss: 0.405528
# [126]	valid_0's binary_logloss: 0.405507
# [127]	valid_0's binary_logloss: 0.405505
# [128]	valid_0's binary_logloss: 0.405498
# [129]	valid_0's binary_logloss: 0.405379
# [130]	valid_0's binary_logloss: 0.405343
# [131]	valid_0's binary_logloss: 0.405258
# [132]	valid_0's binary_logloss: 0.405234
# [133]	valid_0's binary_logloss: 0.40523
# [134]	valid_0's binary_logloss: 0.405188
# [135]	valid_0's binary_logloss: 0.405187
# [136]	valid_0's binary_logloss: 0.405194
# [137]	valid_0's binary_logloss: 0.405191
# [138]	valid_0's binary_logloss: 0.405151
# [139]	valid_0's binary_logloss: 0.405137
# [140]	valid_0's binary_logloss: 0.405108
# [141]	valid_0's binary_logloss: 0.405088
# [142]	valid_0's binary_logloss: 0.404992
# [143]	valid_0's binary_logloss: 0.40499
# [144]	valid_0's binary_logloss: 0.404955
# [145]	valid_0's binary_logloss: 0.404945
# [146]	valid_0's binary_logloss: 0.404944
# [147]	valid_0's binary_logloss: 0.404926
# [148]	valid_0's binary_logloss: 0.404912
# [149]	valid_0's binary_logloss: 0.404864
# [150]	valid_0's binary_logloss: 0.404719
# [151]	valid_0's binary_logloss: 0.404563
# [152]	valid_0's binary_logloss: 0.404576
# [153]	valid_0's binary_logloss: 0.404475
# [154]	valid_0's binary_logloss: 0.404472
# [155]	valid_0's binary_logloss: 0.404466
# [156]	valid_0's binary_logloss: 0.404465
# [157]	valid_0's binary_logloss: 0.404459
# [158]	valid_0's binary_logloss: 0.404425
# [159]	valid_0's binary_logloss: 0.404422
# [160]	valid_0's binary_logloss: 0.404402
# [161]	valid_0's binary_logloss: 0.404391
# [162]	valid_0's binary_logloss: 0.404371
# [163]	valid_0's binary_logloss: 0.404239
# [164]	valid_0's binary_logloss: 0.404084
# [165]	valid_0's binary_logloss: 0.403936
# [166]	valid_0's binary_logloss: 0.40393
# [167]	valid_0's binary_logloss: 0.403782
# [168]	valid_0's binary_logloss: 0.403729
# [169]	valid_0's binary_logloss: 0.403731
# [170]	valid_0's binary_logloss: 0.403727
# [171]	valid_0's binary_logloss: 0.403697
# [172]	valid_0's binary_logloss: 0.403694
# [173]	valid_0's binary_logloss: 0.403613
# [174]	valid_0's binary_logloss: 0.403605
# [175]	valid_0's binary_logloss: 0.403586
# [176]	valid_0's binary_logloss: 0.403587
# [177]	valid_0's binary_logloss: 0.403586
# [178]	valid_0's binary_logloss: 0.403555
# [179]	valid_0's binary_logloss: 0.403504
# [180]	valid_0's binary_logloss: 0.40349
# [181]	valid_0's binary_logloss: 0.403454
# [182]	valid_0's binary_logloss: 0.403388
# [183]	valid_0's binary_logloss: 0.403381
# [184]	valid_0's binary_logloss: 0.403372
# [185]	valid_0's binary_logloss: 0.403343
# [186]	valid_0's binary_logloss: 0.403328
# [187]	valid_0's binary_logloss: 0.403328
# [188]	valid_0's binary_logloss: 0.403321
# [189]	valid_0's binary_logloss: 0.403319
# [190]	valid_0's binary_logloss: 0.403322
# [191]	valid_0's binary_logloss: 0.403306
# [192]	valid_0's binary_logloss: 0.403253
# [193]	valid_0's binary_logloss: 0.403247
# [194]	valid_0's binary_logloss: 0.403242
# [195]	valid_0's binary_logloss: 0.403106
# [196]	valid_0's binary_logloss: 0.403091
# [197]	valid_0's binary_logloss: 0.40309
# [198]	valid_0's binary_logloss: 0.403083
# [199]	valid_0's binary_logloss: 0.402979
# [200]	valid_0's binary_logloss: 0.402981
# [201]	valid_0's binary_logloss: 0.402984
# [202]	valid_0's binary_logloss: 0.40296
# [203]	valid_0's binary_logloss: 0.402959
# [204]	valid_0's binary_logloss: 0.402939
# [205]	valid_0's binary_logloss: 0.402918
# [206]	valid_0's binary_logloss: 0.402909
# [207]	valid_0's binary_logloss: 0.402829
# [208]	valid_0's binary_logloss: 0.402812
# [209]	valid_0's binary_logloss: 0.402808
# [210]	valid_0's binary_logloss: 0.402797
# [211]	valid_0's binary_logloss: 0.402785
# [212]	valid_0's binary_logloss: 0.402776
# [213]	valid_0's binary_logloss: 0.402776
# [214]	valid_0's binary_logloss: 0.402702
# [215]	valid_0's binary_logloss: 0.4027
# [216]	valid_0's binary_logloss: 0.4027
# [217]	valid_0's binary_logloss: 0.402633
# [218]	valid_0's binary_logloss: 0.402622
# [219]	valid_0's binary_logloss: 0.402619
# [220]	valid_0's binary_logloss: 0.402605
# [221]	valid_0's binary_logloss: 0.402614
# [222]	valid_0's binary_logloss: 0.402553
# [223]	valid_0's binary_logloss: 0.402538
# [224]	valid_0's binary_logloss: 0.402527
# [225]	valid_0's binary_logloss: 0.402509
# [226]	valid_0's binary_logloss: 0.402496
# [227]	valid_0's binary_logloss: 0.402405
# [228]	valid_0's binary_logloss: 0.402391
# [229]	valid_0's binary_logloss: 0.402385
# [230]	valid_0's binary_logloss: 0.402392
# [231]	valid_0's binary_logloss: 0.402371
# [232]	valid_0's binary_logloss: 0.402292
# [233]	valid_0's binary_logloss: 0.402291
# [234]	valid_0's binary_logloss: 0.40229
# [235]	valid_0's binary_logloss: 0.402279
# [236]	valid_0's binary_logloss: 0.402263
# [237]	valid_0's binary_logloss: 0.402251
# [238]	valid_0's binary_logloss: 0.402251
# [239]	valid_0's binary_logloss: 0.40225
# [240]	valid_0's binary_logloss: 0.40225
# [241]	valid_0's binary_logloss: 0.402239
# [242]	valid_0's binary_logloss: 0.402237
# [243]	valid_0's binary_logloss: 0.402234
# [244]	valid_0's binary_logloss: 0.402212
# [245]	valid_0's binary_logloss: 0.402208
# [246]	valid_0's binary_logloss: 0.402171
# [247]	valid_0's binary_logloss: 0.40215
# [248]	valid_0's binary_logloss: 0.402149
# [249]	valid_0's binary_logloss: 0.402086
# [250]	valid_0's binary_logloss: 0.402081
# [251]	valid_0's binary_logloss: 0.402075
# [252]	valid_0's binary_logloss: 0.402071
# [253]	valid_0's binary_logloss: 0.402041
# [254]	valid_0's binary_logloss: 0.402036
# [255]	valid_0's binary_logloss: 0.402034
# [256]	valid_0's binary_logloss: 0.402028
# [257]	valid_0's binary_logloss: 0.402022
# [258]	valid_0's binary_logloss: 0.402012
# [259]	valid_0's binary_logloss: 0.402006
# [260]	valid_0's binary_logloss: 0.401993
# [261]	valid_0's binary_logloss: 0.401989
# [262]	valid_0's binary_logloss: 0.401982
# [263]	valid_0's binary_logloss: 0.401982
# [264]	valid_0's binary_logloss: 0.401974
# [265]	valid_0's binary_logloss: 0.40197
# [266]	valid_0's binary_logloss: 0.40197
# [267]	valid_0's binary_logloss: 0.401968
# [268]	valid_0's binary_logloss: 0.401969
# [269]	valid_0's binary_logloss: 0.401966
# [270]	valid_0's binary_logloss: 0.401967
# [271]	valid_0's binary_logloss: 0.401928
# [272]	valid_0's binary_logloss: 0.401932
# [273]	valid_0's binary_logloss: 0.401925
# [274]	valid_0's binary_logloss: 0.401904
# [275]	valid_0's binary_logloss: 0.4019
# [276]	valid_0's binary_logloss: 0.401896
# [277]	valid_0's binary_logloss: 0.40188
# [278]	valid_0's binary_logloss: 0.401879
# [279]	valid_0's binary_logloss: 0.401821
# [280]	valid_0's binary_logloss: 0.401783
# [281]	valid_0's binary_logloss: 0.401763
# [282]	valid_0's binary_logloss: 0.401731
# [283]	valid_0's binary_logloss: 0.401715
# [284]	valid_0's binary_logloss: 0.401708
# [285]	valid_0's binary_logloss: 0.401639
# [286]	valid_0's binary_logloss: 0.401636
# [287]	valid_0's binary_logloss: 0.401641
# [288]	valid_0's binary_logloss: 0.401641
# [289]	valid_0's binary_logloss: 0.40164
# [290]	valid_0's binary_logloss: 0.401638
# [291]	valid_0's binary_logloss: 0.401638
# [292]	valid_0's binary_logloss: 0.401623
# [293]	valid_0's binary_logloss: 0.401617
# [294]	valid_0's binary_logloss: 0.401615
# [295]	valid_0's binary_logloss: 0.401616
# [296]	valid_0's binary_logloss: 0.401626
# [297]	valid_0's binary_logloss: 0.401611
# [298]	valid_0's binary_logloss: 0.401609
# [299]	valid_0's binary_logloss: 0.401606
# [300]	valid_0's binary_logloss: 0.401607
# [301]	valid_0's binary_logloss: 0.401605
# [302]	valid_0's binary_logloss: 0.401602
# [303]	valid_0's binary_logloss: 0.401601
# [304]	valid_0's binary_logloss: 0.401603
# [305]	valid_0's binary_logloss: 0.401602
# [306]	valid_0's binary_logloss: 0.401574
# [307]	valid_0's binary_logloss: 0.401573
# [308]	valid_0's binary_logloss: 0.401573
# [309]	valid_0's binary_logloss: 0.401568
# [310]	valid_0's binary_logloss: 0.401567
# [311]	valid_0's binary_logloss: 0.401533
# [312]	valid_0's binary_logloss: 0.401533
# [313]	valid_0's binary_logloss: 0.40153
# [314]	valid_0's binary_logloss: 0.401446
# [315]	valid_0's binary_logloss: 0.401439
# [316]	valid_0's binary_logloss: 0.401436
# [317]	valid_0's binary_logloss: 0.401432
# [318]	valid_0's binary_logloss: 0.401429
# [319]	valid_0's binary_logloss: 0.401419
# [320]	valid_0's binary_logloss: 0.401402
# [321]	valid_0's binary_logloss: 0.401402
# [322]	valid_0's binary_logloss: 0.40141
# [323]	valid_0's binary_logloss: 0.401408
# [324]	valid_0's binary_logloss: 0.401413
# [325]	valid_0's binary_logloss: 0.401405
# [326]	valid_0's binary_logloss: 0.401405
# [327]	valid_0's binary_logloss: 0.401402
# [328]	valid_0's binary_logloss: 0.401399
# [329]	valid_0's binary_logloss: 0.401398
# [330]	valid_0's binary_logloss: 0.401398
# [331]	valid_0's binary_logloss: 0.401402
# [332]	valid_0's binary_logloss: 0.401397
# [333]	valid_0's binary_logloss: 0.401409
# [334]	valid_0's binary_logloss: 0.401408
# [335]	valid_0's binary_logloss: 0.401407
# [336]	valid_0's binary_logloss: 0.401406
# [337]	valid_0's binary_logloss: 0.401402
# [338]	valid_0's binary_logloss: 0.401402
# [339]	valid_0's binary_logloss: 0.401359
# [340]	valid_0's binary_logloss: 0.401358
# [341]	valid_0's binary_logloss: 0.401295
# [342]	valid_0's binary_logloss: 0.401292
# [343]	valid_0's binary_logloss: 0.401295
# [344]	valid_0's binary_logloss: 0.40129
# [345]	valid_0's binary_logloss: 0.401285
# [346]	valid_0's binary_logloss: 0.401299
# [347]	valid_0's binary_logloss: 0.401259
# [348]	valid_0's binary_logloss: 0.401255
# [349]	valid_0's binary_logloss: 0.401253
# [350]	valid_0's binary_logloss: 0.401247
# [351]	valid_0's binary_logloss: 0.401228
# [352]	valid_0's binary_logloss: 0.401221
# [353]	valid_0's binary_logloss: 0.401217
# [354]	valid_0's binary_logloss: 0.401212
# [355]	valid_0's binary_logloss: 0.401205
# [356]	valid_0's binary_logloss: 0.401202
# [357]	valid_0's binary_logloss: 0.401198
# [358]	valid_0's binary_logloss: 0.40116
# [359]	valid_0's binary_logloss: 0.401155
# [360]	valid_0's binary_logloss: 0.401168
# [361]	valid_0's binary_logloss: 0.401168
# [362]	valid_0's binary_logloss: 0.401176
# [363]	valid_0's binary_logloss: 0.401161
# [364]	valid_0's binary_logloss: 0.401126
# [365]	valid_0's binary_logloss: 0.401125
# [366]	valid_0's binary_logloss: 0.401071
# [367]	valid_0's binary_logloss: 0.401066
# [368]	valid_0's binary_logloss: 0.401053
# [369]	valid_0's binary_logloss: 0.401031
# [370]	valid_0's binary_logloss: 0.401027
# [371]	valid_0's binary_logloss: 0.401029
# [372]	valid_0's binary_logloss: 0.401026
# [373]	valid_0's binary_logloss: 0.401023
# [374]	valid_0's binary_logloss: 0.40102
# [375]	valid_0's binary_logloss: 0.401022
# [376]	valid_0's binary_logloss: 0.401021
# [377]	valid_0's binary_logloss: 0.40102
# [378]	valid_0's binary_logloss: 0.40102
# [379]	valid_0's binary_logloss: 0.40102
# [380]	valid_0's binary_logloss: 0.401015
# [381]	valid_0's binary_logloss: 0.401015
# [382]	valid_0's binary_logloss: 0.401009
# [383]	valid_0's binary_logloss: 0.40102
# [384]	valid_0's binary_logloss: 0.400994
# [385]	valid_0's binary_logloss: 0.400993
# [386]	valid_0's binary_logloss: 0.400992
# [387]	valid_0's binary_logloss: 0.400992
# [388]	valid_0's binary_logloss: 0.40099
# [389]	valid_0's binary_logloss: 0.400988
# [390]	valid_0's binary_logloss: 0.400983
# [391]	valid_0's binary_logloss: 0.400985
# [392]	valid_0's binary_logloss: 0.400955
# [393]	valid_0's binary_logloss: 0.400951
# [394]	valid_0's binary_logloss: 0.400946
# [395]	valid_0's binary_logloss: 0.400882
# [396]	valid_0's binary_logloss: 0.400882
# [397]	valid_0's binary_logloss: 0.400883
# [398]	valid_0's binary_logloss: 0.400883
# [399]	valid_0's binary_logloss: 0.400884
# [400]	valid_0's binary_logloss: 0.400875
# [401]	valid_0's binary_logloss: 0.400868
# [402]	valid_0's binary_logloss: 0.400864
# [403]	valid_0's binary_logloss: 0.400867
# [404]	valid_0's binary_logloss: 0.400871
# [405]	valid_0's binary_logloss: 0.400869
# [406]	valid_0's binary_logloss: 0.400835
# [407]	valid_0's binary_logloss: 0.400831
# [408]	valid_0's binary_logloss: 0.400831
# [409]	valid_0's binary_logloss: 0.400821
# [410]	valid_0's binary_logloss: 0.400821
# [411]	valid_0's binary_logloss: 0.400821
# [412]	valid_0's binary_logloss: 0.400822
# [413]	valid_0's binary_logloss: 0.400822
# [414]	valid_0's binary_logloss: 0.400806
# [415]	valid_0's binary_logloss: 0.400806
# [416]	valid_0's binary_logloss: 0.400806
# [417]	valid_0's binary_logloss: 0.400806
# [418]	valid_0's binary_logloss: 0.400756
# [419]	valid_0's binary_logloss: 0.400756
# [420]	valid_0's binary_logloss: 0.400754
# [421]	valid_0's binary_logloss: 0.400757
# [422]	valid_0's binary_logloss: 0.400734
# [423]	valid_0's binary_logloss: 0.400716
# [424]	valid_0's binary_logloss: 0.400715
# [425]	valid_0's binary_logloss: 0.400716
# [426]	valid_0's binary_logloss: 0.400708
# [427]	valid_0's binary_logloss: 0.400714
# [428]	valid_0's binary_logloss: 0.400713
# [429]	valid_0's binary_logloss: 0.400701
# [430]	valid_0's binary_logloss: 0.400726
# [431]	valid_0's binary_logloss: 0.400728
# [432]	valid_0's binary_logloss: 0.400726
# [433]	valid_0's binary_logloss: 0.400725
# [434]	valid_0's binary_logloss: 0.4007
# [435]	valid_0's binary_logloss: 0.400678
# [436]	valid_0's binary_logloss: 0.400666
# [437]	valid_0's binary_logloss: 0.400654
# [438]	valid_0's binary_logloss: 0.400656
# [439]	valid_0's binary_logloss: 0.400657
# [440]	valid_0's binary_logloss: 0.400657
# [441]	valid_0's binary_logloss: 0.400654
# [442]	valid_0's binary_logloss: 0.400654
# [443]	valid_0's binary_logloss: 0.400653
# [444]	valid_0's binary_logloss: 0.400646
# [445]	valid_0's binary_logloss: 0.400645
# [446]	valid_0's binary_logloss: 0.40064
# [447]	valid_0's binary_logloss: 0.400637
# [448]	valid_0's binary_logloss: 0.400638
# [449]	valid_0's binary_logloss: 0.400636
# [450]	valid_0's binary_logloss: 0.400635
# [451]	valid_0's binary_logloss: 0.40063
# [452]	valid_0's binary_logloss: 0.400631
# [453]	valid_0's binary_logloss: 0.400613
# [454]	valid_0's binary_logloss: 0.400611
# [455]	valid_0's binary_logloss: 0.40061
# [456]	valid_0's binary_logloss: 0.400606
# [457]	valid_0's binary_logloss: 0.400604
# [458]	valid_0's binary_logloss: 0.400607
# [459]	valid_0's binary_logloss: 0.400608
# [460]	valid_0's binary_logloss: 0.400589
# [461]	valid_0's binary_logloss: 0.40059
# [462]	valid_0's binary_logloss: 0.400562
# [463]	valid_0's binary_logloss: 0.400565
# [464]	valid_0's binary_logloss: 0.400565
# [465]	valid_0's binary_logloss: 0.400575
# [466]	valid_0's binary_logloss: 0.400575
# [467]	valid_0's binary_logloss: 0.400589
# [468]	valid_0's binary_logloss: 0.400592
# [469]	valid_0's binary_logloss: 0.40059
# [470]	valid_0's binary_logloss: 0.400588
# [471]	valid_0's binary_logloss: 0.400589
# [472]	valid_0's binary_logloss: 0.400589
# Early stopping, best iteration is:
# [462]	valid_0's binary_logloss: 0.400562

# %%
booster_clf_preds = booster_clf.predict(
    df_test.drop(columns="label"),
    raw_score=True,
)

# %%
roc_auc = roc_auc_score(df_test["label"], booster_clf_preds)
logloss = log_loss(df_test["label"], booster_clf_preds)

print("LightGBM Classifier metrics")
print(f"ROC AUC: {roc_auc}, logloss: {logloss}")
# Out:
# LightGBM Classifier metrics
# ROC AUC: 0.7558925197214148, logloss: 5.135342602797571

# %% [markdown]
# # DCNv2

# %%
dcnv2_model = DCNv2(
    model_structure="stacked_parallel",
    use_low_rank_mixture=True,
    cross_low_rank_dim=32,
    num_cross_layers=5,
    num_cross_experts=4,
    parallel_hidden_dims=[256, 512, 1024],
    parallel_dropout=0.2,
    parallel_use_batch_norm=True,
    parallel_activation=nn.ReLU,
    stacked_hidden_dims=[256, 512, 1024],
    stacked_dropout=0.2,
    stacked_use_batch_norm=True,
    stacked_activation=nn.ReLU,
    output_dim=1,
    proj_output_embeddings=True,
)

# %%
train_metrics_dcnv2, val_metrics_dcnv2 = dcnv2_model.fit(
    features=df_train.drop(columns="label"),
    target=df_train["label"],
    val_features=df_val.drop(columns="label"),
    val_target=df_val["label"],
    optimizer_cls="torch.optim.Adam",
    optimizer_params=dict(lr=1e-2),
    scheduler_cls="torch.optim.lr_scheduler.ReduceLROnPlateau",
    scheduler_params=dict(mode="max", factor=0.1, patience=1, min_lr=1e-6),
    grad_clip_threshold=10.,
    num_epochs=1,
    seed=42,
    artifacts_path="./dcnv2_artifacts",
    device="cuda:0",
    batch_size=4096,
    num_workers=4,
    eval_metric_name="AUC",
    eval_mode="max",
    default_embedding_size=10,
    oov_masking_proba=0.05,
    l2_net_reg=0,
    l2_embedding_reg=0,
)
# Out:
# [2025-05-04 02:38:04,886]{model.py:660} - INFO - Used features config: FeaturesConfig(features=[Feature(name='feat_1', feature_type=<FeatureType.CATEGORICAL: 'categorical'>, feature_size=1, needs_embed=True, embedding_size=10, embedding_vocab_size=8, embedding_padding_idx=None), Feature(name='feat_2', feature_type=<FeatureType.CATEGORICAL: 'categorical'>, feature_size=1, needs_embed=True, embedding_size=10, embedding_vocab_size=8, embedding_padding_idx=None), Feature(name='feat_3', feature_type=<FeatureType.CATEGORICAL: 'categorical'>, feature_size=1, needs_embed=True, embedding_size=10, embedding_vocab_size=3479, embedding_padding_idx=None), Feature(name='feat_4', feature_type=<FeatureType.CATEGORICAL: 'categorical'>, feature_size=1, needs_embed=True, embedding_size=10, embedding_vocab_size=4270, embedding_padding_idx=None), Feature(name='feat_5', feature_type=<FeatureType.CATEGORICAL: 'categorical'>, feature_size=1, needs_embed=True, embedding_size=10, embedding_vocab_size=25, embedding_padding_idx=None), Feature(name='feat_6', feature_type=<FeatureType.CATEGORICAL: 'categorical'>, feature_size=1, needs_embed=True, embedding_size=10, embedding_vocab_size=4863, embedding_padding_idx=None), Feature(name='feat_7', feature_type=<FeatureType.CATEGORICAL: 'categorical'>, feature_size=1, needs_embed=True, embedding_size=10, embedding_vocab_size=304, embedding_padding_idx=None), Feature(name='feat_8', feature_type=<FeatureType.CATEGORICAL: 'categorical'>, feature_size=1, needs_embed=True, embedding_size=10, embedding_vocab_size=32, embedding_padding_idx=None), Feature(name='feat_9', feature_type=<FeatureType.CATEGORICAL: 'categorical'>, feature_size=1, needs_embed=True, embedding_size=10, embedding_vocab_size=228185, embedding_padding_idx=None), Feature(name='feat_10', feature_type=<FeatureType.CATEGORICAL: 'categorical'>, feature_size=1, needs_embed=True, embedding_size=10, embedding_vocab_size=1048284, embedding_padding_idx=None), Feature(name='feat_11', feature_type=<FeatureType.CATEGORICAL: 'categorical'>, feature_size=1, needs_embed=True, embedding_size=10, embedding_vocab_size=6514, embedding_padding_idx=None), Feature(name='feat_12', feature_type=<FeatureType.CATEGORICAL: 'categorical'>, feature_size=1, needs_embed=True, embedding_size=10, embedding_vocab_size=5, embedding_padding_idx=None), Feature(name='feat_13', feature_type=<FeatureType.CATEGORICAL: 'categorical'>, feature_size=1, needs_embed=True, embedding_size=10, embedding_vocab_size=5, embedding_padding_idx=None), Feature(name='feat_14', feature_type=<FeatureType.CATEGORICAL: 'categorical'>, feature_size=1, needs_embed=True, embedding_size=10, embedding_vocab_size=1939, embedding_padding_idx=None), Feature(name='feat_15', feature_type=<FeatureType.CATEGORICAL: 'categorical'>, feature_size=1, needs_embed=True, embedding_size=10, embedding_vocab_size=9, embedding_padding_idx=None), Feature(name='feat_16', feature_type=<FeatureType.CATEGORICAL: 'categorical'>, feature_size=1, needs_embed=True, embedding_size=10, embedding_vocab_size=10, embedding_padding_idx=None), Feature(name='feat_17', feature_type=<FeatureType.CATEGORICAL: 'categorical'>, feature_size=1, needs_embed=True, embedding_size=10, embedding_vocab_size=348, embedding_padding_idx=None), Feature(name='feat_18', feature_type=<FeatureType.CATEGORICAL: 'categorical'>, feature_size=1, needs_embed=True, embedding_size=10, embedding_vocab_size=5, embedding_padding_idx=None), Feature(name='feat_19', feature_type=<FeatureType.CATEGORICAL: 'categorical'>, feature_size=1, needs_embed=True, embedding_size=10, embedding_vocab_size=60, embedding_padding_idx=None), Feature(name='feat_20', feature_type=<FeatureType.CATEGORICAL: 'categorical'>, feature_size=1, needs_embed=True, embedding_size=10, embedding_vocab_size=170, embedding_padding_idx=None), Feature(name='feat_21', feature_type=<FeatureType.CATEGORICAL: 'categorical'>, feature_size=1, needs_embed=True, embedding_size=10, embedding_vocab_size=51, embedding_padding_id ...
# [2025-05-04 02:38:07,187]{model.py:675} - INFO - Artifacts path is /kaggle/working/dcnv2_artifacts
# [2025-05-04 02:38:07,189]{model.py:681} - INFO - Best model path is dcnv2_artifacts/best_model.pt
# [2025-05-04 02:38:07,526]{model.py:686} - INFO - Building features mappings
# [2025-05-04 02:38:07,527]{model.py:272} - INFO - Building mapping for feature feat_1
# [2025-05-04 02:38:07,640]{model.py:272} - INFO - Building mapping for feature feat_2
# [2025-05-04 02:38:07,752]{model.py:272} - INFO - Building mapping for feature feat_3
# [2025-05-04 02:38:07,899]{model.py:272} - INFO - Building mapping for feature feat_4
# [2025-05-04 02:38:08,053]{model.py:272} - INFO - Building mapping for feature feat_5
# [2025-05-04 02:38:08,177]{model.py:272} - INFO - Building mapping for feature feat_6
# [2025-05-04 02:38:08,333]{model.py:272} - INFO - Building mapping for feature feat_7
# [2025-05-04 02:38:08,487]{model.py:272} - INFO - Building mapping for feature feat_8
# [2025-05-04 02:38:08,597]{model.py:272} - INFO - Building mapping for feature feat_9
# [2025-05-04 02:38:08,762]{model.py:272} - INFO - Building mapping for feature feat_10
# [2025-05-04 02:38:09,177]{model.py:272} - INFO - Building mapping for feature feat_11
# [2025-05-04 02:38:09,332]{model.py:272} - INFO - Building mapping for feature feat_12
# [2025-05-04 02:38:09,444]{model.py:272} - INFO - Building mapping for feature feat_13
# [2025-05-04 02:38:09,556]{model.py:272} - INFO - Building mapping for feature feat_14
# [2025-05-04 02:38:09,704]{model.py:272} - INFO - Building mapping for feature feat_15
# [2025-05-04 02:38:09,815]{model.py:272} - INFO - Building mapping for feature feat_16
# [2025-05-04 02:38:09,927]{model.py:272} - INFO - Building mapping for feature feat_17
# [2025-05-04 02:38:10,074]{model.py:272} - INFO - Building mapping for feature feat_18
# [2025-05-04 02:38:10,185]{model.py:272} - INFO - Building mapping for feature feat_19
# [2025-05-04 02:38:10,296]{model.py:272} - INFO - Building mapping for feature feat_20
# [2025-05-04 02:38:10,444]{model.py:272} - INFO - Building mapping for feature feat_21
# [2025-05-04 02:38:10,559]{model.py:272} - INFO - Building mapping for feature feat_22
# [2025-05-04 02:38:10,680]{model.py:689} - INFO - Building train dataloader
# [2025-05-04 02:38:11,056]{model.py:297} - INFO - Encoding feature feat_1
# [2025-05-04 02:38:11,668]{model.py:297} - INFO - Encoding feature feat_2
# [2025-05-04 02:38:12,273]{model.py:297} - INFO - Encoding feature feat_3
# [2025-05-04 02:38:12,896]{model.py:297} - INFO - Encoding feature feat_4
# [2025-05-04 02:38:13,515]{model.py:297} - INFO - Encoding feature feat_5
# [2025-05-04 02:38:14,123]{model.py:297} - INFO - Encoding feature feat_6
# [2025-05-04 02:38:14,739]{model.py:297} - INFO - Encoding feature feat_7
# [2025-05-04 02:38:15,356]{model.py:297} - INFO - Encoding feature feat_8
# [2025-05-04 02:38:15,967]{model.py:297} - INFO - Encoding feature feat_9
# [2025-05-04 02:38:16,748]{model.py:297} - INFO - Encoding feature feat_10
# [2025-05-04 02:38:18,006]{model.py:297} - INFO - Encoding feature feat_11
# [2025-05-04 02:38:18,639]{model.py:297} - INFO - Encoding feature feat_12
# [2025-05-04 02:38:19,243]{model.py:297} - INFO - Encoding feature feat_13
# [2025-05-04 02:38:19,845]{model.py:297} - INFO - Encoding feature feat_14
# [2025-05-04 02:38:20,456]{model.py:297} - INFO - Encoding feature feat_15
# [2025-05-04 02:38:21,055]{model.py:297} - INFO - Encoding feature feat_16
# [2025-05-04 02:38:21,654]{model.py:297} - INFO - Encoding feature feat_17
# [2025-05-04 02:38:22,263]{model.py:297} - INFO - Encoding feature feat_18
# [2025-05-04 02:38:22,863]{model.py:297} - INFO - Encoding feature feat_19
# [2025-05-04 02:38:23,464]{model.py:297} - INFO - Encoding feature feat_20
# [2025-05-04 02:38:24,073]{model.py:297} - INFO - Encoding feature feat_21
# [2025-05-04 02:38:24,680]{model.py:297} - INFO - Encoding feature feat_22
# [2025-05-04 02:38:25,365]{model.py:702} - INFO - Building validation dataloader
# [2025-05-04 02:38:25,404]{model.py:297} - INFO - Encoding feature feat_1
# [2025-05-04 02:38:25,492]{model.py:297} - INFO - Encoding feature feat_2
# [2025-05-04 02:38:25,553]{model.py:297} - INFO - Encoding feature feat_3
# [2025-05-04 02:38:25,633]{model.py:297} - INFO - Encoding feature feat_4
# [2025-05-04 02:38:25,710]{model.py:297} - INFO - Encoding feature feat_5
# [2025-05-04 02:38:25,771]{model.py:297} - INFO - Encoding feature feat_6
# [2025-05-04 02:38:25,852]{model.py:297} - INFO - Encoding feature feat_7
# [2025-05-04 02:38:25,929]{model.py:297} - INFO - Encoding feature feat_8
# [2025-05-04 02:38:25,990]{model.py:297} - INFO - Encoding feature feat_9
# [2025-05-04 02:38:26,172]{model.py:297} - INFO - Encoding feature feat_10
# [2025-05-04 02:38:26,756]{model.py:297} - INFO - Encoding feature feat_11
# [2025-05-04 02:38:26,843]{model.py:297} - INFO - Encoding feature feat_12
# [2025-05-04 02:38:26,903]{model.py:297} - INFO - Encoding feature feat_13
# [2025-05-04 02:38:26,964]{model.py:297} - INFO - Encoding feature feat_14
# [2025-05-04 02:38:27,062]{model.py:297} - INFO - Encoding feature feat_15
# [2025-05-04 02:38:27,124]{model.py:297} - INFO - Encoding feature feat_16
# [2025-05-04 02:38:27,185]{model.py:297} - INFO - Encoding feature feat_17
# [2025-05-04 02:38:27,290]{model.py:297} - INFO - Encoding feature feat_18
# [2025-05-04 02:38:27,350]{model.py:297} - INFO - Encoding feature feat_19
# [2025-05-04 02:38:27,432]{model.py:297} - INFO - Encoding feature feat_20
# [2025-05-04 02:38:27,491]{model.py:297} - INFO - Encoding feature feat_21
# [2025-05-04 02:38:27,579]{model.py:297} - INFO - Encoding feature feat_22
# [2025-05-04 02:38:27,651]{model.py:712} - INFO - Starting training process
# Train epoch #0:   0%|          | 0/6910 [00:03<?, ?it/s]
# [2025-05-04 04:03:46,368]{model.py:567} - INFO - Finished Train Epoch #0, average metrics - [loss: 0.39880]
# Validation epoch #0:   0%|          | 0/988 [00:00<?, ?it/s]
# [2025-05-04 04:06:07,086]{model.py:567} - INFO - Finished Validation Epoch #0, average metrics - [AUC: 0.73463, log_loss: 0.40229]
# [2025-05-04 04:06:29,024]{model.py:747} - INFO - Best model with AUC = 0.7346270845082805 was saved to dcnv2_artifacts/best_model.pt
# [2025-05-04 04:06:29,025]{model.py:763} - INFO - Loading best model from dcnv2_artifacts/best_model.pt

# %%
test_metrics_dcnv2 = dcnv2_model.test(
    features=df_test.drop(columns="label"),
    target=df_test["label"],
    device="cuda:0",
    batch_size=4096,
    num_workers=2,
)
test_metrics_dcnv2
# Out:
# [2025-05-04 04:06:29,582]{model.py:789} - INFO - Building test dataloader
# [2025-05-04 04:06:30,015]{model.py:297} - INFO - Encoding feature feat_1
# [2025-05-04 04:06:30,392]{model.py:297} - INFO - Encoding feature feat_2
# [2025-05-04 04:06:30,590]{model.py:297} - INFO - Encoding feature feat_3
# [2025-05-04 04:06:30,837]{model.py:297} - INFO - Encoding feature feat_4
# [2025-05-04 04:06:31,071]{model.py:297} - INFO - Encoding feature feat_5
# [2025-05-04 04:06:31,304]{model.py:297} - INFO - Encoding feature feat_6
# [2025-05-04 04:06:31,454]{model.py:297} - INFO - Encoding feature feat_7
# [2025-05-04 04:06:31,685]{model.py:297} - INFO - Encoding feature feat_8
# [2025-05-04 04:06:31,810]{model.py:297} - INFO - Encoding feature feat_9
# [2025-05-04 04:06:32,177]{model.py:297} - INFO - Encoding feature feat_10
# [2025-05-04 04:06:32,994]{model.py:297} - INFO - Encoding feature feat_11
# [2025-05-04 04:06:33,199]{model.py:297} - INFO - Encoding feature feat_12
# [2025-05-04 04:06:33,396]{model.py:297} - INFO - Encoding feature feat_13
# [2025-05-04 04:06:33,532]{model.py:297} - INFO - Encoding feature feat_14
# [2025-05-04 04:06:33,773]{model.py:297} - INFO - Encoding feature feat_15
# [2025-05-04 04:06:33,929]{model.py:297} - INFO - Encoding feature feat_16
# [2025-05-04 04:06:34,086]{model.py:297} - INFO - Encoding feature feat_17
# [2025-05-04 04:06:34,330]{model.py:297} - INFO - Encoding feature feat_18
# [2025-05-04 04:06:34,485]{model.py:297} - INFO - Encoding feature feat_19
# [2025-05-04 04:06:34,673]{model.py:297} - INFO - Encoding feature feat_20
# [2025-05-04 04:06:34,848]{model.py:297} - INFO - Encoding feature feat_21
# [2025-05-04 04:06:35,198]{model.py:297} - INFO - Encoding feature feat_22
# Test epoch #-1:   0%|          | 0/1975 [00:00<?, ?it/s]
# Exception ignored in: <function _MultiProcessingDataLoaderIter.__del__ at 0x7c3514d632e0>
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.11/dist-packages/torch/utils/data/dataloader.py", line 1604, in __del__
#     self._shutdown_workers()
#   File "/usr/local/lib/python3.11/dist-packages/torch/utils/data/dataloader.py", line 1587, in _shutdown_workers
#     if w.is_alive():
#        ^^^^^^^^^^^^
#   File "/usr/lib/python3.11/multiprocessing/process.py", line 160, in is_alive
#     assert self._parent_pid == os.getpid(), 'can only test a child process'
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# AssertionError: can only test a child process
# Exception ignored in: <function _MultiProcessingDataLoaderIter.__del__ at 0x7c3514d632e0>
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.11/dist-packages/torch/utils/data/dataloader.py", line 1604, in __del__
#     self._shutdown_workers()
#   File "/usr/local/lib/python3.11/dist-packages/torch/utils/data/dataloader.py", line 1587, in _shutdown_workers
#     if w.is_alive():
#        ^^^^^^^^^^^^
#   File "/usr/lib/python3.11/multiprocessing/process.py", line 160, in is_alive
#     assert self._parent_pid == os.getpid(), 'can only test a child process'
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# AssertionError: can only test a child process
# [2025-05-04 04:11:40,965]{model.py:567} - INFO - Finished Test Epoch #-1, average metrics - [AUC: 0.75402, log_loss: 0.37445]
# {'AUC': 0.7540177975669551, 'log_loss': 0.37445330387777553}

# %% [markdown]
# # FinalNet

# %%
finalnet_model = FinalNet(
    block_type="2B",
    use_field_gate=True,
    use_batch_norm=True,
    add_bias=True,
    block1_hidden_dims=[256, 512, 1024],
    block1_hidden_activations=nn.ReLU,
    block1_dropout_rates=0.2,
    block2_hidden_dims=[256, 512, 1024],
    block2_hidden_activations=nn.ReLU,
    block2_dropout_rates=0.2,
    residual_type="concat",
    proj_output_embeddings=True,
)

# %%
train_metrics_final, val_metrics_final = finalnet_model.fit(
    features=df_train.drop(columns="label"),
    target=df_train["label"],
    val_features=df_val.drop(columns="label"),
    val_target=df_val["label"],
    optimizer_cls="torch.optim.Adam",
    optimizer_params=dict(lr=1e-2),
    scheduler_cls="torch.optim.lr_scheduler.ReduceLROnPlateau",
    scheduler_params=dict(mode="max", factor=0.1, patience=1, min_lr=1e-6),
    grad_clip_threshold=10.,
    num_epochs=1,
    seed=42,
    artifacts_path="./finalnet_artifacts",
    device="cuda:0",
    batch_size=4096,
    num_workers=4,
    eval_metric_name="AUC",
    eval_mode="max",
    oov_masking_proba=0.05,
    default_embedding_size=10, # should be equal for all features if using field gate
    l2_net_reg=0.,
    l2_embedding_reg=0,
)
# Out:
# [2025-05-04 04:11:46,001]{model.py:660} - INFO - Used features config: FeaturesConfig(features=[Feature(name='feat_1', feature_type=<FeatureType.CATEGORICAL: 'categorical'>, feature_size=1, needs_embed=True, embedding_size=10, embedding_vocab_size=8, embedding_padding_idx=None), Feature(name='feat_2', feature_type=<FeatureType.CATEGORICAL: 'categorical'>, feature_size=1, needs_embed=True, embedding_size=10, embedding_vocab_size=8, embedding_padding_idx=None), Feature(name='feat_3', feature_type=<FeatureType.CATEGORICAL: 'categorical'>, feature_size=1, needs_embed=True, embedding_size=10, embedding_vocab_size=3479, embedding_padding_idx=None), Feature(name='feat_4', feature_type=<FeatureType.CATEGORICAL: 'categorical'>, feature_size=1, needs_embed=True, embedding_size=10, embedding_vocab_size=4270, embedding_padding_idx=None), Feature(name='feat_5', feature_type=<FeatureType.CATEGORICAL: 'categorical'>, feature_size=1, needs_embed=True, embedding_size=10, embedding_vocab_size=25, embedding_padding_idx=None), Feature(name='feat_6', feature_type=<FeatureType.CATEGORICAL: 'categorical'>, feature_size=1, needs_embed=True, embedding_size=10, embedding_vocab_size=4863, embedding_padding_idx=None), Feature(name='feat_7', feature_type=<FeatureType.CATEGORICAL: 'categorical'>, feature_size=1, needs_embed=True, embedding_size=10, embedding_vocab_size=304, embedding_padding_idx=None), Feature(name='feat_8', feature_type=<FeatureType.CATEGORICAL: 'categorical'>, feature_size=1, needs_embed=True, embedding_size=10, embedding_vocab_size=32, embedding_padding_idx=None), Feature(name='feat_9', feature_type=<FeatureType.CATEGORICAL: 'categorical'>, feature_size=1, needs_embed=True, embedding_size=10, embedding_vocab_size=228185, embedding_padding_idx=None), Feature(name='feat_10', feature_type=<FeatureType.CATEGORICAL: 'categorical'>, feature_size=1, needs_embed=True, embedding_size=10, embedding_vocab_size=1048284, embedding_padding_idx=None), Feature(name='feat_11', feature_type=<FeatureType.CATEGORICAL: 'categorical'>, feature_size=1, needs_embed=True, embedding_size=10, embedding_vocab_size=6514, embedding_padding_idx=None), Feature(name='feat_12', feature_type=<FeatureType.CATEGORICAL: 'categorical'>, feature_size=1, needs_embed=True, embedding_size=10, embedding_vocab_size=5, embedding_padding_idx=None), Feature(name='feat_13', feature_type=<FeatureType.CATEGORICAL: 'categorical'>, feature_size=1, needs_embed=True, embedding_size=10, embedding_vocab_size=5, embedding_padding_idx=None), Feature(name='feat_14', feature_type=<FeatureType.CATEGORICAL: 'categorical'>, feature_size=1, needs_embed=True, embedding_size=10, embedding_vocab_size=1939, embedding_padding_idx=None), Feature(name='feat_15', feature_type=<FeatureType.CATEGORICAL: 'categorical'>, feature_size=1, needs_embed=True, embedding_size=10, embedding_vocab_size=9, embedding_padding_idx=None), Feature(name='feat_16', feature_type=<FeatureType.CATEGORICAL: 'categorical'>, feature_size=1, needs_embed=True, embedding_size=10, embedding_vocab_size=10, embedding_padding_idx=None), Feature(name='feat_17', feature_type=<FeatureType.CATEGORICAL: 'categorical'>, feature_size=1, needs_embed=True, embedding_size=10, embedding_vocab_size=348, embedding_padding_idx=None), Feature(name='feat_18', feature_type=<FeatureType.CATEGORICAL: 'categorical'>, feature_size=1, needs_embed=True, embedding_size=10, embedding_vocab_size=5, embedding_padding_idx=None), Feature(name='feat_19', feature_type=<FeatureType.CATEGORICAL: 'categorical'>, feature_size=1, needs_embed=True, embedding_size=10, embedding_vocab_size=60, embedding_padding_idx=None), Feature(name='feat_20', feature_type=<FeatureType.CATEGORICAL: 'categorical'>, feature_size=1, needs_embed=True, embedding_size=10, embedding_vocab_size=170, embedding_padding_idx=None), Feature(name='feat_21', feature_type=<FeatureType.CATEGORICAL: 'categorical'>, feature_size=1, needs_embed=True, embedding_size=10, embedding_vocab_size=51, embedding_padding_id ...
# [2025-05-04 04:11:46,004]{model.py:675} - INFO - Artifacts path is /kaggle/working/finalnet_artifacts
# [2025-05-04 04:11:46,005]{model.py:681} - INFO - Best model path is finalnet_artifacts/best_model.pt
# [2025-05-04 04:11:46,025]{model.py:686} - INFO - Building features mappings
# [2025-05-04 04:11:46,026]{model.py:272} - INFO - Building mapping for feature feat_1
# [2025-05-04 04:11:46,138]{model.py:272} - INFO - Building mapping for feature feat_2
# [2025-05-04 04:11:46,249]{model.py:272} - INFO - Building mapping for feature feat_3
# [2025-05-04 04:11:46,397]{model.py:272} - INFO - Building mapping for feature feat_4
# [2025-05-04 04:11:46,545]{model.py:272} - INFO - Building mapping for feature feat_5
# [2025-05-04 04:11:46,658]{model.py:272} - INFO - Building mapping for feature feat_6
# [2025-05-04 04:11:46,805]{model.py:272} - INFO - Building mapping for feature feat_7
# [2025-05-04 04:11:46,954]{model.py:272} - INFO - Building mapping for feature feat_8
# [2025-05-04 04:11:47,066]{model.py:272} - INFO - Building mapping for feature feat_9
# [2025-05-04 04:11:47,237]{model.py:272} - INFO - Building mapping for feature feat_10
# [2025-05-04 04:11:47,700]{model.py:272} - INFO - Building mapping for feature feat_11
# [2025-05-04 04:11:47,856]{model.py:272} - INFO - Building mapping for feature feat_12
# [2025-05-04 04:11:47,973]{model.py:272} - INFO - Building mapping for feature feat_13
# [2025-05-04 04:11:48,085]{model.py:272} - INFO - Building mapping for feature feat_14
# [2025-05-04 04:11:48,259]{model.py:272} - INFO - Building mapping for feature feat_15
# [2025-05-04 04:11:48,373]{model.py:272} - INFO - Building mapping for feature feat_16
# [2025-05-04 04:11:48,490]{model.py:272} - INFO - Building mapping for feature feat_17
# [2025-05-04 04:11:48,639]{model.py:272} - INFO - Building mapping for feature feat_18
# [2025-05-04 04:11:48,751]{model.py:272} - INFO - Building mapping for feature feat_19
# [2025-05-04 04:11:48,864]{model.py:272} - INFO - Building mapping for feature feat_20
# [2025-05-04 04:11:49,012]{model.py:272} - INFO - Building mapping for feature feat_21
# [2025-05-04 04:11:49,124]{model.py:272} - INFO - Building mapping for feature feat_22
# [2025-05-04 04:11:49,235]{model.py:689} - INFO - Building train dataloader
# [2025-05-04 04:11:49,614]{model.py:297} - INFO - Encoding feature feat_1
# [2025-05-04 04:11:50,214]{model.py:297} - INFO - Encoding feature feat_2
# [2025-05-04 04:11:50,816]{model.py:297} - INFO - Encoding feature feat_3
# [2025-05-04 04:11:51,438]{model.py:297} - INFO - Encoding feature feat_4
# [2025-05-04 04:11:52,061]{model.py:297} - INFO - Encoding feature feat_5
# [2025-05-04 04:11:52,660]{model.py:297} - INFO - Encoding feature feat_6
# [2025-05-04 04:11:53,295]{model.py:297} - INFO - Encoding feature feat_7
# [2025-05-04 04:11:53,919]{model.py:297} - INFO - Encoding feature feat_8
# [2025-05-04 04:11:54,521]{model.py:297} - INFO - Encoding feature feat_9
# [2025-05-04 04:11:55,331]{model.py:297} - INFO - Encoding feature feat_10
# [2025-05-04 04:11:56,565]{model.py:297} - INFO - Encoding feature feat_11
# [2025-05-04 04:11:57,189]{model.py:297} - INFO - Encoding feature feat_12
# [2025-05-04 04:11:57,784]{model.py:297} - INFO - Encoding feature feat_13
# [2025-05-04 04:11:58,399]{model.py:297} - INFO - Encoding feature feat_14
# [2025-05-04 04:11:59,022]{model.py:297} - INFO - Encoding feature feat_15
# [2025-05-04 04:11:59,623]{model.py:297} - INFO - Encoding feature feat_16
# [2025-05-04 04:12:00,223]{model.py:297} - INFO - Encoding feature feat_17
# [2025-05-04 04:12:00,852]{model.py:297} - INFO - Encoding feature feat_18
# [2025-05-04 04:12:01,456]{model.py:297} - INFO - Encoding feature feat_19
# [2025-05-04 04:12:02,053]{model.py:297} - INFO - Encoding feature feat_20
# [2025-05-04 04:12:02,669]{model.py:297} - INFO - Encoding feature feat_21
# [2025-05-04 04:12:03,268]{model.py:297} - INFO - Encoding feature feat_22
# [2025-05-04 04:12:03,950]{model.py:702} - INFO - Building validation dataloader
# [2025-05-04 04:12:03,981]{model.py:297} - INFO - Encoding feature feat_1
# [2025-05-04 04:12:04,053]{model.py:297} - INFO - Encoding feature feat_2
# [2025-05-04 04:12:04,114]{model.py:297} - INFO - Encoding feature feat_3
# [2025-05-04 04:12:04,191]{model.py:297} - INFO - Encoding feature feat_4
# [2025-05-04 04:12:04,269]{model.py:297} - INFO - Encoding feature feat_5
# [2025-05-04 04:12:04,330]{model.py:297} - INFO - Encoding feature feat_6
# [2025-05-04 04:12:04,409]{model.py:297} - INFO - Encoding feature feat_7
# [2025-05-04 04:12:04,485]{model.py:297} - INFO - Encoding feature feat_8
# [2025-05-04 04:12:04,545]{model.py:297} - INFO - Encoding feature feat_9
# [2025-05-04 04:12:04,728]{model.py:297} - INFO - Encoding feature feat_10
# [2025-05-04 04:12:05,320]{model.py:297} - INFO - Encoding feature feat_11
# [2025-05-04 04:12:05,402]{model.py:297} - INFO - Encoding feature feat_12
# [2025-05-04 04:12:05,463]{model.py:297} - INFO - Encoding feature feat_13
# [2025-05-04 04:12:05,524]{model.py:297} - INFO - Encoding feature feat_14
# [2025-05-04 04:12:05,629]{model.py:297} - INFO - Encoding feature feat_15
# [2025-05-04 04:12:05,690]{model.py:297} - INFO - Encoding feature feat_16
# [2025-05-04 04:12:05,751]{model.py:297} - INFO - Encoding feature feat_17
# [2025-05-04 04:12:05,854]{model.py:297} - INFO - Encoding feature feat_18
# [2025-05-04 04:12:05,915]{model.py:297} - INFO - Encoding feature feat_19
# [2025-05-04 04:12:06,000]{model.py:297} - INFO - Encoding feature feat_20
# [2025-05-04 04:12:06,064]{model.py:297} - INFO - Encoding feature feat_21
# [2025-05-04 04:12:06,151]{model.py:297} - INFO - Encoding feature feat_22
# [2025-05-04 04:12:06,223]{model.py:712} - INFO - Starting training process
# Train epoch #0:   0%|          | 0/6910 [00:04<?, ?it/s]
# Exception ignored in: <function _MultiProcessingDataLoaderIter.__del__ at 0x7c3514d632e0>
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.11/dist-packages/torch/utils/data/dataloader.py", line 1604, in __del__
#     self._shutdown_workers()
#   File "/usr/local/lib/python3.11/dist-packages/torch/utils/data/dataloader.py", line 1587, in _shutdown_workers
#     if w.is_alive():
#        ^^^^^^^^^^^^
#   File "/usr/lib/python3.11/multiprocessing/process.py", line 160, in is_alive
#     assert self._parent_pid == os.getpid(), 'can only test a child process'
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# AssertionError: can only test a child process
# Exception ignored in: <function _MultiProcessingDataLoaderIter.__del__ at 0x7c3514d632e0>
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.11/dist-packages/torch/utils/data/dataloader.py", line 1604, in __del__
#     self._shutdown_workers()
#   File "/usr/local/lib/python3.11/dist-packages/torch/utils/data/dataloader.py", line 1587, in _shutdown_workers
#     if w.is_alive():
#        ^^^^^^^^^^^^
#   File "/usr/lib/python3.11/multiprocessing/process.py", line 160, in is_alive
#     assert self._parent_pid == os.getpid(), 'can only test a child process'
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# AssertionError: can only test a child process
# Exception ignored in: <function _MultiProcessingDataLoaderIter.__del__ at 0x7c3514d632e0>
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.11/dist-packages/torch/utils/data/dataloader.py", line 1604, in __del__
#     self._shutdown_workers()
#   File "/usr/local/lib/python3.11/dist-packages/torch/utils/data/dataloader.py", line 1587, in _shutdown_workers
#     if w.is_alive():
#        ^^^^^^^^^^^^
#   File "/usr/lib/python3.11/multiprocessing/process.py", line 160, in is_alive
#     assert self._parent_pid == os.getpid(), 'can only test a child process'
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# AssertionError: can only test a child process
# Exception ignored in: <function _MultiProcessingDataLoaderIter.__del__ at 0x7c3514d632e0>
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.11/dist-packages/torch/utils/data/dataloader.py", line 1604, in __del__
#     self._shutdown_workers()
#   File "/usr/local/lib/python3.11/dist-packages/torch/utils/data/dataloader.py", line 1587, in _shutdown_workers
#     if w.is_alive():
#        ^^^^^^^^^^^^
#   File "/usr/lib/python3.11/multiprocessing/process.py", line 160, in is_alive
#     assert self._parent_pid == os.getpid(), 'can only test a child process'
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# AssertionError: can only test a child process
# [2025-05-04 05:36:29,675]{model.py:567} - INFO - Finished Train Epoch #0, average metrics - [loss: 0.39554]
# Validation epoch #0:   0%|          | 0/988 [00:00<?, ?it/s]
# [2025-05-04 05:38:48,478]{model.py:567} - INFO - Finished Validation Epoch #0, average metrics - [AUC: 0.73775, log_loss: 0.39812]
# [2025-05-04 05:39:10,485]{model.py:747} - INFO - Best model with AUC = 0.7377471633309797 was saved to finalnet_artifacts/best_model.pt
# [2025-05-04 05:39:10,486]{model.py:763} - INFO - Loading best model from finalnet_artifacts/best_model.pt

# %%
test_metrics_final = finalnet_model.test(
    features=df_test.drop(columns="label"),
    target=df_test["label"],
    device="cuda:0",
    batch_size=4096,
    num_workers=2,
)
test_metrics_final
# Out:
# [2025-05-04 05:39:11,010]{model.py:789} - INFO - Building test dataloader
# [2025-05-04 05:39:11,384]{model.py:297} - INFO - Encoding feature feat_1
# [2025-05-04 05:39:11,744]{model.py:297} - INFO - Encoding feature feat_2
# [2025-05-04 05:39:11,937]{model.py:297} - INFO - Encoding feature feat_3
# [2025-05-04 05:39:12,192]{model.py:297} - INFO - Encoding feature feat_4
# [2025-05-04 05:39:12,425]{model.py:297} - INFO - Encoding feature feat_5
# [2025-05-04 05:39:12,653]{model.py:297} - INFO - Encoding feature feat_6
# [2025-05-04 05:39:12,807]{model.py:297} - INFO - Encoding feature feat_7
# [2025-05-04 05:39:13,039]{model.py:297} - INFO - Encoding feature feat_8
# [2025-05-04 05:39:13,231]{model.py:297} - INFO - Encoding feature feat_9
# [2025-05-04 05:39:13,627]{model.py:297} - INFO - Encoding feature feat_10
# [2025-05-04 05:39:14,509]{model.py:297} - INFO - Encoding feature feat_11
# [2025-05-04 05:39:14,678]{model.py:297} - INFO - Encoding feature feat_12
# [2025-05-04 05:39:14,914]{model.py:297} - INFO - Encoding feature feat_13
# [2025-05-04 05:39:15,115]{model.py:297} - INFO - Encoding feature feat_14
# [2025-05-04 05:39:15,304]{model.py:297} - INFO - Encoding feature feat_15
# [2025-05-04 05:39:15,504]{model.py:297} - INFO - Encoding feature feat_16
# [2025-05-04 05:39:15,711]{model.py:297} - INFO - Encoding feature feat_17
# [2025-05-04 05:39:15,980]{model.py:297} - INFO - Encoding feature feat_18
# [2025-05-04 05:39:16,185]{model.py:297} - INFO - Encoding feature feat_19
# [2025-05-04 05:39:16,424]{model.py:297} - INFO - Encoding feature feat_20
# [2025-05-04 05:39:16,554]{model.py:297} - INFO - Encoding feature feat_21
# [2025-05-04 05:39:16,798]{model.py:297} - INFO - Encoding feature feat_22
# Test epoch #-1:   0%|          | 0/1975 [00:00<?, ?it/s]
# Exception ignored in: <function _MultiProcessingDataLoaderIter.__del__ at 0x7c3514d632e0>
#   File "/usr/local/lib/python3.11/dist-packages/torch/utils/data/dataloader.py", line 1604, in __del__
# Traceback (most recent call last):
#     self._shutdown_workers()
#   File "/usr/local/lib/python3.11/dist-packages/torch/utils/data/dataloader.py", line 1587, in _shutdown_workers
#     if w.is_alive():
#       ^ ^^^^^^^^^^^
#   File "/usr/lib/python3.11/multiprocessing/process.py", line 160, in is_alive
#     assert self._parent_pid == os.getpid(), 'can only test a child process'
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# AssertionError: can only test a child process
# Exception ignored in: <function _MultiProcessingDataLoaderIter.__del__ at 0x7c3514d632e0>
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.11/dist-packages/torch/utils/data/dataloader.py", line 1604, in __del__
#     self._shutdown_workers()
#   File "/usr/local/lib/python3.11/dist-packages/torch/utils/data/dataloader.py", line 1587, in _shutdown_workers
#     if w.is_alive():
#        ^^^^^^^^^^^^
#   File "/usr/lib/python3.11/multiprocessing/process.py", line 160, in is_alive
#     assert self._parent_pid == os.getpid(), 'can only test a child process'
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# AssertionError: can only test a child process
# [2025-05-04 05:44:14,865]{model.py:567} - INFO - Finished Test Epoch #-1, average metrics - [AUC: 0.75845, log_loss: 0.36969]
# {'AUC': 0.7584461618508356, 'log_loss': 0.36968690108798863}
