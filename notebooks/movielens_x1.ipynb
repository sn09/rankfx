# %%
# !git clone https://github.com/sn09/ranking.git
# Out:
# Cloning into 'ranking'...
# remote: Enumerating objects: 342, done.
# remote: Counting objects: 100% (342/342), done.
# remote: Compressing objects: 100% (198/198), done.
# remote: Total 342 (delta 166), reused 286 (delta 119), pack-reused 0 (from 0)
# Receiving objects: 100% (342/342), 169.45 KiB | 3.20 MiB/s, done.
# Resolving deltas: 100% (166/166), done.

# %%
import sys

import lightgbm as lgb
import numpy as np
import pandas as pd
from lightgbm import LGBMClassifier, LGBMRanker
from sklearn.metrics import log_loss, roc_auc_score
from torch import nn

sys.path.append("./ranking/")

from rankfx.dcnv2.model import DCNv2
from rankfx.finalnet.model import FinalNet

# %%
base_path = "/kaggle/input/final-movielens-x1"

df_train = pd.read_csv(f"{base_path}/train.csv")
df_test = pd.read_csv(f"{base_path}/test.csv")
df_val = pd.read_csv(f"{base_path}/valid.csv")

df_train.head()
# Out:
#    label  user_id  item_id  tag_id
# 0      0    84982       58   39525
# 1      0    87756     8757   22786
# 2      0    80311    14912   45676
# 3      1    82036    84509   33556
# 4      0    66867    57349   15092

# %%
for df in [df_train, df_val, df_test]:
    df["user_id"] = df["user_id"].astype("category")
    df["item_id"] = df["item_id"].astype("category")
    df["tag_id"] = df["tag_id"].astype("category")

# %% [markdown]
# # LightGBM

# %% [markdown]
# ## LGBMClassifier

# %%
booster_clf = LGBMClassifier(
    objective="binary",
    max_depth=5,
    learning_rate=1e-1,
    n_estimators=2000,
)

# %%
feature_names = df_train.columns.difference(["label"]).tolist()

booster_clf = booster_clf.fit(
    X=df_train.drop(columns="label"),
    y=df_train["label"],
    eval_set=(df_val.drop(columns="label"), df_val["label"]),
    feature_name=df_train.drop(columns="label").columns.tolist(),
    categorical_feature=feature_names,
    callbacks=[lgb.early_stopping(stopping_rounds=10), lgb.log_evaluation()],
)
# Out:
# [LightGBM] [Warning] Categorical features with more bins than the configured maximum bin number found.
# [LightGBM] [Warning] For categorical features, max_bin and max_bin_by_feature may be ignored with a large number of categories.
# [LightGBM] [Info] Number of positive: 467878, number of negative: 936923
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.072819 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 43730
# [LightGBM] [Info] Number of data points in the train set: 1404801, number of used features: 3
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.333056 -> initscore=-0.694394
# [LightGBM] [Info] Start training from score -0.694394
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [1]	valid_0's binary_logloss: 0.614768
# Training until validation scores don't improve for 10 rounds
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [2]	valid_0's binary_logloss: 0.602935
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [3]	valid_0's binary_logloss: 0.593241
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [4]	valid_0's binary_logloss: 0.58715
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [5]	valid_0's binary_logloss: 0.579756
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [6]	valid_0's binary_logloss: 0.572435
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [7]	valid_0's binary_logloss: 0.567546
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [8]	valid_0's binary_logloss: 0.563567
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [9]	valid_0's binary_logloss: 0.557626
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [10]	valid_0's binary_logloss: 0.552823
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [11]	valid_0's binary_logloss: 0.548545
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [12]	valid_0's binary_logloss: 0.545015
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [13]	valid_0's binary_logloss: 0.541082
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [14]	valid_0's binary_logloss: 0.537077
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [15]	valid_0's binary_logloss: 0.532987
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [16]	valid_0's binary_logloss: 0.5301
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [17]	valid_0's binary_logloss: 0.527228
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [18]	valid_0's binary_logloss: 0.524165
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [19]	valid_0's binary_logloss: 0.520371
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [20]	valid_0's binary_logloss: 0.517809
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [21]	valid_0's binary_logloss: 0.514819
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [22]	valid_0's binary_logloss: 0.51243
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [23]	valid_0's binary_logloss: 0.509841
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [24]	valid_0's binary_logloss: 0.50693
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [25]	valid_0's binary_logloss: 0.5044
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [26]	valid_0's binary_logloss: 0.502478
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [27]	valid_0's binary_logloss: 0.500042
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [28]	valid_0's binary_logloss: 0.497961
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [29]	valid_0's binary_logloss: 0.495676
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [30]	valid_0's binary_logloss: 0.493249
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [31]	valid_0's binary_logloss: 0.491048
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [32]	valid_0's binary_logloss: 0.489062
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [33]	valid_0's binary_logloss: 0.487057
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [34]	valid_0's binary_logloss: 0.485254
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [35]	valid_0's binary_logloss: 0.482939
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [36]	valid_0's binary_logloss: 0.481292
# Exception ignored on calling ctypes callback function: <function _log_callback at 0x7b02b2b8a3e0>
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.11/dist-packages/lightgbm/basic.py", line 287, in _log_callback
#     def _log_callback(msg: bytes) -> None:
#
# KeyboardInterrupt:
# No further splits with positive gain, best gain: -inf
# [37]	valid_0's binary_logloss: 0.47932
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [38]	valid_0's binary_logloss: 0.477549
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [39]	valid_0's binary_logloss: 0.475992
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [40]	valid_0's binary_logloss: 0.473971
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [41]	valid_0's binary_logloss: 0.472167
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [42]	valid_0's binary_logloss: 0.47054
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [43]	valid_0's binary_logloss: 0.468779
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [44]	valid_0's binary_logloss: 0.467297
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [45]	valid_0's binary_logloss: 0.465891
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [46]	valid_0's binary_logloss: 0.46413
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [47]	valid_0's binary_logloss: 0.462535
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [48]	valid_0's binary_logloss: 0.461124
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [49]	valid_0's binary_logloss: 0.459588
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [50]	valid_0's binary_logloss: 0.458345
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [51]	valid_0's binary_logloss: 0.456964
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [52]	valid_0's binary_logloss: 0.455385
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [53]	valid_0's binary_logloss: 0.453952
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [54]	valid_0's binary_logloss: 0.452761
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [55]	valid_0's binary_logloss: 0.45132
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [56]	valid_0's binary_logloss: 0.449886
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [57]	valid_0's binary_logloss: 0.44874
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [58]	valid_0's binary_logloss: 0.4472
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [59]	valid_0's binary_logloss: 0.445995
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [60]	valid_0's binary_logloss: 0.444962
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [61]	valid_0's binary_logloss: 0.4437
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [62]	valid_0's binary_logloss: 0.442486
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [63]	valid_0's binary_logloss: 0.441394
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [64]	valid_0's binary_logloss: 0.440348
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [65]	valid_0's binary_logloss: 0.439243
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [66]	valid_0's binary_logloss: 0.438145
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [67]	valid_0's binary_logloss: 0.437058
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [68]	valid_0's binary_logloss: 0.435951
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [69]	valid_0's binary_logloss: 0.434741
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [70]	valid_0's binary_logloss: 0.433591
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [71]	valid_0's binary_logloss: 0.432571
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [72]	valid_0's binary_logloss: 0.431465
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [73]	valid_0's binary_logloss: 0.430452
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [74]	valid_0's binary_logloss: 0.429654
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [75]	valid_0's binary_logloss: 0.428603
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [76]	valid_0's binary_logloss: 0.427768
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [77]	valid_0's binary_logloss: 0.426811
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [78]	valid_0's binary_logloss: 0.425905
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [79]	valid_0's binary_logloss: 0.42485
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [80]	valid_0's binary_logloss: 0.423913
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [81]	valid_0's binary_logloss: 0.422869
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [82]	valid_0's binary_logloss: 0.422087
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [83]	valid_0's binary_logloss: 0.421183
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [84]	valid_0's binary_logloss: 0.420313
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [85]	valid_0's binary_logloss: 0.419421
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [86]	valid_0's binary_logloss: 0.418685
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [87]	valid_0's binary_logloss: 0.417623
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [88]	valid_0's binary_logloss: 0.41682
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [89]	valid_0's binary_logloss: 0.415967
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [90]	valid_0's binary_logloss: 0.415055
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [91]	valid_0's binary_logloss: 0.414209
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [92]	valid_0's binary_logloss: 0.413541
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [93]	valid_0's binary_logloss: 0.412761
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [94]	valid_0's binary_logloss: 0.412014
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [95]	valid_0's binary_logloss: 0.411372
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [96]	valid_0's binary_logloss: 0.41055
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [97]	valid_0's binary_logloss: 0.409787
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [98]	valid_0's binary_logloss: 0.408977
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [99]	valid_0's binary_logloss: 0.407921
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [100]	valid_0's binary_logloss: 0.407173
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [101]	valid_0's binary_logloss: 0.406419
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [102]	valid_0's binary_logloss: 0.40567
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [103]	valid_0's binary_logloss: 0.404849
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [104]	valid_0's binary_logloss: 0.404225
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [105]	valid_0's binary_logloss: 0.403562
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [106]	valid_0's binary_logloss: 0.402937
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [107]	valid_0's binary_logloss: 0.40202
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [108]	valid_0's binary_logloss: 0.401301
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [109]	valid_0's binary_logloss: 0.400575
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [110]	valid_0's binary_logloss: 0.399928
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [111]	valid_0's binary_logloss: 0.39928
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [112]	valid_0's binary_logloss: 0.398654
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [113]	valid_0's binary_logloss: 0.398026
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [114]	valid_0's binary_logloss: 0.396876
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [115]	valid_0's binary_logloss: 0.396229
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [116]	valid_0's binary_logloss: 0.39565
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [117]	valid_0's binary_logloss: 0.395004
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [118]	valid_0's binary_logloss: 0.394467
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [119]	valid_0's binary_logloss: 0.393861
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [120]	valid_0's binary_logloss: 0.393307
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [121]	valid_0's binary_logloss: 0.392743
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [122]	valid_0's binary_logloss: 0.392168
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [123]	valid_0's binary_logloss: 0.391675
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [124]	valid_0's binary_logloss: 0.391117
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [125]	valid_0's binary_logloss: 0.390601
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [126]	valid_0's binary_logloss: 0.390034
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [127]	valid_0's binary_logloss: 0.389527
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [128]	valid_0's binary_logloss: 0.388472
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [129]	valid_0's binary_logloss: 0.387991
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [130]	valid_0's binary_logloss: 0.387457
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [131]	valid_0's binary_logloss: 0.38698
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [132]	valid_0's binary_logloss: 0.386456
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [133]	valid_0's binary_logloss: 0.385932
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [134]	valid_0's binary_logloss: 0.385456
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [135]	valid_0's binary_logloss: 0.384721
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [136]	valid_0's binary_logloss: 0.384211
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [137]	valid_0's binary_logloss: 0.383697
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [138]	valid_0's binary_logloss: 0.383205
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [139]	valid_0's binary_logloss: 0.382715
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [140]	valid_0's binary_logloss: 0.382219
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [141]	valid_0's binary_logloss: 0.381791
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [142]	valid_0's binary_logloss: 0.381364
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [143]	valid_0's binary_logloss: 0.380923
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [144]	valid_0's binary_logloss: 0.380487
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [145]	valid_0's binary_logloss: 0.379858
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [146]	valid_0's binary_logloss: 0.379392
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [147]	valid_0's binary_logloss: 0.37898
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [148]	valid_0's binary_logloss: 0.378559
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [149]	valid_0's binary_logloss: 0.378098
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [150]	valid_0's binary_logloss: 0.377696
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [151]	valid_0's binary_logloss: 0.37726
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [152]	valid_0's binary_logloss: 0.376816
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [153]	valid_0's binary_logloss: 0.376397
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [154]	valid_0's binary_logloss: 0.375818
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [155]	valid_0's binary_logloss: 0.375411
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [156]	valid_0's binary_logloss: 0.375032
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [157]	valid_0's binary_logloss: 0.374649
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [158]	valid_0's binary_logloss: 0.374238
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [159]	valid_0's binary_logloss: 0.373861
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [160]	valid_0's binary_logloss: 0.373482
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [161]	valid_0's binary_logloss: 0.373104
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [162]	valid_0's binary_logloss: 0.372692
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [163]	valid_0's binary_logloss: 0.37235
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [164]	valid_0's binary_logloss: 0.371982
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [165]	valid_0's binary_logloss: 0.371607
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [166]	valid_0's binary_logloss: 0.371129
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [167]	valid_0's binary_logloss: 0.370725
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [168]	valid_0's binary_logloss: 0.370403
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [169]	valid_0's binary_logloss: 0.370035
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [170]	valid_0's binary_logloss: 0.369667
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [171]	valid_0's binary_logloss: 0.369299
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [172]	valid_0's binary_logloss: 0.368941
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [173]	valid_0's binary_logloss: 0.368585
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [174]	valid_0's binary_logloss: 0.368241
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [175]	valid_0's binary_logloss: 0.367897
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [176]	valid_0's binary_logloss: 0.367588
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [177]	valid_0's binary_logloss: 0.367143
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [178]	valid_0's binary_logloss: 0.366811
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [179]	valid_0's binary_logloss: 0.366443
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [180]	valid_0's binary_logloss: 0.366134
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [181]	valid_0's binary_logloss: 0.365801
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [182]	valid_0's binary_logloss: 0.365459
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [183]	valid_0's binary_logloss: 0.365138
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [184]	valid_0's binary_logloss: 0.364854
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [185]	valid_0's binary_logloss: 0.364556
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [186]	valid_0's binary_logloss: 0.364234
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [187]	valid_0's binary_logloss: 0.363948
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [188]	valid_0's binary_logloss: 0.363623
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [189]	valid_0's binary_logloss: 0.363315
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [190]	valid_0's binary_logloss: 0.363003
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [191]	valid_0's binary_logloss: 0.362686
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [192]	valid_0's binary_logloss: 0.362392
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [193]	valid_0's binary_logloss: 0.361788
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [194]	valid_0's binary_logloss: 0.361499
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [195]	valid_0's binary_logloss: 0.361205
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [196]	valid_0's binary_logloss: 0.360889
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [197]	valid_0's binary_logloss: 0.360601
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [198]	valid_0's binary_logloss: 0.360315
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [199]	valid_0's binary_logloss: 0.360016
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [200]	valid_0's binary_logloss: 0.359737
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [201]	valid_0's binary_logloss: 0.359366
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [202]	valid_0's binary_logloss: 0.359084
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [203]	valid_0's binary_logloss: 0.358815
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [204]	valid_0's binary_logloss: 0.35843
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [205]	valid_0's binary_logloss: 0.358138
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [206]	valid_0's binary_logloss: 0.357869
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [207]	valid_0's binary_logloss: 0.357593
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [208]	valid_0's binary_logloss: 0.35732
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [209]	valid_0's binary_logloss: 0.357083
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [210]	valid_0's binary_logloss: 0.35682
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [211]	valid_0's binary_logloss: 0.356536
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [212]	valid_0's binary_logloss: 0.356268
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [213]	valid_0's binary_logloss: 0.355915
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [214]	valid_0's binary_logloss: 0.355637
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [215]	valid_0's binary_logloss: 0.355209
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [216]	valid_0's binary_logloss: 0.354959
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [217]	valid_0's binary_logloss: 0.354702
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [218]	valid_0's binary_logloss: 0.354429
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [219]	valid_0's binary_logloss: 0.354164
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [220]	valid_0's binary_logloss: 0.353904
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [221]	valid_0's binary_logloss: 0.353663
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [222]	valid_0's binary_logloss: 0.353411
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [223]	valid_0's binary_logloss: 0.35316
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [224]	valid_0's binary_logloss: 0.352926
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [225]	valid_0's binary_logloss: 0.352681
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [226]	valid_0's binary_logloss: 0.352434
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [227]	valid_0's binary_logloss: 0.352107
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [228]	valid_0's binary_logloss: 0.351855
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [229]	valid_0's binary_logloss: 0.35157
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [230]	valid_0's binary_logloss: 0.351287
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [231]	valid_0's binary_logloss: 0.3509
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [232]	valid_0's binary_logloss: 0.350616
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [233]	valid_0's binary_logloss: 0.350253
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [234]	valid_0's binary_logloss: 0.350028
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [235]	valid_0's binary_logloss: 0.349831
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [236]	valid_0's binary_logloss: 0.349594
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [237]	valid_0's binary_logloss: 0.34936
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [238]	valid_0's binary_logloss: 0.349123
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [239]	valid_0's binary_logloss: 0.348902
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [240]	valid_0's binary_logloss: 0.348688
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [241]	valid_0's binary_logloss: 0.34846
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [242]	valid_0's binary_logloss: 0.3481
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [243]	valid_0's binary_logloss: 0.347867
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [244]	valid_0's binary_logloss: 0.347649
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [245]	valid_0's binary_logloss: 0.34743
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [246]	valid_0's binary_logloss: 0.347209
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [247]	valid_0's binary_logloss: 0.346998
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [248]	valid_0's binary_logloss: 0.346716
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [249]	valid_0's binary_logloss: 0.346434
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [250]	valid_0's binary_logloss: 0.346058
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [251]	valid_0's binary_logloss: 0.345836
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [252]	valid_0's binary_logloss: 0.345613
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [253]	valid_0's binary_logloss: 0.345405
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [254]	valid_0's binary_logloss: 0.345121
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [255]	valid_0's binary_logloss: 0.344815
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [256]	valid_0's binary_logloss: 0.344637
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [257]	valid_0's binary_logloss: 0.344435
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [258]	valid_0's binary_logloss: 0.344231
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [259]	valid_0's binary_logloss: 0.344031
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [260]	valid_0's binary_logloss: 0.343712
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [261]	valid_0's binary_logloss: 0.343508
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [262]	valid_0's binary_logloss: 0.343316
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [263]	valid_0's binary_logloss: 0.343131
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [264]	valid_0's binary_logloss: 0.342932
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [265]	valid_0's binary_logloss: 0.342716
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [266]	valid_0's binary_logloss: 0.34249
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [267]	valid_0's binary_logloss: 0.342304
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [268]	valid_0's binary_logloss: 0.342111
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [269]	valid_0's binary_logloss: 0.341924
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [270]	valid_0's binary_logloss: 0.341741
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [271]	valid_0's binary_logloss: 0.341556
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [272]	valid_0's binary_logloss: 0.341362
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [273]	valid_0's binary_logloss: 0.341176
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [274]	valid_0's binary_logloss: 0.340921
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [275]	valid_0's binary_logloss: 0.34074
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [276]	valid_0's binary_logloss: 0.340561
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [277]	valid_0's binary_logloss: 0.340287
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [278]	valid_0's binary_logloss: 0.340105
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [279]	valid_0's binary_logloss: 0.339922
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [280]	valid_0's binary_logloss: 0.339739
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [281]	valid_0's binary_logloss: 0.339499
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [282]	valid_0's binary_logloss: 0.339317
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [283]	valid_0's binary_logloss: 0.339138
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [284]	valid_0's binary_logloss: 0.338974
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [285]	valid_0's binary_logloss: 0.338818
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [286]	valid_0's binary_logloss: 0.338562
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [287]	valid_0's binary_logloss: 0.338385
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [288]	valid_0's binary_logloss: 0.338208
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [289]	valid_0's binary_logloss: 0.338051
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [290]	valid_0's binary_logloss: 0.337797
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [291]	valid_0's binary_logloss: 0.337487
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [292]	valid_0's binary_logloss: 0.337308
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [293]	valid_0's binary_logloss: 0.337134
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [294]	valid_0's binary_logloss: 0.336949
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [295]	valid_0's binary_logloss: 0.336785
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [296]	valid_0's binary_logloss: 0.336623
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [297]	valid_0's binary_logloss: 0.336454
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [298]	valid_0's binary_logloss: 0.336312
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [299]	valid_0's binary_logloss: 0.336137
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [300]	valid_0's binary_logloss: 0.335984
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [301]	valid_0's binary_logloss: 0.33578
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [302]	valid_0's binary_logloss: 0.335631
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [303]	valid_0's binary_logloss: 0.335473
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [304]	valid_0's binary_logloss: 0.335342
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [305]	valid_0's binary_logloss: 0.335128
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [306]	valid_0's binary_logloss: 0.33496
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [307]	valid_0's binary_logloss: 0.334742
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [308]	valid_0's binary_logloss: 0.334492
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [309]	valid_0's binary_logloss: 0.33433
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [310]	valid_0's binary_logloss: 0.334157
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [311]	valid_0's binary_logloss: 0.333965
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [312]	valid_0's binary_logloss: 0.333812
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [313]	valid_0's binary_logloss: 0.333622
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [314]	valid_0's binary_logloss: 0.333468
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [315]	valid_0's binary_logloss: 0.333316
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [316]	valid_0's binary_logloss: 0.333159
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [317]	valid_0's binary_logloss: 0.33301
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [318]	valid_0's binary_logloss: 0.33286
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [319]	valid_0's binary_logloss: 0.332699
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [320]	valid_0's binary_logloss: 0.332552
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [321]	valid_0's binary_logloss: 0.332395
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [322]	valid_0's binary_logloss: 0.332282
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [323]	valid_0's binary_logloss: 0.332047
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [324]	valid_0's binary_logloss: 0.331816
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [325]	valid_0's binary_logloss: 0.331682
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [326]	valid_0's binary_logloss: 0.331548
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [327]	valid_0's binary_logloss: 0.331405
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [328]	valid_0's binary_logloss: 0.331251
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [329]	valid_0's binary_logloss: 0.331106
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [330]	valid_0's binary_logloss: 0.330858
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [331]	valid_0's binary_logloss: 0.33059
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [332]	valid_0's binary_logloss: 0.330463
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [333]	valid_0's binary_logloss: 0.33033
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [334]	valid_0's binary_logloss: 0.3302
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [335]	valid_0's binary_logloss: 0.330067
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [336]	valid_0's binary_logloss: 0.329928
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [337]	valid_0's binary_logloss: 0.329792
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [338]	valid_0's binary_logloss: 0.329644
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [339]	valid_0's binary_logloss: 0.329508
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [340]	valid_0's binary_logloss: 0.329333
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [341]	valid_0's binary_logloss: 0.329199
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [342]	valid_0's binary_logloss: 0.329058
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [343]	valid_0's binary_logloss: 0.328922
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [344]	valid_0's binary_logloss: 0.328782
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [345]	valid_0's binary_logloss: 0.328645
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [346]	valid_0's binary_logloss: 0.32851
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [347]	valid_0's binary_logloss: 0.328387
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [348]	valid_0's binary_logloss: 0.32825
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [349]	valid_0's binary_logloss: 0.327979
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [350]	valid_0's binary_logloss: 0.327854
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [351]	valid_0's binary_logloss: 0.327678
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [352]	valid_0's binary_logloss: 0.327545
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [353]	valid_0's binary_logloss: 0.327423
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [354]	valid_0's binary_logloss: 0.327257
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [355]	valid_0's binary_logloss: 0.327131
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [356]	valid_0's binary_logloss: 0.326989
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [357]	valid_0's binary_logloss: 0.326874
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [358]	valid_0's binary_logloss: 0.326761
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [359]	valid_0's binary_logloss: 0.326641
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [360]	valid_0's binary_logloss: 0.326533
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [361]	valid_0's binary_logloss: 0.326406
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [362]	valid_0's binary_logloss: 0.32625
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [363]	valid_0's binary_logloss: 0.326135
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [364]	valid_0's binary_logloss: 0.326009
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [365]	valid_0's binary_logloss: 0.325791
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [366]	valid_0's binary_logloss: 0.325671
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [367]	valid_0's binary_logloss: 0.325547
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [368]	valid_0's binary_logloss: 0.325413
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [369]	valid_0's binary_logloss: 0.325271
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [370]	valid_0's binary_logloss: 0.32516
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [371]	valid_0's binary_logloss: 0.325046
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [372]	valid_0's binary_logloss: 0.324925
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [373]	valid_0's binary_logloss: 0.324735
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [374]	valid_0's binary_logloss: 0.324534
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [375]	valid_0's binary_logloss: 0.324414
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [376]	valid_0's binary_logloss: 0.324307
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [377]	valid_0's binary_logloss: 0.324154
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [378]	valid_0's binary_logloss: 0.324033
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [379]	valid_0's binary_logloss: 0.323872
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [380]	valid_0's binary_logloss: 0.323748
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [381]	valid_0's binary_logloss: 0.323618
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [382]	valid_0's binary_logloss: 0.323463
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [383]	valid_0's binary_logloss: 0.323325
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [384]	valid_0's binary_logloss: 0.323192
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [385]	valid_0's binary_logloss: 0.323074
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [386]	valid_0's binary_logloss: 0.322964
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [387]	valid_0's binary_logloss: 0.322849
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [388]	valid_0's binary_logloss: 0.322697
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [389]	valid_0's binary_logloss: 0.322576
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [390]	valid_0's binary_logloss: 0.322466
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [391]	valid_0's binary_logloss: 0.322355
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [392]	valid_0's binary_logloss: 0.322235
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [393]	valid_0's binary_logloss: 0.322126
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [394]	valid_0's binary_logloss: 0.322012
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [395]	valid_0's binary_logloss: 0.321895
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [396]	valid_0's binary_logloss: 0.321769
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [397]	valid_0's binary_logloss: 0.3216
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [398]	valid_0's binary_logloss: 0.321502
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [399]	valid_0's binary_logloss: 0.321399
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [400]	valid_0's binary_logloss: 0.321292
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [401]	valid_0's binary_logloss: 0.321186
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [402]	valid_0's binary_logloss: 0.321031
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [403]	valid_0's binary_logloss: 0.320937
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [404]	valid_0's binary_logloss: 0.320821
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [405]	valid_0's binary_logloss: 0.320704
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [406]	valid_0's binary_logloss: 0.320594
# ...
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [1865]	valid_0's binary_logloss: 0.267837
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [1866]	valid_0's binary_logloss: 0.267831
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [1867]	valid_0's binary_logloss: 0.267811
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [1868]	valid_0's binary_logloss: 0.267802
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [1869]	valid_0's binary_logloss: 0.267787
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [1870]	valid_0's binary_logloss: 0.267777
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [1871]	valid_0's binary_logloss: 0.267771
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [1872]	valid_0's binary_logloss: 0.267762
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [1873]	valid_0's binary_logloss: 0.267752
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [1874]	valid_0's binary_logloss: 0.267723
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [1875]	valid_0's binary_logloss: 0.267718
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [1876]	valid_0's binary_logloss: 0.267694
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [1877]	valid_0's binary_logloss: 0.267671
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [1878]	valid_0's binary_logloss: 0.267649
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [1879]	valid_0's binary_logloss: 0.267646
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [1880]	valid_0's binary_logloss: 0.267639
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [1881]	valid_0's binary_logloss: 0.267622
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [1882]	valid_0's binary_logloss: 0.267611
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [1883]	valid_0's binary_logloss: 0.267601
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [1884]	valid_0's binary_logloss: 0.267577
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [1885]	valid_0's binary_logloss: 0.267562
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [1886]	valid_0's binary_logloss: 0.267553
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [1887]	valid_0's binary_logloss: 0.267542
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [1888]	valid_0's binary_logloss: 0.26753
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [1889]	valid_0's binary_logloss: 0.267525
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [1890]	valid_0's binary_logloss: 0.267515
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [1891]	valid_0's binary_logloss: 0.267515
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [1892]	valid_0's binary_logloss: 0.267506
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [1893]	valid_0's binary_logloss: 0.267493
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [1894]	valid_0's binary_logloss: 0.267488
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [1895]	valid_0's binary_logloss: 0.267469
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [1896]	valid_0's binary_logloss: 0.26747
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [1897]	valid_0's binary_logloss: 0.267453
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [1898]	valid_0's binary_logloss: 0.267452
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [1899]	valid_0's binary_logloss: 0.26745
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [1900]	valid_0's binary_logloss: 0.267423
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [1901]	valid_0's binary_logloss: 0.267414
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [1902]	valid_0's binary_logloss: 0.267385
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [1903]	valid_0's binary_logloss: 0.267381
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [1904]	valid_0's binary_logloss: 0.267377
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [1905]	valid_0's binary_logloss: 0.267378
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [1906]	valid_0's binary_logloss: 0.267377
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [1907]	valid_0's binary_logloss: 0.267351
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [1908]	valid_0's binary_logloss: 0.267344
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [1909]	valid_0's binary_logloss: 0.267335
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [1910]	valid_0's binary_logloss: 0.267317
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [1911]	valid_0's binary_logloss: 0.267308
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [1912]	valid_0's binary_logloss: 0.26731
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [1913]	valid_0's binary_logloss: 0.2673
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [1914]	valid_0's binary_logloss: 0.267294
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [1915]	valid_0's binary_logloss: 0.267294
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [1916]	valid_0's binary_logloss: 0.267283
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [1917]	valid_0's binary_logloss: 0.267275
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [1918]	valid_0's binary_logloss: 0.267273
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [1919]	valid_0's binary_logloss: 0.267271
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [1920]	valid_0's binary_logloss: 0.267263
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [1921]	valid_0's binary_logloss: 0.267235
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [1922]	valid_0's binary_logloss: 0.267216
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [1923]	valid_0's binary_logloss: 0.267211
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [1924]	valid_0's binary_logloss: 0.267207
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [1925]	valid_0's binary_logloss: 0.267205
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [1926]	valid_0's binary_logloss: 0.267208
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [1927]	valid_0's binary_logloss: 0.267201
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [1928]	valid_0's binary_logloss: 0.267195
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [1929]	valid_0's binary_logloss: 0.26719
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [1930]	valid_0's binary_logloss: 0.267185
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [

# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [2000]	valid_0's binary_logloss: 0.266334
# Did not meet early stopping. Best iteration is:
# [2000]	valid_0's binary_logloss: 0.266334

# %%
booster_clf_preds = booster_clf.predict(
    df_test.drop(columns="label"),
    raw_score=True,
)

# %%
roc_auc = roc_auc_score(df_test["label"], booster_clf_preds)
logloss = log_loss(df_test["label"], booster_clf_preds)

print("LightGBM Classifier metrics")
print(f"ROC AUC: {roc_auc}, logloss: {logloss}")
# Out:
# LightGBM Classifier metrics
# ROC AUC: 0.9387817972801997, logloss: 2.964612512312728

# %% [markdown]
# ## LGBMRanker

# %%
# dont want to recompile lightgbm, so must ensure group has less than 10000 queries

df_train_lgb = (
    df_train
    .groupby("user_id", as_index=False)
    .sample(n=10_000, replace=True)
    .drop_duplicates()
    .sort_values(by="user_id")
)
group = df_train_lgb["user_id"].value_counts(sort=False).values

df_val_lgb = (
    df_val
    .groupby("user_id", as_index=False)
    .sample(n=10_000, replace=True)
    .drop_duplicates()
    .sort_values(by="user_id")
)
group_val = df_val_lgb["user_id"].value_counts(sort=False).values
# Out:
# /tmp/ipykernel_31/1118170982.py:5: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   .groupby("user_id", as_index=False)
# /tmp/ipykernel_31/1118170982.py:14: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   .groupby("user_id", as_index=False)

# %%
booster_rnk = LGBMRanker(
    objective="lambdarank",
    max_depth=5,
    learning_rate=1e-1,
    n_estimators=2000,
)

# %%
feature_names = df_train_lgb.columns.difference(["label"]).tolist()

booster_rnk = booster_rnk.fit(
    X=df_train_lgb.drop(columns="label"),
    y=df_train_lgb["label"],
    group=group,
    eval_set=[(df_val_lgb.drop(columns="label"), df_val_lgb["label"])],
    eval_group=[group_val],
    feature_name=feature_names,
    categorical_feature=feature_names,
    callbacks=[lgb.early_stopping(stopping_rounds=10), lgb.log_evaluation()],
    eval_metric="auc",
)
# Out:
# [LightGBM] [Warning] Categorical features with more bins than the configured maximum bin number found.
# [LightGBM] [Warning] For categorical features, max_bin and max_bin_by_feature may be ignored with a large number of categories.
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.059933 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 43399
# [LightGBM] [Info] Number of data points in the train set: 1218503, number of used features: 3
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [1]	valid_0's auc: 0.654493	valid_0's ndcg@1: 0.859303	valid_0's ndcg@2: 0.868233	valid_0's ndcg@3: 0.875496	valid_0's ndcg@4: 0.879837	valid_0's ndcg@5: 0.883231
# Training until validation scores don't improve for 10 rounds
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [2]	valid_0's auc: 0.681099	valid_0's ndcg@1: 0.877182	valid_0's ndcg@2: 0.884895	valid_0's ndcg@3: 0.891829	valid_0's ndcg@4: 0.895354	valid_0's ndcg@5: 0.897747
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [3]	valid_0's auc: 0.699294	valid_0's ndcg@1: 0.888347	valid_0's ndcg@2: 0.895315	valid_0's ndcg@3: 0.900985	valid_0's ndcg@4: 0.90446	valid_0's ndcg@5: 0.906452
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [4]	valid_0's auc: 0.710276	valid_0's ndcg@1: 0.892799	valid_0's ndcg@2: 0.899707	valid_0's ndcg@3: 0.904811	valid_0's ndcg@4: 0.908431	valid_0's ndcg@5: 0.910451
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [5]	valid_0's auc: 0.72028	valid_0's ndcg@1: 0.898382	valid_0's ndcg@2: 0.904332	valid_0's ndcg@3: 0.909408	valid_0's ndcg@4: 0.912796	valid_0's ndcg@5: 0.914885
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [6]	valid_0's auc: 0.729825	valid_0's ndcg@1: 0.902339	valid_0's ndcg@2: 0.907969	valid_0's ndcg@3: 0.91319	valid_0's ndcg@4: 0.916459	valid_0's ndcg@5: 0.918551
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [7]	valid_0's auc: 0.735909	valid_0's ndcg@1: 0.9046	valid_0's ndcg@2: 0.910173	valid_0's ndcg@3: 0.915693	valid_0's ndcg@4: 0.91865	valid_0's ndcg@5: 0.920766
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [8]	valid_0

# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [116]	valid_0's auc: 0.854393	valid_0's ndcg@1: 0.940711	valid_0's ndcg@2: 0.946821	valid_0's ndcg@3: 0.950273	valid_0's ndcg@4: 0.95208	valid_0's ndcg@5: 0.953517
# Early stopping, best iteration is:
# [106]	valid_0's auc: 0.85256	valid_0's ndcg@1: 0.940782	valid_0's ndcg@2: 0.946707	valid_0's ndcg@3: 0.950018	valid_0's ndcg@4: 0.951998	valid_0's ndcg@5: 0.953239

# %%
booster_rnk_preds = booster_rnk.predict(
    df_test.drop(columns="label"),
    raw_score=True,
)

# %%
roc_auc = roc_auc_score(df_test["label"], booster_rnk_preds)
logloss = log_loss(df_test["label"], booster_rnk_preds)

print("LightGBM Ranker metrics")
print(f"ROC AUC: {roc_auc}, logloss: {logloss}")
# Out:
# LightGBM Ranker metrics
# ROC AUC: 0.8492354434477607, logloss: 5.666125678303608

# %% [markdown]
# # DCNv2

# %%
dcnv2_model = DCNv2(
    model_structure="stacked_parallel",
    use_low_rank_mixture=True,
    cross_low_rank_dim=32,
    num_cross_layers=5,
    num_cross_experts=4,
    parallel_hidden_dims=[256, 512, 1024],
    parallel_dropout=0.2,
    parallel_use_batch_norm=True,
    parallel_activation=nn.ReLU,
    stacked_hidden_dims=[256, 512, 1024],
    stacked_dropout=0.2,
    stacked_use_batch_norm=True,
    stacked_activation=nn.ReLU,
    output_dim=1,
    proj_output_embeddings=True,
)

# %%
train_metrics_dcnv2, val_metrics_dcnv2 = dcnv2_model.fit(
    features=df_train.drop(columns="label"),
    target=df_train["label"],
    val_features=df_val.drop(columns="label"),
    val_target=df_val["label"],
    optimizer_cls="torch.optim.Adam",
    optimizer_params=dict(lr=1e-3),
    scheduler_cls="torch.optim.lr_scheduler.ReduceLROnPlateau",
    scheduler_params=dict(mode="max", factor=0.1, patience=2, min_lr=1e-6),
    grad_clip_threshold=10.,
    num_epochs=10,
    seed=42,
    artifacts_path="./dcnv2_artifacts",
    device="cuda:0",
    batch_size=4096,
    num_workers=2,
    eval_metric_name="AUC",
    eval_mode="max",
    embedded_features=["user_id", "item_id", "tag_id"],
    default_embedding_size=64,
    oov_masking_proba=0.05,
    l2_net_reg=0,
    l2_embedding_reg=0,
)
# Out:
# [2025-05-03 22:21:44,116]{model.py:660} - INFO - Used features config: FeaturesConfig(features=[Feature(name='user_id', feature_type=<FeatureType.CATEGORICAL: 'categorical'>, feature_size=1, needs_embed=True, embedding_size=64, embedding_vocab_size=16976, embedding_padding_idx=None), Feature(name='item_id', feature_type=<FeatureType.CATEGORICAL: 'categorical'>, feature_size=1, needs_embed=True, embedding_size=64, embedding_vocab_size=23605, embedding_padding_idx=None), Feature(name='tag_id', feature_type=<FeatureType.CATEGORICAL: 'categorical'>, feature_size=1, needs_embed=True, embedding_size=64, embedding_vocab_size=49658, embedding_padding_idx=None)])
# [2025-05-03 22:21:47,298]{model.py:675} - INFO - Artifacts path is /kaggle/working/dcnv2_artifacts
# [2025-05-03 22:21:47,299]{model.py:677} - INFO - Creating artifacts path
# [2025-05-03 22:21:47,300]{model.py:681} - INFO - Best model path is dcnv2_artifacts/best_model.pt
# [2025-05-03 22:21:47,616]{model.py:686} - INFO - Building features mappings
# [2025-05-03 22:21:47,617]{model.py:272} - INFO - Building mapping for feature user_id
# [2025-05-03 22:21:47,629]{model.py:272} - INFO - Building mapping for feature item_id
# [2025-05-03 22:21:47,641]{model.py:272} - INFO - Building mapping for feature tag_id
# [2025-05-03 22:21:47,656]{model.py:689} - INFO - Building train dataloader
# [2025-05-03 22:21:47,659]{model.py:297} - INFO - Encoding feature user_id
# [2025-05-03 22:21:47,689]{model.py:297} - INFO - Encoding feature item_id
# [2025-05-03 22:21:47,719]{model.py:297} - INFO - Encoding feature tag_id
# [2025-05-03 22:21:47,763]{model.py:702} - INFO - Building validation dataloader
# [2025-05-03 22:21:47,765]{model.py:297} - INFO - Encoding feature user_id
# [2025-05-03 22:21:47,782]{model.py:297} - INFO - Encoding feature item_id
# [2025-05-03 22:21:47,799]{model.py:297} - INFO - Encoding feature tag_id
# [2025-05-03 22:21:47,828]{model.py:712} - INFO - Starting training process
# Train epoch #0:   0%|          | 0/343 [00:00<?, ?it/s]
# [2025-05-03 22:23:05,842]{model.py:567} - INFO - Finished Train Epoch #0, average metrics - [loss: 0.47479]
# Validation epoch #0:   0%|          | 0/98 [00:00<?, ?it/s]
# [2025-05-03 22:23:15,082]{model.py:567} - INFO - Finished Validation Epoch #0, average metrics - [AUC: 0.88930, log_loss: 0.34868]
# [2025-05-03 22:23:25,561]{model.py:747} - INFO - Best model with AUC = 0.8893002081617837 was saved to dcnv2_artifacts/best_model.pt
# Train epoch #1:   0%|          | 0/343 [00:00<?, ?it/s]
# [2025-05-03 22:24:41,749]{model.py:567} - INFO - Finished Train Epoch #1, average metrics - [loss: 0.34255]
# Validation epoch #1:   0%|          | 0/98 [00:00<?, ?it/s]
# [2025-05-03 22:25:01,027]{model.py:567} - INFO - Finished Validation Epoch #1, average metrics - [AUC: 0.91561, log_loss: 0.31087]
# [2025-05-03 22:25:11,549]{model.py:747} - INFO - Best model with AUC = 0.9156107340890131 was saved to dcnv2_artifacts/best_model.pt
# Train epoch #2:   0%|          | 0/343 [00:00<?, ?it/s]
# [2025-05-03 22:26:30,029]{model.py:567} - INFO - Finished Train Epoch #2, average metrics - [loss: 0.30934]
# Validation epoch #2:   0%|          | 0/98 [00:00<?, ?it/s]
# [2025-05-03 22:26:49,357]{model.py:567} - INFO - Finished Validation Epoch #2, average metrics - [AUC: 0.92616, log_loss: 0.29679]
# [2025-05-03 22:26:59,861]{model.py:747} - INFO - Best model with AUC = 0.9261597124266459 was saved to dcnv2_artifacts/best_model.pt
# Train epoch #3:   0%|          | 0/343 [00:00<?, ?it/s]
# [2025-05-03 22:28:16,285]{model.py:567} - INFO - Finished Train Epoch #3, average metrics - [loss: 0.28822]
# Validation epoch #3:   0%|          | 0/98 [00:00<?, ?it/s]
# [2025-05-03 22:28:35,558]{model.py:567} - INFO - Finished Validation Epoch #3, average metrics - [AUC: 0.93185, log_loss: 0.28971]
# [2025-05-03 22:28:46,082]{model.py:747} - INFO - Best model with AUC = 0.9318497509745438 was saved to dcnv2_artifacts/best_model.pt
# Train epoch #4:   0%|          | 0/343 [00:00<?, ?it/s]
# [2025-05-03 22:30:03,279]{model.py:567} - INFO - Finished Train Epoch #4, average metrics - [loss: 0.26914]
# Validation epoch #4:   0%|          | 0/98 [00:00<?, ?it/s]
# [2025-05-03 22:30:22,555]{model.py:567} - INFO - Finished Validation Epoch #4, average metrics - [AUC: 0.93508, log_loss: 0.28558]
# [2025-05-03 22:30:33,056]{model.py:747} - INFO - Best model with AUC = 0.9350827802885244 was saved to dcnv2_artifacts/best_model.pt
# Train epoch #5:   0%|          | 0/343 [00:00<?, ?it/s]
# [2025-05-03 22:31:50,242]{model.py:567} - INFO - Finished Train Epoch #5, average metrics - [loss: 0.25056]
# Validation epoch #5:   0%|          | 0/98 [00:00<?, ?it/s]
# [2025-05-03 22:32:09,505]{model.py:567} - INFO - Finished Validation Epoch #5, average metrics - [AUC: 0.93721, log_loss: 0.28390]
# [2025-05-03 22:32:20,022]{model.py:747} - INFO - Best model with AUC = 0.9372142220420207 was saved to dcnv2_artifacts/best_model.pt
# Train epoch #6:   0%|          | 0/343 [00:00<?, ?it/s]
# [2025-05-03 22:33:38,925]{model.py:567} - INFO - Finished Train Epoch #6, average metrics - [loss: 0.23154]
# Validation epoch #6:   0%|          | 0/98 [00:00<?, ?it/s]
# [2025-05-03 22:33:58,249]{model.py:567} - INFO - Finished Validation Epoch #6, average metrics - [AUC: 0.93827, log_loss: 0.28757]
# [2025-05-03 22:34:08,752]{model.py:747} - INFO - Best model with AUC = 0.9382730505053614 was saved to dcnv2_artifacts/best_model.pt
# Train epoch #7:   0%|          | 0/343 [00:00<?, ?it/s]
# [2025-05-03 22:35:27,232]{model.py:567} - INFO - Finished Train Epoch #7, average metrics - [loss: 0.21350]
# Validation epoch #7:   0%|          | 0/98 [00:00<?, ?it/s]
# [2025-05-03 22:35:46,531]{model.py:567} - INFO - Finished Validation Epoch #7, average metrics - [AUC: 0.93852, log_loss: 0.29525]
# [2025-05-03 22:35:57,024]{model.py:747} - INFO - Best model with AUC = 0.9385228988706931 was saved to dcnv2_artifacts/best_model.pt
# Train epoch #8:   0%|          | 0/343 [00:00<?, ?it/s]
# [2025-05-03 22:37:14,533]{model.py:567} - INFO - Finished Train Epoch #8, average metrics - [loss: 0.19641]
# Validation epoch #8:   0%|          | 0/98 [00:00<?, ?it/s]
# [2025-05-03 22:37:34,274]{model.py:567} - INFO - Finished Validation Epoch #8, average metrics - [AUC: 0.93857, log_loss: 0.30407]
# [2025-05-03 22:37:44,776]{model.py:747} - INFO - Best model with AUC = 0.9385710490776249 was saved to dcnv2_artifacts/best_model.pt
# Train epoch #9:   0%|          | 0/343 [00:00<?, ?it/s]
# [2025-05-03 22:39:03,031]{model.py:567} - INFO - Finished Train Epoch #9, average metrics - [loss: 0.17956]
# Validation epoch #9:   0%|          | 0/98 [00:00<?, ?it/s]
# [2025-05-03 22:39:22,500]{model.py:567} - INFO - Finished Validation Epoch #9, average metrics - [AUC: 0.93843, log_loss: 0.31329]
# [2025-05-03 22:39:32,907]{model.py:763} - INFO - Loading best model from dcnv2_artifacts/best_model.pt

# %%
test_metrics_dcnv2 = dcnv2_model.test(
    features=df_test.drop(columns="label"),
    target=df_test["label"],
    device="cuda:0",
    batch_size=4096,
    num_workers=2,
)
test_metrics_dcnv2
# Out:
# [2025-05-03 22:39:32,988]{model.py:789} - INFO - Building test dataloader
# [2025-05-03 22:39:32,992]{model.py:297} - INFO - Encoding feature user_id
# [2025-05-03 22:39:33,016]{model.py:297} - INFO - Encoding feature item_id
# [2025-05-03 22:39:33,041]{model.py:297} - INFO - Encoding feature tag_id
# Test epoch #-1:   0%|          | 0/49 [00:00<?, ?it/s]
# [2025-05-03 22:39:38,315]{model.py:567} - INFO - Finished Test Epoch #-1, average metrics - [AUC: 0.93801, log_loss: 0.30535]
# {'AUC': 0.9380089869168355, 'log_loss': 0.30535252850359723}

# %% [markdown]
# # FinalNet

# %%
finalnet_model = FinalNet(
    block_type="2B",
    use_field_gate=True,
    use_batch_norm=True,
    add_bias=True,
    block1_hidden_dims=[256, 512, 1024],
    block1_hidden_activations=nn.ReLU,
    block1_dropout_rates=0.2,
    block2_hidden_dims=[256, 512, 1024],
    block2_hidden_activations=nn.ReLU,
    block2_dropout_rates=0.2,
    residual_type="concat",
    proj_output_embeddings=True,
)

# %%
train_metrics_final, val_metrics_final = finalnet_model.fit(
    features=df_train.drop(columns="label"),
    target=df_train["label"],
    val_features=df_val.drop(columns="label"),
    val_target=df_val["label"],
    optimizer_cls="torch.optim.Adam",
    optimizer_params=dict(lr=1e-3),
    scheduler_cls="torch.optim.lr_scheduler.ReduceLROnPlateau",
    scheduler_params=dict(mode="max", factor=0.1, patience=2, min_lr=1e-6),
    grad_clip_threshold=10.,
    num_epochs=10,
    seed=42,
    artifacts_path="./finalnet_artifacts",
    device="cuda:0",
    batch_size=4096,
    num_workers=2,
    eval_metric_name="AUC",
    eval_mode="max",
    embedded_features=["user_id", "item_id", "tag_id"],
    oov_masking_proba=0.05,
    default_embedding_size=64, # should be equal for all features if using field gate
    l2_net_reg=0.,
    l2_embedding_reg=0,
)
# Out:
# [2025-05-03 22:50:49,224]{model.py:660} - INFO - Used features config: FeaturesConfig(features=[Feature(name='user_id', feature_type=<FeatureType.CATEGORICAL: 'categorical'>, feature_size=1, needs_embed=True, embedding_size=64, embedding_vocab_size=16976, embedding_padding_idx=None), Feature(name='item_id', feature_type=<FeatureType.CATEGORICAL: 'categorical'>, feature_size=1, needs_embed=True, embedding_size=64, embedding_vocab_size=23605, embedding_padding_idx=None), Feature(name='tag_id', feature_type=<FeatureType.CATEGORICAL: 'categorical'>, feature_size=1, needs_embed=True, embedding_size=64, embedding_vocab_size=49658, embedding_padding_idx=None)])
# [2025-05-03 22:50:49,227]{model.py:675} - INFO - Artifacts path is /kaggle/working/finalnet_artifacts
# [2025-05-03 22:50:49,227]{model.py:681} - INFO - Best model path is finalnet_artifacts/best_model.pt
# [2025-05-03 22:50:49,237]{model.py:686} - INFO - Building features mappings
# [2025-05-03 22:50:49,237]{model.py:272} - INFO - Building mapping for feature user_id
# [2025-05-03 22:50:49,249]{model.py:272} - INFO - Building mapping for feature item_id
# [2025-05-03 22:50:49,262]{model.py:272} - INFO - Building mapping for feature tag_id
# [2025-05-03 22:50:49,278]{model.py:689} - INFO - Building train dataloader
# [2025-05-03 22:50:49,282]{model.py:297} - INFO - Encoding feature user_id
# [2025-05-03 22:50:49,318]{model.py:297} - INFO - Encoding feature item_id
# [2025-05-03 22:50:49,352]{model.py:297} - INFO - Encoding feature tag_id
# [2025-05-03 22:50:49,401]{model.py:702} - INFO - Building validation dataloader
# [2025-05-03 22:50:49,403]{model.py:297} - INFO - Encoding feature user_id
# [2025-05-03 22:50:49,419]{model.py:297} - INFO - Encoding feature item_id
# [2025-05-03 22:50:49,438]{model.py:297} - INFO - Encoding feature tag_id
# [2025-05-03 22:50:49,467]{model.py:712} - INFO - Starting training process
# Train epoch #0:   0%|          | 0/343 [00:00<?, ?it/s]
# [2025-05-03 22:52:05,594]{model.py:567} - INFO - Finished Train Epoch #0, average metrics - [loss: 0.48856]
# Validation epoch #0:   0%|          | 0/98 [00:00<?, ?it/s]
# [2025-05-03 22:52:14,275]{model.py:567} - INFO - Finished Validation Epoch #0, average metrics - [AUC: 0.88632, log_loss: 0.35258]
# [2025-05-03 22:52:24,789]{model.py:747} - INFO - Best model with AUC = 0.8863208422165121 was saved to finalnet_artifacts/best_model.pt
# Train epoch #1:   0%|          | 0/343 [00:00<?, ?it/s]
# [2025-05-03 22:53:40,308]{model.py:567} - INFO - Finished Train Epoch #1, average metrics - [loss: 0.34778]
# Validation epoch #1:   0%|          | 0/98 [00:00<?, ?it/s]
# [2025-05-03 22:53:59,336]{model.py:567} - INFO - Finished Validation Epoch #1, average metrics - [AUC: 0.91738, log_loss: 0.30707]
# [2025-05-03 22:54:09,851]{model.py:747} - INFO - Best model with AUC = 0.9173769994567224 was saved to finalnet_artifacts/best_model.pt
# Train epoch #2:   0%|          | 0/343 [00:00<?, ?it/s]
# [2025-05-03 22:55:26,048]{model.py:567} - INFO - Finished Train Epoch #2, average metrics - [loss: 0.31334]
# Validation epoch #2:   0%|          | 0/98 [00:00<?, ?it/s]
# [2025-05-03 22:55:44,841]{model.py:567} - INFO - Finished Validation Epoch #2, average metrics - [AUC: 0.92697, log_loss: 0.29233]
# [2025-05-03 22:55:55,360]{model.py:747} - INFO - Best model with AUC = 0.9269715051551158 was saved to finalnet_artifacts/best_model.pt
# Train epoch #3:   0%|          | 0/343 [00:00<?, ?it/s]
# [2025-05-03 22:57:12,426]{model.py:567} - INFO - Finished Train Epoch #3, average metrics - [loss: 0.29422]
# Validation epoch #3:   0%|          | 0/98 [00:00<?, ?it/s]
# [2025-05-03 22:57:31,200]{model.py:567} - INFO - Finished Validation Epoch #3, average metrics - [AUC: 0.93201, log_loss: 0.28601]
# [2025-05-03 22:57:41,735]{model.py:747} - INFO - Best model with AUC = 0.932008322176752 was saved to finalnet_artifacts/best_model.pt
# Train epoch #4:   0%|          | 0/343 [00:00<?, ?it/s]
# [2025-05-03 22:58:58,238]{model.py:567} - INFO - Finished Train Epoch #4, average metrics - [loss: 0.27861]
# Validation epoch #4:   0%|          | 0/98 [00:00<?, ?it/s]
# [2025-05-03 22:59:17,018]{model.py:567} - INFO - Finished Validation Epoch #4, average metrics - [AUC: 0.93523, log_loss: 0.28202]
# [2025-05-03 22:59:27,531]{model.py:747} - INFO - Best model with AUC = 0.9352298550373609 was saved to finalnet_artifacts/best_model.pt
# Train epoch #5:   0%|          | 0/343 [00:00<?, ?it/s]
# [2025-05-03 23:00:43,734]{model.py:567} - INFO - Finished Train Epoch #5, average metrics - [loss: 0.26512]
# Validation epoch #5:   0%|          | 0/98 [00:00<?, ?it/s]
# [2025-05-03 23:01:02,588]{model.py:567} - INFO - Finished Validation Epoch #5, average metrics - [AUC: 0.93742, log_loss: 0.28346]
# [2025-05-03 23:01:13,111]{model.py:747} - INFO - Best model with AUC = 0.9374223890363187 was saved to finalnet_artifacts/best_model.pt
# Train epoch #6:   0%|          | 0/343 [00:00<?, ?it/s]
# [2025-05-03 23:02:29,274]{model.py:567} - INFO - Finished Train Epoch #6, average metrics - [loss: 0.25302]
# Validation epoch #6:   0%|          | 0/98 [00:00<?, ?it/s]
# [2025-05-03 23:02:47,969]{model.py:567} - INFO - Finished Validation Epoch #6, average metrics - [AUC: 0.93867, log_loss: 0.28150]
# [2025-05-03 23:02:58,507]{model.py:747} - INFO - Best model with AUC = 0.938673443635399 was saved to finalnet_artifacts/best_model.pt
# Train epoch #7:   0%|          | 0/343 [00:00<?, ?it/s]
# [2025-05-03 23:04:14,620]{model.py:567} - INFO - Finished Train Epoch #7, average metrics - [loss: 0.24111]
# Validation epoch #7:   0%|          | 0/98 [00:00<?, ?it/s]
# [2025-05-03 23:04:33,624]{model.py:567} - INFO - Finished Validation Epoch #7, average metrics - [AUC: 0.93984, log_loss: 0.28443]
# [2025-05-03 23:04:44,137]{model.py:747} - INFO - Best model with AUC = 0.9398425484006653 was saved to finalnet_artifacts/best_model.pt
# Train epoch #8:   0%|          | 0/343 [00:00<?, ?it/s]
# [2025-05-03 23:06:01,448]{model.py:567} - INFO - Finished Train Epoch #8, average metrics - [loss: 0.22975]
# Validation epoch #8:   0%|          | 0/98 [00:00<?, ?it/s]
# [2025-05-03 23:06:20,594]{model.py:567} - INFO - Finished Validation Epoch #8, average metrics - [AUC: 0.94060, log_loss: 0.28852]
# [2025-05-03 23:06:31,126]{model.py:747} - INFO - Best model with AUC = 0.9406039642532047 was saved to finalnet_artifacts/best_model.pt
# Train epoch #9:   0%|          | 0/343 [00:00<?, ?it/s]
# [2025-05-03 23:07:46,860]{model.py:567} - INFO - Finished Train Epoch #9, average metrics - [loss: 0.21908]
# Validation epoch #9:   0%|          | 0/98 [00:00<?, ?it/s]
# [2025-05-03 23:08:05,692]{model.py:567} - INFO - Finished Validation Epoch #9, average metrics - [AUC: 0.94129, log_loss: 0.29179]
# [2025-05-03 23:08:16,221]{model.py:747} - INFO - Best model with AUC = 0.9412890242553024 was saved to finalnet_artifacts/best_model.pt
# [2025-05-03 23:08:16,222]{model.py:763} - INFO - Loading best model from finalnet_artifacts/best_model.pt

# %%
test_metrics_final = finalnet_model.test(
    features=df_test.drop(columns="label"),
    target=df_test["label"],
    device="cuda:0",
    batch_size=4096,
    num_workers=2,
)
test_metrics_final
# Out:
# [2025-05-03 23:08:54,873]{model.py:789} - INFO - Building test dataloader
# [2025-05-03 23:08:54,876]{model.py:297} - INFO - Encoding feature user_id
# [2025-05-03 23:08:54,903]{model.py:297} - INFO - Encoding feature item_id
# [2025-05-03 23:08:54,925]{model.py:297} - INFO - Encoding feature tag_id
# Test epoch #-1:   0%|          | 0/49 [00:00<?, ?it/s]
# [2025-05-03 23:08:59,488]{model.py:567} - INFO - Finished Test Epoch #-1, average metrics - [AUC: 0.94116, log_loss: 0.29209]
# {'AUC': 0.9411648940751596, 'log_loss': 0.29209004007438505}
