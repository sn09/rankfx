# %%
# !git clone https://github.com/sn09/ranking.git
# Out:
# Cloning into 'ranking'...
# remote: Enumerating objects: 342, done.
# remote: Counting objects: 100% (342/342), done.
# remote: Compressing objects: 100% (198/198), done.
# remote: Total 342 (delta 166), reused 286 (delta 119), pack-reused 0 (from 0)
# Receiving objects: 100% (342/342), 169.45 KiB | 3.20 MiB/s, done.
# Resolving deltas: 100% (166/166), done.

# %%
import sys

import lightgbm as lgb
import numpy as np
import pandas as pd
from lightgbm import LGBMClassifier, LGBMRanker
from sklearn.metrics import log_loss, roc_auc_score
from torch import nn

sys.path.append("./ranking/models/")

from rankfx.dcnv2.model import DCNv2
from rankfx.finalnet.model import FinalNet

# %%
base_path = "/kaggle/input/kkbox-x1"

df_train = pd.read_csv(f"{base_path}/train.csv")
df_test = pd.read_csv(f"{base_path}/test.csv")
df_val = pd.read_csv(f"{base_path}/valid.csv")

df_train.head()
# Out:
#    label   msno  song_id source_system_tab   source_screen_name  \
# 0      1   2972   298350        my library  Local playlist more
# 1      1  31472   684399        my library  Local playlist more
# 2      1   1238   552192        my library  Local playlist more
# 3      1   1238   994686        my library  Local playlist more
# 4      1   6871  1631708        my library  Local playlist more
#
#       source_type  city  bd  gender  registered_via  registration_init_time  \
# 0   local-library     5   0     NaN               9                20110221
# 1   local-library     9  27  female               9                20130912
# 2  local-playlist     1   0     NaN               7                20130925
# 3  local-playlist     1   0     NaN               7                20130925
# 4   local-library    13  28    male               3                20140626
#
#    expiration_date  song_length genre_ids artist_name  \
# 0         20170922     240624.0       465      444553
# 1         20170912     247911.0       465      506764
# 2         20171001     261224.0       465      507689
# 3         20171001     227343.0       465      508873
# 4         20170913     121858.0       921      444553
#
#                                             composer       lyricist  language  \
# 0                                             149542  206321 364176      31.0
# 1                                             391787         497352       3.0
# 2                                             507689         507689       3.0
# 3                                             346049         346049       3.0
# 4  225688 331823 77958 336148 209890 450162 25980...            NaN      52.0
#
#       name          isrc
# 0   975794           NaN
# 1  1082967  TWA470326002
# 2  1111889  CNA651500229
# 3  1141245  TWA531657203
# 4   967217  USUM71504649

# %%
from sklearn.preprocessing import StandardScaler


cols_to_delete = [
    "isrc",
    "name",
    "lyricist",
    "composer",
    "expiration_date",
    "registration_init_time",
]
feature_columns = df_train.columns.difference([*cols_to_delete, "label"])


num_features = ["song_length"]
cat_features = feature_columns.difference(num_features).tolist()
for df in [df_train, df_val, df_test]:
    df.drop(columns=cols_to_delete, inplace=True)
    df[cat_features] = df[cat_features].fillna("__NONE__").astype("category")
    df[num_features] = df[num_features].fillna(-1)


scaler = StandardScaler()
df_train[num_features] = scaler.fit_transform(df_train[num_features])
df_val[num_features] = scaler.transform(df_val[num_features])
df_test[num_features] = scaler.transform(df_test[num_features])

# %% [markdown]
# # LightGBM

# %% [markdown]
# ## LGBMClassifier

# %%
booster_clf = LGBMClassifier(
    objective="binary",
    max_depth=5,
    learning_rate=1e-1,
    n_estimators=1000,
)

# %%
feature_names = df_train.columns.difference(["label"]).tolist()

booster_clf = booster_clf.fit(
    X=df_train.drop(columns="label"),
    y=df_train["label"],
    eval_set=(df_val.drop(columns="label"), df_val["label"]),
    feature_name=df_train.drop(columns="label").columns.tolist(),
    categorical_feature=cat_features,
    callbacks=[lgb.early_stopping(stopping_rounds=10), lgb.log_evaluation()],
)
# Out:
# [LightGBM] [Warning] Categorical features with more bins than the configured maximum bin number found.
# [LightGBM] [Warning] For categorical features, max_bin and max_bin_by_feature may be ignored with a large number of categories.
# [LightGBM] [Info] Number of positive: 2971724, number of negative: 2930208
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.124494 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 34133
# [LightGBM] [Info] Number of data points in the train set: 5901932, number of used features: 13
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.503517 -> initscore=0.014069
# [LightGBM] [Info] Start training from score 0.014069
# [1]	valid_0's binary_logloss: 0.68428
# Training until validation scores don't improve for 10 rounds
# [2]	valid_0's binary_logloss: 0.677072
# [3]	valid_0's binary_logloss: 0.671092
# [4]	valid_0's binary_logloss: 0.666161
# [5]	valid_0's binary_logloss: 0.661932
# [6]	valid_0's binary_logloss: 0.658358
# [7]	valid_0's binary_logloss: 0.655377
# [8]	valid_0's binary_logloss: 0.652704
# [9]	valid_0's binary_logloss: 0.650466
# [10]	valid_0's binary_logloss: 0.648557
# [11]	valid_0's binary_logloss: 0.646831
# [12]	valid_0's binary_logloss: 0.645249
# [13]	valid_0's binary_logloss: 0.643808
# [14]	valid_0's binary_logloss: 0.64251
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [15]	valid_0's binary_logloss: 0.641353
# [16]	valid_0's binary_logloss: 0.640244
# [17]	valid_0's binary_logloss: 0.63937
# [18]	valid_0's binary_logloss: 0.63843
# [19]	valid_0's binary_logloss: 0.637662
# [20]	valid_0's binary_logloss: 0.63692
# [21]	valid_0's binary_logloss: 0.636358
# [22]	valid_0's binary_logloss: 0.635539
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [23]	valid_0's binary_logloss: 0.63493
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [24]	valid_0's binary_logloss: 0.63449
# [25]	valid_0's binary_logloss: 0.633817
# [26]	valid_0's binary_logloss: 0.633264
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [27]	valid_0's binary_logloss: 0.632645
# [28]	valid_0's binary_logloss: 0.632032
# [29]	valid_0's binary_logloss: 0.631667
# [30]	valid_0's binary_logloss: 0.631218
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [31]	valid_0's binary_logloss: 0.630798
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [32]	valid_0's binary_logloss: 0.630391
# [33]	valid_0's binary_logloss: 0.629854
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [34]	valid_0's binary_logloss: 0.629641
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [35]	valid_0's binary_logloss: 0.629444
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [36]	valid_0's binary_logloss: 0.629094
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [37]	valid_0's binary_logloss: 0.628881
# [38]	valid_0's binary_logloss: 0.628634
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [39]	valid_0's binary_logloss: 0.628402
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [40]	valid_0's binary_logloss: 0.628205
# [41]	valid_0's binary_logloss: 0.627951
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [42]	valid_0's binary_logloss: 0.627765
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [43]	valid_0's binary_logloss: 0.627577
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [44]	valid_0's binary_logloss: 0.627385
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [45]	valid_0's binary_logloss: 0.627191
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [46]	valid_0's binary_logloss: 0.627023
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [47]	valid_0's binary_logloss: 0.626754
# [48]	valid_0's binary_logloss: 0.626501
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [49]	valid_0's binary_logloss: 0.626313
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [50]	valid_0's binary_logloss: 0.62609
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [51]	valid_0's binary_logloss: 0.625929
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [52]	valid_0's binary_logloss: 0.625757
# [53]	valid_0's binary_logloss: 0.625419
# [54]	valid_0's binary_logloss: 0.624878
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [55]	valid_0's binary_logloss: 0.624717
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [56]	valid_0's binary_logloss: 0.624556
# [57]	valid_0's binary_logloss: 0.624389
# [58]	valid_0's binary_logloss: 0.624223
# [59]	valid_0's binary_logloss: 0.624059
# [60]	valid_0's binary_logloss: 0.623792
# [61]	valid_0's binary_logloss: 0.623572
# [62]	valid_0's binary_logloss: 0.623389
# [63]	valid_0's binary_logloss: 0.623246
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [64]	valid_0's binary_logloss: 0.623093
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [65]	valid_0's binary_logloss: 0.622937
# [66]	valid_0's binary_logloss: 0.622699
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [67]	valid_0's binary_logloss: 0.622551
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [68]	valid_0's binary_logloss: 0.622418
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [69]	valid_0's binary_logloss: 0.622177
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [70]	valid_0's binary_logloss: 0.62199
# [71]	valid_0's binary_logloss: 0.621859
# [72]	valid_0's binary_logloss: 0.621713
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [73]	valid_0's binary_logloss: 0.621567
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [74]	valid_0's binary_logloss: 0.621429
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [75]	valid_0's binary_logloss: 0.621297
# [76]	valid_0's binary_logloss: 0.621141
# [77]	valid_0's binary_logloss: 0.621001
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [78]	valid_0's binary_logloss: 0.620867
# [79]	valid_0's binary_logloss: 0.620725
# [80]	valid_0's binary_logloss: 0.620588
# [81]	valid_0's binary_logloss: 0.620454
# [82]	valid_0's binary_logloss: 0.620325
# [83]	valid_0's binary_logloss: 0.620175
# [84]	valid_0's binary_logloss: 0.619746
# [85]	valid_0's binary_logloss: 0.619612
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [86]	valid_0's binary_logloss: 0.619491
# [87]	valid_0's binary_logloss: 0.619364
# [88]	valid_0's binary_logloss: 0.619256
# [89]	valid_0's binary_logloss: 0.619011
# [90]	valid_0's binary_logloss: 0.618729
# [91]	valid_0's binary_logloss: 0.618606
# [92]	valid_0's binary_logloss: 0.618486
# [93]	valid_0's binary_logloss: 0.618377
# [94]	valid_0's binary_logloss: 0.618244
# [95]	valid_0's binary_logloss: 0.618121
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [96]	valid_0's binary_logloss: 0.618012
# [97]	valid_0's binary_logloss: 0.617899
# [98]	valid_0's binary_logloss: 0.617785
# [99]	valid_0's binary_logloss: 0.617667
# [100]	valid_0's binary_logloss: 0.617565
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [101]	valid_0's binary_logloss: 0.61746
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [102]	valid_0's binary_logloss: 0.617353
# [103]	valid_0's binary_logloss: 0.617255
# [104]	valid_0's binary_logloss: 0.61714
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [105]	valid_0's binary_logloss: 0.616911
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [106]	valid_0's binary_logloss: 0.616708
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [107]	valid_0's binary_logloss: 0.6166
# [108]	valid_0's binary_logloss: 0.616478
# [109]	valid_0's binary_logloss: 0.61636
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [110]	valid_0's binary_logloss: 0.616241
# [111]	valid_0's binary_logloss: 0.616118
# [112]	valid_0's binary_logloss: 0.616008
# [113]	valid_0's binary_logloss: 0.615881
# [114]	valid_0's binary_logloss: 0.615757
# [115]	valid_0's binary_logloss: 0.615651
# [116]	valid_0's binary_logloss: 0.615546
# [117]	valid_0's binary_logloss: 0.61543
# [118]	valid_0's binary_logloss: 0.615323
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [119]	valid_0's binary_logloss: 0.615219
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [120]	valid_0's binary_logloss: 0.615106
# [121]	valid_0's binary_logloss: 0.614998
# [122]	valid_0's binary_logloss: 0.614853
# [123]	valid_0's binary_logloss: 0.61476
# [124]	valid_0's binary_logloss: 0.614647
# [125]	valid_0's binary_logloss: 0.614541
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [126]	valid_0's binary_logloss: 0.614427
# [127]	valid_0's binary_logloss: 0.614325
# [128]	valid_0's binary_logloss: 0.614211
# [129]	valid_0's binary_logloss: 0.614033
# [130]	valid_0's binary_logloss: 0.613913
# [131]	valid_0's binary_logloss: 0.613817
# [132]	valid_0's binary_logloss: 0.613678
# [133]	valid_0's binary_logloss: 0.61355
# [134]	valid_0's binary_logloss: 0.613448
# [135]	valid_0's binary_logloss: 0.61335
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [136]	valid_0's binary_logloss: 0.613228
# [137]	valid_0's binary_logloss: 0.61313
# [138]	valid_0's binary_logloss: 0.612826
# [139]	valid_0's binary_logloss: 0.612734
# [140]	valid_0's binary_logloss: 0.612575
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [141]	valid_0's binary_logloss: 0.612485
# [142]	valid_0's binary_logloss: 0.612382
# [143]	valid_0's binary_logloss: 0.612285
# [144]	valid_0's binary_logloss: 0.612203
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [145]	valid_0's binary_logloss: 0.612122
# [146]	valid_0's binary_logloss: 0.612021
# [147]	valid_0's binary_logloss: 0.611924
# [148]	valid_0's binary_logloss: 0.611828
# [149]	valid_0's binary_logloss: 0.611733
# [150]	valid_0's binary_logloss: 0.611633
# [151]	valid_0's binary_logloss: 0.611546
# [152]	valid_0's binary_logloss: 0.611457
# [153]	valid_0's binary_logloss: 0.611359
# [154]	valid_0's binary_logloss: 0.611243
# [155]	valid_0's binary_logloss: 0.611149
# [156]	valid_0's binary_logloss: 0.611057
# [157]	valid_0's binary_logloss: 0.61097
# [158]	valid_0's binary_logloss: 0.61084
# [159]	valid_0's binary_logloss: 0.610767
# [160]	valid_0's binary_logloss: 0.610523
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [161]	valid_0's binary_logloss: 0.610427
# [162]	valid_0's binary_logloss: 0.610342
# [163]	valid_0's binary_logloss: 0.610257
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [164]	valid_0's binary_logloss: 0.610167
# [165]	valid_0's binary_logloss: 0.610092
# [166]	valid_0's binary_logloss: 0.61
# [167]	valid_0's binary_logloss: 0.60991
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [168]	valid_0's binary_logloss: 0.609833
# [169]	valid_0's binary_logloss: 0.609749
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [170]	valid_0's binary_logloss: 0.609652
# [171]	valid_0's binary_logloss: 0.609567
# [172]	valid_0's binary_logloss: 0.609483
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [173]	valid_0's binary_logloss: 0.6094
# [174]	valid_0's binary_logloss: 0.609305
# [175]	valid_0's binary_logloss: 0.609217
# [176]	valid_0's binary_logloss: 0.609127
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [177]	valid_0's binary_logloss: 0.609045
# [178]	valid_0's binary_logloss: 0.608961
# [179]	valid_0's binary_logloss: 0.608881
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [180]	valid_0's binary_logloss: 0.608799
# [181]	valid_0's binary_logloss: 0.608727
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [182]	valid_0's binary_logloss: 0.608617
# [183]	valid_0's binary_logloss: 0.608521
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [184]	valid_0's binary_logloss: 0.608419
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [185]	valid_0's binary_logloss: 0.608322
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [186]	valid_0's binary_logloss: 0.608234
# [187]	valid_0's binary_logloss: 0.608143
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [188]	valid_0's binary_logloss: 0.608061
# [189]	valid_0's binary_logloss: 0.607864
# [190]	valid_0's binary_logloss: 0.607783
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [191]	valid_0's binary_logloss: 0.607708
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [192]	valid_0's binary_logloss: 0.607638
# [193]	valid_0's binary_logloss: 0.607543
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [194]	valid_0's binary_logloss: 0.607466
# [195]	valid_0's binary_logloss: 0.607375
# [196]	valid_0's binary_logloss: 0.607286
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [197]	valid_0's binary_logloss: 0.607188
# [198]	valid_0's binary_logloss: 0.6071
# [199]	valid_0's binary_logloss: 0.60702
# [200]	valid_0's binary_logloss: 0.606936
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [201]	valid_0's binary_logloss: 0.606855
# [202]	valid_0's binary_logloss: 0.606769
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [203]	valid_0's binary_logloss: 0.606688
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [204]	valid_0's binary_logloss: 0.606596
# [205]	valid_0's binary_logloss: 0.606527
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [206]	valid_0's binary_logloss: 0.606454
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [207]	valid_0's binary_logloss: 0.606375
# [208]	valid_0's binary_logloss: 0.606298
# [209]	valid_0's binary_logloss: 0.606221
# [210]	valid_0's binary_logloss: 0.606147
# [211]	valid_0's binary_logloss: 0.606072
# [212]	valid_0's binary_logloss: 0.606008
# [213]	valid_0's binary_logloss: 0.605934
# [214]	valid_0's binary_logloss: 0.605853
# [215]	valid_0's binary_logloss: 0.605778
# [216]	valid_0's binary_logloss: 0.605699
# [217]	valid_0's binary_logloss: 0.605626
# [218]	valid_0's binary_logloss: 0.605551
# [219]	valid_0's binary_logloss: 0.605487
# [220]	valid_0's binary_logloss: 0.605405
# [221]	valid_0's binary_logloss: 0.605331
# [222]	valid_0's binary_logloss: 0.605232
# [223]	valid_0's binary_logloss: 0.605161
# [224]	valid_0's binary_logloss: 0.605095
# [225]	valid_0's binary_logloss: 0.604941
# [226]	valid_0's binary_logloss: 0.604877
# [227]	valid_0's binary_logloss: 0.604802
# [228]	valid_0's binary_logloss: 0.604737
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [229]	valid_0's binary_logloss: 0.604569
# [230]	valid_0's binary_logloss: 0.604482
# [231]	valid_0's binary_logloss: 0.604412
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [232]	valid_0's binary_logloss: 0.604296
# [233]	valid_0's binary_logloss: 0.604232
# [234]	valid_0's binary_logloss: 0.604174
# [235]	valid_0's binary_logloss: 0.604116
# [236]	valid_0's binary_logloss: 0.604051
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [237]	valid_0's binary_logloss: 0.60398
# [238]	valid_0's binary_logloss: 0.603917
# [239]	valid_0's binary_logloss: 0.603843
# [240]	valid_0's binary_logloss: 0.603785
# [241]	valid_0's binary_logloss: 0.603718
# [242]	valid_0's binary_logloss: 0.603648
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [243]	valid_0's binary_logloss: 0.603585
# [244]	valid_0's binary_logloss: 0.603525
# [245]	valid_0's binary_logloss: 0.603462
# [246]	valid_0's binary_logloss: 0.603351
# [247]	valid_0's binary_logloss: 0.603291
# [248]	valid_0's binary_logloss: 0.603228
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [249]	valid_0's binary_logloss: 0.603128
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [250]	valid_0's binary_logloss: 0.60307
# [251]	valid_0's binary_logloss: 0.603013
# [252]	valid_0's binary_logloss: 0.602943
# [253]	valid_0's binary_logloss: 0.602882
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [254]	valid_0's binary_logloss: 0.602818
# [255]	valid_0's binary_logloss: 0.602762
# [256]	valid_0's binary_logloss: 0.602703
# [257]	valid_0's binary_logloss: 0.602639
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [258]	valid_0's binary_logloss: 0.602587
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [259]	valid_0's binary_logloss: 0.602526
# [260]	valid_0's binary_logloss: 0.602461
# [261]	valid_0's binary_logloss: 0.602391
# [262]	valid_0's binary_logloss: 0.602311
# [263]	valid_0's binary_logloss: 0.602234
# [264]	valid_0's binary_logloss: 0.602158
# [265]	valid_0's binary_logloss: 0.602086
# [266]	valid_0's binary_logloss: 0.602017
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [267]	valid_0's binary_logloss: 0.60194
# [268]	valid_0's binary_logloss: 0.601865
# [269]	valid_0's binary_logloss: 0.601794
# [270]	valid_0's binary_logloss: 0.601717
# [271]	valid_0's binary_logloss: 0.601648
# [272]	valid_0's binary_logloss: 0.601573
# [273]	valid_0's binary_logloss: 0.601512
# [274]	valid_0's binary_logloss: 0.601451
# [275]	valid_0's binary_logloss: 0.601388
# [276]	valid_0's binary_logloss: 0.601319
# [277]	valid_0's binary_logloss: 0.601263
# [278]	valid_0's binary_logloss: 0.601196
# [279]	valid_0's binary_logloss: 0.601121
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [280]	valid_0's binary_logloss: 0.60106
# [281]	valid_0's binary_logloss: 0.601
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [282]	valid_0's binary_logloss: 0.600934
# [283]	valid_0's binary_logloss: 0.600867
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [284]	valid_0's binary_logloss: 0.600758
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [285]	valid_0's binary_logloss: 0.600687
# [286]	valid_0's binary_logloss: 0.60061
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [287]	valid_0's binary_logloss: 0.600553
# [288]	valid_0's binary_logloss: 0.600485
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [289]	valid_0's binary_logloss: 0.600424
# [290]	valid_0's binary_logloss: 0.600354
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [291]	valid_0's binary_logloss: 0.600293
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [292]	valid_0's binary_logloss: 0.600229
# [293]	valid_0's binary_logloss: 0.600155
# [294]	valid_0's binary_logloss: 0.600089
# [295]	valid_0's binary_logloss: 0.600026
# [296]	valid_0's binary_logloss: 0.599907
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [297]	valid_0's binary_logloss: 0.599854
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [298]	valid_0's binary_logloss: 0.599728
# [299]	valid_0's binary_logloss: 0.599589
# [300]	valid_0's binary_logloss: 0.599526
# [301]	valid_0's binary_logloss: 0.599477
# [302]	valid_0's binary_logloss: 0.599426
# [303]	valid_0's binary_logloss: 0.599369
# [304]	valid_0's binary_logloss: 0.599301
# [305]	valid_0's binary_logloss: 0.599241
# [306]	valid_0's binary_logloss: 0.599183
# [307]	valid_0's binary_logloss: 0.599121
# [308]	valid_0's binary_logloss: 0.599049
# [309]	valid_0's binary_logloss: 0.598987
# [310]	valid_0's binary_logloss: 0.598927
# [311]	valid_0's binary_logloss: 0.598797
# [312]	valid_0's binary_logloss: 0.598736
# [313]	valid_0's binary_logloss: 0.598677
# [314]	valid_0's binary_logloss: 0.598619
# [315]	valid_0's binary_logloss: 0.598555
# [316]	valid_0's binary_logloss: 0.598507
# [317]	valid_0's binary_logloss: 0.598449
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [318]	valid_0's binary_logloss: 0.59839
# [319]	valid_0's binary_logloss: 0.598343
# [320]	valid_0's binary_logloss: 0.598279
# [321]	valid_0's binary_logloss: 0.598211
# [322]	valid_0's binary_logloss: 0.598147
# [323]	valid_0's binary_logloss: 0.598018
# [324]	valid_0's binary_logloss: 0.597957
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [325]	valid_0's binary_logloss: 0.597888
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [326]	valid_0's binary_logloss: 0.597826
# [327]	valid_0's binary_logloss: 0.597774
# [328]	valid_0's binary_logloss: 0.597717
# [329]	valid_0's binary_logloss: 0.597664
# [330]	valid_0's binary_logloss: 0.597611
# [331]	valid_0's binary_logloss: 0.597553
# [332]	valid_0's binary_logloss: 0.5975
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [333]	valid_0's binary_logloss: 0.597446
# [334]	valid_0's binary_logloss: 0.597353
# [335]	valid_0's binary_logloss: 0.597306
# [336]	valid_0's binary_logloss: 0.597246
# [337]	valid_0's binary_logloss: 0.597188
# [338]	valid_0's binary_logloss: 0.597123
# [339]	valid_0's binary_logloss: 0.597067
# [340]	valid_0's binary_logloss: 0.597015
# [341]	valid_0's binary_logloss: 0.596959
# [342]	valid_0's binary_logloss: 0.596904
# [343]	valid_0's binary_logloss: 0.596842
# [344]	valid_0's binary_logloss: 0.596783
# [345]	valid_0's binary_logloss: 0.596731
# [346]	valid_0's binary_logloss: 0.596691
# [347]	valid_0's binary_logloss: 0.596655
# [348]	valid_0's binary_logloss: 0.596607
# [349]	valid_0's binary_logloss: 0.596558
# [350]	valid_0's binary_logloss: 0.596499
# [351]	valid_0's binary_logloss: 0.596436
# [352]	valid_0's binary_logloss: 0.596374
# [353]	valid_0's binary_logloss: 0.596319
# [354]	valid_0's binary_logloss: 0.596267
# [355]	valid_0's binary_logloss: 0.596219
# [356]	valid_0's binary_logloss: 0.596174
# [357]	valid_0's binary_logloss: 0.596123
# [358]	valid_0's binary_logloss: 0.596072
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [359]	valid_0's binary_logloss: 0.596025
# [360]	valid_0's binary_logloss: 0.59597
# [361]	valid_0's binary_logloss: 0.595923
# [362]	valid_0's binary_logloss: 0.595865
# [363]	valid_0's binary_logloss: 0.595821
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [364]	valid_0's binary_logloss: 0.595771
# [365]	valid_0's binary_logloss: 0.595617
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [366]	valid_0's binary_logloss: 0.595566
# [367]	valid_0's binary_logloss: 0.59551
# [368]	valid_0's binary_logloss: 0.59543
# [369]	valid_0's binary_logloss: 0.595386
# [370]	valid_0's binary_logloss: 0.595342
# [371]	valid_0's binary_logloss: 0.595292
# [372]	valid_0's binary_logloss: 0.595257
# [373]	valid_0's binary_logloss: 0.595218
# [374]	valid_0's binary_logloss: 0.595175
# [375]	valid_0's binary_logloss: 0.59513
# [376]	valid_0's binary_logloss: 0.594984
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [377]	valid_0's binary_logloss: 0.594946
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [378]	valid_0's binary_logloss: 0.594906
# [379]	valid_0's binary_logloss: 0.594857
# [380]	valid_0's binary_logloss: 0.594809
# [381]	valid_0's binary_logloss: 0.594765
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [382]	valid_0's binary_logloss: 0.59471
# [383]	valid_0's binary_logloss: 0.594662
# [384]	valid_0's binary_logloss: 0.594615
# [385]	valid_0's binary_logloss: 0.594561
# [386]	valid_0's binary_logloss: 0.594515
# [387]	valid_0's binary_logloss: 0.594466
# [388]	valid_0's binary_logloss: 0.594417
# [389]	valid_0's binary_logloss: 0.594366
# [390]	valid_0's binary_logloss: 0.594325
# [391]	valid_0's binary_logloss: 0.594279
# [392]	valid_0's binary_logloss: 0.594227
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [393]	valid_0's binary_logloss: 0.594177
# [394]	valid_0's binary_logloss: 0.594127
# [395]	valid_0's binary_logloss: 0.594079
# [396]	valid_0's binary_logloss: 0.594039
# [397]	valid_0's binary_logloss: 0.593991
# [398]	valid_0's binary_logloss: 0.593948
# [399]	valid_0's binary_logloss: 0.593892
# [400]	valid_0's binary_logloss: 0.593851
# [401]	valid_0's binary_logloss: 0.593798
# [402]	valid_0's binary_logloss: 0.593759
# [403]	valid_0's binary_logloss: 0.593714
# [404]	valid_0's binary_logloss: 0.593665
# [405]	valid_0's binary_logloss: 0.593624
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [406]	valid_0's binary_logloss: 0.593585
# [407]	valid_0's binary_logloss: 0.593545
# [408]	valid_0's binary_logloss: 0.593505
# [409]	valid_0's binary_logloss: 0.593448
# [410]	valid_0's binary_logloss: 0.593302
# [411]	valid_0's binary_logloss: 0.59326
# [412]	valid_0's binary_logloss: 0.593215
# [413]	valid_0's binary_logloss: 0.593154
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [414]	valid_0's binary_logloss: 0.593114
# [415]	valid_0's binary_logloss: 0.593074
# [416]	valid_0's binary_logloss: 0.593024
# [417]	valid_0's binary_logloss: 0.592983
# [418]	valid_0's binary_logloss: 0.592935
# [419]	valid_0's binary_logloss: 0.592894
# [420]	valid_0's binary_logloss: 0.592852
# [421]	valid_0's binary_logloss: 0.592812
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [422]	valid_0's binary_logloss: 0.592768
# [423]	valid_0's binary_logloss: 0.592731
# [424]	valid_0's binary_logloss: 0.592691
# [425]	valid_0's binary_logloss: 0.59265
# [426]	valid_0's binary_logloss: 0.592561
# [427]	valid_0's binary_logloss: 0.592526
# [428]	valid_0's binary_logloss: 0.592489
# [429]	valid_0's binary_logloss: 0.592447
# [430]	valid_0's binary_logloss: 0.592404
# [431]	valid_0's binary_logloss: 0.592366
# [432]	valid_0's binary_logloss: 0.592318
# [433]	valid_0's binary_logloss: 0.592273
# [434]	valid_0's binary_logloss: 0.592238
# [435]	valid_0's binary_logloss: 0.592198
# [436]	valid_0's binary_logloss: 0.592156
# [437]	valid_0's binary_logloss: 0.592115
# [438]	valid_0's binary_logloss: 0.592073
# [439]	valid_0's binary_logloss: 0.592038
# [440]	valid_0's binary_logloss: 0.591998
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [441]	valid_0's binary_logloss: 0.591966
# [442]	valid_0's binary_logloss: 0.591933
# [443]	valid_0's binary_logloss: 0.591894
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [444]	valid_0's binary_logloss: 0.591855
# [445]	valid_0's binary_logloss: 0.591817
# [446]	valid_0's binary_logloss: 0.59177
# [447]	valid_0's binary_logloss: 0.591663
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [448]	valid_0's binary_logloss: 0.591628
# [449]	valid_0's binary_logloss: 0.59159
# [450]	valid_0's binary_logloss: 0.591551
# [451]	valid_0's binary_logloss: 0.591505
# [452]	valid_0's binary_logloss: 0.591463
# [453]	valid_0's binary_logloss: 0.591428
# [454]	valid_0's binary_logloss: 0.591393
# [455]	valid_0's binary_logloss: 0.591285
# [456]	valid_0's binary_logloss: 0.591251
# [457]	valid_0's binary_logloss: 0.591212
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [458]	valid_0's binary_logloss: 0.591174
# [459]	valid_0's binary_logloss: 0.59114
# [460]	valid_0's binary_logloss: 0.591107
# [461]	valid_0's binary_logloss: 0.591068
# [462]	valid_0's binary_logloss: 0.591029
# [463]	valid_0's binary_logloss: 0.590956
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [464]	valid_0's binary_logloss: 0.590928
# [465]	valid_0's binary_logloss: 0.590898
# [466]	valid_0's binary_logloss: 0.590863
# [467]	valid_0's binary_logloss: 0.590741
# [468]	valid_0's binary_logloss: 0.590643
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [469]	valid_0's binary_logloss: 0.590615
# [470]	valid_0's binary_logloss: 0.59054
# [471]	valid_0's binary_logloss: 0.59038
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [472]	valid_0's binary_logloss: 0.590317
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [473]	valid_0's binary_logloss: 0.590285
# [474]	valid_0's binary_logloss: 0.59025
# [475]	valid_0's binary_logloss: 0.590213
# [476]	valid_0's binary_logloss: 0.59017
# [477]	valid_0's binary_logloss: 0.590128
# [478]	valid_0's binary_logloss: 0.590086
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [479]	valid_0's binary_logloss: 0.59005
# [480]	valid_0's binary_logloss: 0.590013
# [481]	valid_0's binary_logloss: 0.589973
# [482]	valid_0's binary_logloss: 0.589939
# [483]	valid_0's binary_logloss: 0.589902
# [484]	valid_0's binary_logloss: 0.589872
# [485]	valid_0's binary_logloss: 0.589835
# [486]	valid_0's binary_logloss: 0.589793
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [487]	valid_0's binary_logloss: 0.589765
# [488]	valid_0's binary_logloss: 0.589733
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [489]	valid_0's binary_logloss: 0.589698
# [490]	valid_0's binary_logloss: 0.589662
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [491]	valid_0's binary_logloss: 0.589632
# [492]	valid_0's binary_logloss: 0.589476
# [493]	valid_0's binary_logloss: 0.589435
# [494]	valid_0's binary_logloss: 0.589394
# [495]	valid_0's binary_logloss: 0.589355
# [496]	valid_0's binary_logloss: 0.589324
# [497]	valid_0's binary_logloss: 0.589289
# [498]	valid_0's binary_logloss: 0.589258
# [499]	valid_0's binary_logloss: 0.589216
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [500]	valid_0's binary_logloss: 0.589176
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [501]	valid_0's binary_logloss: 0.589126
# [502]	valid_0's binary_logloss: 0.589079
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [503]	valid_0's binary_logloss: 0.589039
# [504]	valid_0's binary_logloss: 0.589001
# [505]	valid_0's binary_logloss: 0.588959
# [506]	valid_0's binary_logloss: 0.588914
# [507]	valid_0's binary_logloss: 0.588874
# [508]	valid_0's binary_logloss: 0.588838
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [509]	valid_0's binary_logloss: 0.588792
# [510]	valid_0's binary_logloss: 0.588758
# [511]	valid_0's binary_logloss: 0.588712
# [512]	valid_0's binary_logloss: 0.588677
# [513]	valid_0's binary_logloss: 0.588639
# [514]	valid_0's binary_logloss: 0.588589
# [515]	valid_0's binary_logloss: 0.588546
# [516]	valid_0's binary_logloss: 0.588504
# [517]	valid_0's binary_logloss: 0.588468
# [518]	valid_0's binary_logloss: 0.588422
# [519]	valid_0's binary_logloss: 0.588385
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [520]	valid_0's binary_logloss: 0.588343
# [521]	valid_0's binary_logloss: 0.588303
# [522]	valid_0's binary_logloss: 0.588261
# [523]	valid_0's binary_logloss: 0.588228
# [524]	valid_0's binary_logloss: 0.58815
# [525]	valid_0's binary_logloss: 0.588114
# [526]	valid_0's binary_logloss: 0.588079
# [527]	valid_0's binary_logloss: 0.588037
# [528]	valid_0's binary_logloss: 0.588001
# [529]	valid_0's binary_logloss: 0.587959
# [530]	valid_0's binary_logloss: 0.587926
# [531]	valid_0's binary_logloss: 0.587892
# [532]	valid_0's binary_logloss: 0.587854
# [533]	valid_0's binary_logloss: 0.587807
# [534]	valid_0's binary_logloss: 0.587761
# [535]	valid_0's binary_logloss: 0.587717
# [536]	valid_0's binary_logloss: 0.587672
# [537]	valid_0's binary_logloss: 0.587637
# [538]	valid_0's binary_logloss: 0.587599
# [539]	valid_0's binary_logloss: 0.58756
# [540]	valid_0's binary_logloss: 0.587521
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [541]	valid_0's binary_logloss: 0.587484
# [542]	valid_0's binary_logloss: 0.587435
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [543]	valid_0's binary_logloss: 0.587394
# [544]	valid_0's binary_logloss: 0.587358
# [545]	valid_0's binary_logloss: 0.587314
# [546]	valid_0's binary_logloss: 0.587273
# [547]	valid_0's binary_logloss: 0.587127
# [548]	valid_0's binary_logloss: 0.587088
# [549]	valid_0's binary_logloss: 0.587054
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [550]	valid_0's binary_logloss: 0.587008
# [551]	valid_0's binary_logloss: 0.58697
# [552]	valid_0's binary_logloss: 0.586934
# [553]	valid_0's binary_logloss: 0.586896
# [554]	valid_0's binary_logloss: 0.586852
# [555]	valid_0's binary_logloss: 0.58682
# [556]	valid_0's binary_logloss: 0.586768
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [557]	valid_0's binary_logloss: 0.586737
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [558]	valid_0's binary_logloss: 0.5867
# [559]	valid_0's binary_logloss: 0.586659
# [560]	valid_0's binary_logloss: 0.586622
# [561]	valid_0's binary_logloss: 0.586588
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [562]	valid_0's binary_logloss: 0.586538
# [563]	valid_0's binary_logloss: 0.586503
# [564]	valid_0's binary_logloss: 0.586469
# [565]	valid_0's binary_logloss: 0.586431
# [566]	valid_0's binary_logloss: 0.586401
# [567]	valid_0's binary_logloss: 0.586359
# [568]	valid_0's binary_logloss: 0.586327
# [569]	valid_0's binary_logloss: 0.586291
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [570]	valid_0's binary_logloss: 0.586255
# [571]	valid_0's binary_logloss: 0.586218
# [572]	valid_0's binary_logloss: 0.586186
# [573]	valid_0's binary_logloss: 0.586149
# [574]	valid_0's binary_logloss: 0.586114
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [575]	valid_0's binary_logloss: 0.586083
# [576]	valid_0's binary_logloss: 0.586037
# [577]	valid_0's binary_logloss: 0.586003
# [578]	valid_0's binary_logloss: 0.585969
# [579]	valid_0's binary_logloss: 0.585859
# [580]	valid_0's binary_logloss: 0.585826
# [581]	valid_0's binary_logloss: 0.585788
# [582]	valid_0's binary_logloss: 0.585749
# [583]	valid_0's binary_logloss: 0.585714
# [584]	valid_0's binary_logloss: 0.585676
# [585]	valid_0's binary_logloss: 0.58564
# [586]	valid_0's binary_logloss: 0.585606
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [587]	valid_0's binary_logloss: 0.585572
# [588]	valid_0's binary_logloss: 0.585529
# [589]	valid_0's binary_logloss: 0.585488
# [590]	valid_0's binary_logloss: 0.585455
# [591]	valid_0's binary_logloss: 0.585421
# [592]	valid_0's binary_logloss: 0.585382
# [593]	valid_0's binary_logloss: 0.585321
# [594]	valid_0's binary_logloss: 0.585281
# [595]	valid_0's binary_logloss: 0.585243
# [596]	valid_0's binary_logloss: 0.5852
# [597]	valid_0's binary_logloss: 0.585164
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [598]	valid_0's binary_logloss: 0.58512
# [599]	valid_0's binary_logloss: 0.585092
# [600]	valid_0's binary_logloss: 0.585063
# [601]	valid_0's binary_logloss: 0.585029
# [602]	valid_0's binary_logloss: 0.584992
# [603]	valid_0's binary_logloss: 0.584952
# [604]	valid_0's binary_logloss: 0.584918
# [605]	valid_0's binary_logloss: 0.584888
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [606]	valid_0's binary_logloss: 0.58486
# [607]	valid_0's binary_logloss: 0.584795
# [608]	valid_0's binary_logloss: 0.584772
# [609]	valid_0's binary_logloss: 0.58474
# [610]	valid_0's binary_logloss: 0.58472
# [611]	valid_0's binary_logloss: 0.584692
# [612]	valid_0's binary_logloss: 0.584652
# [613]	valid_0's binary_logloss: 0.58463
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [614]	valid_0's binary_logloss: 0.584603
# [615]	valid_0's binary_logloss: 0.584565
# [616]	valid_0's binary_logloss: 0.58453
# [617]	valid_0's binary_logloss: 0.5845
# [618]	valid_0's binary_logloss: 0.584365
# [619]	valid_0's binary_logloss: 0.584326
# [620]	valid_0's binary_logloss: 0.584293
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [621]	valid_0's binary_logloss: 0.58426
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [622]	valid_0's binary_logloss: 0.584224
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [623]	valid_0's binary_logloss: 0.584188
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [624]	valid_0's binary_logloss: 0.584158
# [625]	valid_0's binary_logloss: 0.584125
# [626]	valid_0's binary_logloss: 0.584093
# [627]	valid_0's binary_logloss: 0.584064
# [628]	valid_0's binary_logloss: 0.584034
# [629]	valid_0's binary_logloss: 0.584005
# [630]	valid_0's binary_logloss: 0.58397
# [631]	valid_0's binary_logloss: 0.583937
# [632]	valid_0's binary_logloss: 0.583905
# [633]	valid_0's binary_logloss: 0.583871
# [634]	valid_0's binary_logloss: 0.583844
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [635]	valid_0's binary_logloss: 0.583821
# [636]	valid_0's binary_logloss: 0.583787
# [637]	valid_0's binary_logloss: 0.583756
# [638]	valid_0's binary_logloss: 0.583725
# [639]	valid_0's binary_logloss: 0.583691
# [640]	valid_0's binary_logloss: 0.583651
# [641]	valid_0's binary_logloss: 0.583624
# [642]	valid_0's binary_logloss: 0.583587
# [643]	valid_0's binary_logloss: 0.583556
# [644]	valid_0's binary_logloss: 0.583503
# [645]	valid_0's binary_logloss: 0.583467
# [646]	valid_0's binary_logloss: 0.583441
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [647]	valid_0's binary_logloss: 0.58337
# [648]	valid_0's binary_logloss: 0.583346
# [649]	valid_0's binary_logloss: 0.58332
# [650]	valid_0's binary_logloss: 0.583293
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [651]	valid_0's binary_logloss: 0.583262
# [652]	valid_0's binary_logloss: 0.583234
# [653]	valid_0's binary_logloss: 0.583197
# [654]	valid_0's binary_logloss: 0.583167
# [655]	valid_0's binary_logloss: 0.583131
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [656]	valid_0's binary_logloss: 0.583104
# [657]	valid_0's binary_logloss: 0.583078
# [658]	valid_0's binary_logloss: 0.583054
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [659]	valid_0's binary_logloss: 0.583026
# [660]	valid_0's binary_logloss: 0.583005
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [661]	valid_0's binary_logloss: 0.58298
# [662]	valid_0's binary_logloss: 0.582951
# [663]	valid_0's binary_logloss: 0.582922
# [664]	valid_0's binary_logloss: 0.5829
# [665]	valid_0's binary_logloss: 0.58288
# [666]	valid_0's binary_logloss: 0.582803
# [667]	valid_0's binary_logloss: 0.582782
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [668]	valid_0's binary_logloss: 0.582715
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [669]	valid_0's binary_logloss: 0.58269
# [670]	valid_0's binary_logloss: 0.582672
# [671]	valid_0's binary_logloss: 0.582643
# [672]	valid_0's binary_logloss: 0.582627
# [673]	valid_0's binary_logloss: 0.582605
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [674]	valid_0's binary_logloss: 0.582581
# [675]	valid_0's binary_logloss: 0.58256
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [676]	valid_0's binary_logloss: 0.582539
# [677]	valid_0's binary_logloss: 0.582508
# [678]	valid_0's binary_logloss: 0.582478
# [679]	valid_0's binary_logloss: 0.582365
# [680]	valid_0's binary_logloss: 0.582336
# [681]	valid_0's binary_logloss: 0.582316
# [682]	valid_0's binary_logloss: 0.582295
# [683]	valid_0's binary_logloss: 0.582276
# [684]	valid_0's binary_logloss: 0.582259
# [685]	valid_0's binary_logloss: 0.582232
# [686]	valid_0's binary_logloss: 0.582205
# [687]	valid_0's binary_logloss: 0.582182
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [688]	valid_0's binary_logloss: 0.582158
# [689]	valid_0's binary_logloss: 0.582132
# [690]	valid_0's binary_logloss: 0.58211
# [691]	valid_0's binary_logloss: 0.582089
# [692]	valid_0's binary_logloss: 0.582062
# [693]	valid_0's binary_logloss: 0.58204
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [694]	valid_0's binary_logloss: 0.582008
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [695]	valid_0's binary_logloss: 0.581977
# [696]	valid_0's binary_logloss: 0.581947
# [697]	valid_0's binary_logloss: 0.581917
# [698]	valid_0's binary_logloss: 0.581883
# [699]	valid_0's binary_logloss: 0.581854
# [700]	valid_0's binary_logloss: 0.581818
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [701]	valid_0's binary_logloss: 0.581783
# [702]	valid_0's binary_logloss: 0.581761
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [703]	valid_0's binary_logloss: 0.58173
# [704]	valid_0's binary_logloss: 0.581697
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [705]	valid_0's binary_logloss: 0.581671
# [706]	valid_0's binary_logloss: 0.581642
# [707]	valid_0's binary_logloss: 0.581614
# [708]	valid_0's binary_logloss: 0.581577
# [709]	valid_0's binary_logloss: 0.581549
# [710]	valid_0's binary_logloss: 0.581519
# [711]	valid_0's binary_logloss: 0.581496
# [712]	valid_0's binary_logloss: 0.581464
# [713]	valid_0's binary_logloss: 0.581432
# [714]	valid_0's binary_logloss: 0.581404
# [715]	valid_0's binary_logloss: 0.581374
# [716]	valid_0's binary_logloss: 0.581295
# [717]	valid_0's binary_logloss: 0.581265
# [718]	valid_0's binary_logloss: 0.581245
# [719]	valid_0's binary_logloss: 0.581226
# [720]	valid_0's binary_logloss: 0.581206
# [721]	valid_0's binary_logloss: 0.581166
# [722]	valid_0's binary_logloss: 0.581064
# [723]	valid_0's binary_logloss: 0.581034
# [724]	valid_0's binary_logloss: 0.581007
# [725]	valid_0's binary_logloss: 0.580986
# [726]	valid_0's binary_logloss: 0.580964
# [727]	valid_0's binary_logloss: 0.580937
# [728]	valid_0's binary_logloss: 0.580902
# [729]	valid_0's binary_logloss: 0.580871
# [730]	valid_0's binary_logloss: 0.580846
# [731]	valid_0's binary_logloss: 0.580813
# [732]	valid_0's binary_logloss: 0.580786
# [733]	valid_0's binary_logloss: 0.58077
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [734]	valid_0's binary_logloss: 0.58075
# [735]	valid_0's binary_logloss: 0.580726
# [736]	valid_0's binary_logloss: 0.580698
# [737]	valid_0's binary_logloss: 0.580671
# [738]	valid_0's binary_logloss: 0.580646
# [739]	valid_0's binary_logloss: 0.580616
# [740]	valid_0's binary_logloss: 0.580599
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [741]	valid_0's binary_logloss: 0.580577
# [742]	valid_0's binary_logloss: 0.580551
# [743]	valid_0's binary_logloss: 0.580527
# [744]	valid_0's binary_logloss: 0.580457
# [745]	valid_0's binary_logloss: 0.580428
# [746]	valid_0's binary_logloss: 0.580396
# [747]	valid_0's binary_logloss: 0.58037
# [748]	valid_0's binary_logloss: 0.58035
# [749]	valid_0's binary_logloss: 0.580321
# [750]	valid_0's binary_logloss: 0.580286
# [751]	valid_0's binary_logloss: 0.580255
# [752]	valid_0's binary_logloss: 0.580228
# [753]	valid_0's binary_logloss: 0.580203
# [754]	valid_0's binary_logloss: 0.580178
# [755]	valid_0's binary_logloss: 0.580153
# [756]	valid_0's binary_logloss: 0.580087
# [757]	valid_0's binary_logloss: 0.580059
# [758]	valid_0's binary_logloss: 0.580028
# [759]	valid_0's binary_logloss: 0.580011
# [760]	valid_0's binary_logloss: 0.579987
# [761]	valid_0's binary_logloss: 0.579955
# [762]	valid_0's binary_logloss: 0.57993
# [763]	valid_0's binary_logloss: 0.579906
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [764]	valid_0's binary_logloss: 0.57989
# [765]	valid_0's binary_logloss: 0.579871
# [766]	valid_0's binary_logloss: 0.579844
# [767]	valid_0's binary_logloss: 0.579761
# [768]	valid_0's binary_logloss: 0.579676
# [769]	valid_0's binary_logloss: 0.579644
# [770]	valid_0's binary_logloss: 0.579617
# [771]	valid_0's binary_logloss: 0.579589
# [772]	valid_0's binary_logloss: 0.579562
# [773]	valid_0's binary_logloss: 0.579539
# [774]	valid_0's binary_logloss: 0.579513
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [775]	valid_0's binary_logloss: 0.579486
# [776]	valid_0's binary_logloss: 0.579458
# [777]	valid_0's binary_logloss: 0.579426
# [778]	valid_0's binary_logloss: 0.5794
# [779]	valid_0's binary_logloss: 0.579377
# [780]	valid_0's binary_logloss: 0.579356
# [781]	valid_0's binary_logloss: 0.579334
# [782]	valid_0's binary_logloss: 0.579265
# [783]	valid_0's binary_logloss: 0.579243
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [784]	valid_0's binary_logloss: 0.579217
# [785]	valid_0's binary_logloss: 0.579186
# [786]	valid_0's binary_logloss: 0.579162
# [787]	valid_0's binary_logloss: 0.579139
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [788]	valid_0's binary_logloss: 0.579116
# [789]	valid_0's binary_logloss: 0.579093
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [790]	valid_0's binary_logloss: 0.579066
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [791]	valid_0's binary_logloss: 0.579038
# [792]	valid_0's binary_logloss: 0.579015
# [793]	valid_0's binary_logloss: 0.578985
# [794]	valid_0's binary_logloss: 0.578961
# [795]	valid_0's binary_logloss: 0.578932
# [796]	valid_0's binary_logloss: 0.578855
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [797]	valid_0's binary_logloss: 0.578829
# [798]	valid_0's binary_logloss: 0.578813
# [799]	valid_0's binary_logloss: 0.57878
# [800]	valid_0's binary_logloss: 0.57876
# [801]	valid_0's binary_logloss: 0.578739
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [802]	valid_0's binary_logloss: 0.578721
# [803]	valid_0's binary_logloss: 0.578699
# [804]	valid_0's binary_logloss: 0.578666
# [805]	valid_0's binary_logloss: 0.578642
# [806]	valid_0's binary_logloss: 0.578614
# [807]	valid_0's binary_logloss: 0.578576
# [808]	valid_0's binary_logloss: 0.578553
# [809]	valid_0's binary_logloss: 0.578534
# [810]	valid_0's binary_logloss: 0.57851
# [811]	valid_0's binary_logloss: 0.57846
# [812]	valid_0's binary_logloss: 0.578433
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [813]	valid_0's binary_logloss: 0.57841
# [814]	valid_0's binary_logloss: 0.578385
# [815]	valid_0's binary_logloss: 0.57837
# [816]	valid_0's binary_logloss: 0.578345
# [817]	valid_0's binary_logloss: 0.578323
# [818]	valid_0's binary_logloss: 0.578292
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [819]	valid_0's binary_logloss: 0.578268
# [820]	valid_0's binary_logloss: 0.578247
# [821]	valid_0's binary_logloss: 0.578227
# [822]	valid_0's binary_logloss: 0.578176
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [823]	valid_0's binary_logloss: 0.57815
# [824]	valid_0's binary_logloss: 0.578118
# [825]	valid_0's binary_logloss: 0.578095
# [826]	valid_0's binary_logloss: 0.578073
# [827]	valid_0's binary_logloss: 0.578057
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [828]	valid_0's binary_logloss: 0.578036
# [829]	valid_0's binary_logloss: 0.578012
# [830]	valid_0's binary_logloss: 0.577991
# [831]	valid_0's binary_logloss: 0.577972
# [832]	valid_0's binary_logloss: 0.577953
# [833]	valid_0's binary_logloss: 0.577932
# [834]	valid_0's binary_logloss: 0.57791
# [835]	valid_0's binary_logloss: 0.577884
# [836]	valid_0's binary_logloss: 0.577858
# [837]	valid_0's binary_logloss: 0.577836
# [838]	valid_0's binary_logloss: 0.577785
# [839]	valid_0's binary_logloss: 0.577762
# [840]	valid_0's binary_logloss: 0.577746
# [841]	valid_0's binary_logloss: 0.577722
# [842]	valid_0's binary_logloss: 0.5777
# [843]	valid_0's binary_logloss: 0.577679
# [844]	valid_0's binary_logloss: 0.577655
# [845]	valid_0's binary_logloss: 0.577634
# [846]	valid_0's binary_logloss: 0.577612
# [847]	valid_0's binary_logloss: 0.57759
# [848]	valid_0's binary_logloss: 0.57757
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [849]	valid_0's binary_logloss: 0.577549
# [850]	valid_0's binary_logloss: 0.577532
# [851]	valid_0's binary_logloss: 0.577515
# [852]	valid_0's binary_logloss: 0.577493
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [853]	valid_0's binary_logloss: 0.577473
# [854]	valid_0's binary_logloss: 0.577451
# [855]	valid_0's binary_logloss: 0.577433
# [856]	valid_0's binary_logloss: 0.577412
# [857]	valid_0's binary_logloss: 0.577391
# [858]	valid_0's binary_logloss: 0.577371
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [859]	valid_0's binary_logloss: 0.577349
# [860]	valid_0's binary_logloss: 0.577327
# [861]	valid_0's binary_logloss: 0.577307
# [862]	valid_0's binary_logloss: 0.57728
# [863]	valid_0's binary_logloss: 0.577252
# [864]	valid_0's binary_logloss: 0.577225
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [865]	valid_0's binary_logloss: 0.577197
# [866]	valid_0's binary_logloss: 0.577176
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [867]	valid_0's binary_logloss: 0.577159
# [868]	valid_0's binary_logloss: 0.577139
# [869]	valid_0's binary_logloss: 0.577115
# [870]	valid_0's binary_logloss: 0.577091
# [871]	valid_0's binary_logloss: 0.577075
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [872]	valid_0's binary_logloss: 0.577054
# [873]	valid_0's binary_logloss: 0.577036
# [874]	valid_0's binary_logloss: 0.577019
# [875]	valid_0's binary_logloss: 0.577003
# [876]	valid_0's binary_logloss: 0.576979
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [877]	valid_0's binary_logloss: 0.57696
# [878]	valid_0's binary_logloss: 0.57694
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [879]	valid_0's binary_logloss: 0.576918
# [880]	valid_0's binary_logloss: 0.576892
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [881]	valid_0's binary_logloss: 0.576873
# [882]	valid_0's binary_logloss: 0.576851
# [883]	valid_0's binary_logloss: 0.576834
# [884]	valid_0's binary_logloss: 0.576811
# [885]	valid_0's binary_logloss: 0.576789
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [886]	valid_0's binary_logloss: 0.57677
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [887]	valid_0's binary_logloss: 0.576744
# [888]	valid_0's binary_logloss: 0.576724
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [889]	valid_0's binary_logloss: 0.5766
# [890]	valid_0's binary_logloss: 0.57652
# [891]	valid_0's binary_logloss: 0.576479
# [892]	valid_0's binary_logloss: 0.576461
# [893]	valid_0's binary_logloss: 0.576359
# [894]	valid_0's binary_logloss: 0.57634
# [895]	valid_0's binary_logloss: 0.576319
# [896]	valid_0's binary_logloss: 0.576299
# [897]	valid_0's binary_logloss: 0.576275
# [898]	valid_0's binary_logloss: 0.576255
# [899]	valid_0's binary_logloss: 0.576217
# [900]	valid_0's binary_logloss: 0.576197
# [901]	valid_0's binary_logloss: 0.576178
# [902]	valid_0's binary_logloss: 0.576158
# [903]	valid_0's binary_logloss: 0.576141
# [904]	valid_0's binary_logloss: 0.576117
# [905]	valid_0's binary_logloss: 0.5761
# [906]	valid_0's binary_logloss: 0.576081
# [907]	valid_0's binary_logloss: 0.576061
# [908]	valid_0's binary_logloss: 0.575979
# [909]	valid_0's binary_logloss: 0.575952
# [910]	valid_0's binary_logloss: 0.575929
# [911]	valid_0's binary_logloss: 0.575911
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [912]	valid_0's binary_logloss: 0.575888
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [913]	valid_0's binary_logloss: 0.575866
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [914]	valid_0's binary_logloss: 0.575846
# [915]	valid_0's binary_logloss: 0.575824
# [916]	valid_0's binary_logloss: 0.575802
# [917]	valid_0's binary_logloss: 0.57578
# [918]	valid_0's binary_logloss: 0.575756
# [919]	valid_0's binary_logloss: 0.575736
# [920]	valid_0's binary_logloss: 0.575719
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [921]	valid_0's binary_logloss: 0.575707
# [922]	valid_0's binary_logloss: 0.575539
# [923]	valid_0's binary_logloss: 0.575513
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [924]	valid_0's binary_logloss: 0.575498
# [925]	valid_0's binary_logloss: 0.57548
# [926]	valid_0's binary_logloss: 0.575463
# [927]	valid_0's binary_logloss: 0.575443
# [928]	valid_0's binary_logloss: 0.575406
# [929]	valid_0's binary_logloss: 0.575392
# [930]	valid_0's binary_logloss: 0.575381
# [931]	valid_0's binary_logloss: 0.575293
# [932]	valid_0's binary_logloss: 0.575227
# [933]	valid_0's binary_logloss: 0.575215
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [934]	valid_0's binary_logloss: 0.575201
# [935]	valid_0's binary_logloss: 0.575183
# [936]	valid_0's binary_logloss: 0.57517
# [937]	valid_0's binary_logloss: 0.575151
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [938]	valid_0's binary_logloss: 0.57513
# [939]	valid_0's binary_logloss: 0.575113
# [940]	valid_0's binary_logloss: 0.575031
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [941]	valid_0's binary_logloss: 0.575012
# [942]	valid_0's binary_logloss: 0.575001
# [943]	valid_0's binary_logloss: 0.574985
# [944]	valid_0's binary_logloss: 0.574966
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [945]	valid_0's binary_logloss: 0.574951
# [946]	valid_0's binary_logloss: 0.574871
# [947]	valid_0's binary_logloss: 0.57485
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [948]	valid_0's binary_logloss: 0.574827
# [949]	valid_0's binary_logloss: 0.574812
# [950]	valid_0's binary_logloss: 0.574795
# [951]	valid_0's binary_logloss: 0.574776
# [952]	valid_0's binary_logloss: 0.574762
# [953]	valid_0's binary_logloss: 0.574742
# [954]	valid_0's binary_logloss: 0.574728
# [955]	valid_0's binary_logloss: 0.57471
# [956]	valid_0's binary_logloss: 0.574686
# [957]	valid_0's binary_logloss: 0.574665
# [958]	valid_0's binary_logloss: 0.574626
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [959]	valid_0's binary_logloss: 0.574613
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [960]	valid_0's binary_logloss: 0.574544
# [961]	valid_0's binary_logloss: 0.574529
# [962]	valid_0's binary_logloss: 0.574513
# [963]	valid_0's binary_logloss: 0.574497
# [964]	valid_0's binary_logloss: 0.574479
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [965]	valid_0's binary_logloss: 0.574451
# [966]	valid_0's binary_logloss: 0.574433
# [967]	valid_0's binary_logloss: 0.574415
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [968]	valid_0's binary_logloss: 0.574398
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [969]	valid_0's binary_logloss: 0.574304
# [970]	valid_0's binary_logloss: 0.574289
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [971]	valid_0's binary_logloss: 0.574274
# [972]	valid_0's binary_logloss: 0.574242
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [973]	valid_0's binary_logloss: 0.574167
# [974]	valid_0's binary_logloss: 0.574155
# [975]	valid_0's binary_logloss: 0.574139
# [976]	valid_0's binary_logloss: 0.574125
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [977]	valid_0's binary_logloss: 0.574107
# [978]	valid_0's binary_logloss: 0.57409
# [979]	valid_0's binary_logloss: 0.574072
# [980]	valid_0's binary_logloss: 0.574016
# [981]	valid_0's binary_logloss: 0.574002
# [982]	valid_0's binary_logloss: 0.573986
# [983]	valid_0's binary_logloss: 0.573967
# [984]	valid_0's binary_logloss: 0.573947
# [985]	valid_0's binary_logloss: 0.573922
# [986]	valid_0's binary_logloss: 0.573859
# [987]	valid_0's binary_logloss: 0.573844
# [988]	valid_0's binary_logloss: 0.573831
# [989]	valid_0's binary_logloss: 0.57381
# [990]	valid_0's binary_logloss: 0.573795
# [991]	valid_0's binary_logloss: 0.573773
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [992]	valid_0's binary_logloss: 0.573759
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [993]	valid_0's binary_logloss: 0.573745
# [994]	valid_0's binary_logloss: 0.573729
# [995]	valid_0's binary_logloss: 0.573632
# [996]	valid_0's binary_logloss: 0.573606
# [997]	valid_0's binary_logloss: 0.573595
# [998]	valid_0's binary_logloss: 0.573557
# [999]	valid_0's binary_logloss: 0.573537
# [1000]	valid_0's binary_logloss: 0.573526
# Did not meet early stopping. Best iteration is:
# [1000]	valid_0's binary_logloss: 0.573526

# %%
booster_clf_preds = booster_clf.predict(
    df_test.drop(columns="label"),
    raw_score=True,
)

# %%
roc_auc = roc_auc_score(df_test["label"], booster_clf_preds)
logloss = log_loss(df_test["label"], booster_clf_preds)

print("LightGBM Classifier metrics")
print(f"ROC AUC: {roc_auc}, logloss: {logloss}")
# Out:
# LightGBM Classifier metrics
# ROC AUC: 0.7726528528950893, logloss: 6.170192000842237

# %% [markdown]
# # DCNv2

# %%
dcnv2_model = DCNv2(
    model_structure="stacked_parallel",
    use_low_rank_mixture=True,
    cross_low_rank_dim=32,
    num_cross_layers=5,
    num_cross_experts=4,
    parallel_hidden_dims=[256, 512, 1024],
    parallel_dropout=0.2,
    parallel_use_batch_norm=True,
    parallel_activation=nn.ReLU,
    stacked_hidden_dims=[256, 512, 1024],
    stacked_dropout=0.2,
    stacked_use_batch_norm=True,
    stacked_activation=nn.ReLU,
    output_dim=1,
    proj_output_embeddings=True,
)

# %%
train_metrics_dcnv2, val_metrics_dcnv2 = dcnv2_model.fit(
    features=df_train.drop(columns="label"),
    target=df_train["label"],
    val_features=df_val.drop(columns="label"),
    val_target=df_val["label"],
    optimizer_cls="torch.optim.Adam",
    optimizer_params=dict(lr=1e-2),
    scheduler_cls="torch.optim.lr_scheduler.ReduceLROnPlateau",
    scheduler_params=dict(mode="max", factor=0.1, patience=1, min_lr=1e-6),
    grad_clip_threshold=10.,
    num_epochs=3,
    seed=42,
    artifacts_path="./dcnv2_artifacts",
    device="cuda:0",
    batch_size=4096,
    num_workers=2,
    eval_metric_name="AUC",
    eval_mode="max",
    default_embedding_size=20,
    oov_masking_proba=0.05,
    l2_net_reg=0,
    l2_embedding_reg=0,
)
# Out:
# [2025-05-04 00:24:34,049]{model.py:660} - INFO - Used features config: FeaturesConfig(features=[Feature(name='msno', feature_type=<FeatureType.CATEGORICAL: 'categorical'>, feature_size=1, needs_embed=True, embedding_size=20, embedding_vocab_size=30534, embedding_padding_idx=None), Feature(name='song_id', feature_type=<FeatureType.CATEGORICAL: 'categorical'>, feature_size=1, needs_embed=True, embedding_size=20, embedding_vocab_size=324210, embedding_padding_idx=None), Feature(name='source_system_tab', feature_type=<FeatureType.CATEGORICAL: 'categorical'>, feature_size=1, needs_embed=True, embedding_size=20, embedding_vocab_size=10, embedding_padding_idx=None), Feature(name='source_screen_name', feature_type=<FeatureType.CATEGORICAL: 'categorical'>, feature_size=1, needs_embed=True, embedding_size=20, embedding_vocab_size=22, embedding_padding_idx=None), Feature(name='source_type', feature_type=<FeatureType.CATEGORICAL: 'categorical'>, feature_size=1, needs_embed=True, embedding_size=20, embedding_vocab_size=14, embedding_padding_idx=None), Feature(name='city', feature_type=<FeatureType.CATEGORICAL: 'categorical'>, feature_size=1, needs_embed=True, embedding_size=20, embedding_vocab_size=22, embedding_padding_idx=None), Feature(name='bd', feature_type=<FeatureType.CATEGORICAL: 'categorical'>, feature_size=1, needs_embed=True, embedding_size=20, embedding_vocab_size=93, embedding_padding_idx=None), Feature(name='gender', feature_type=<FeatureType.CATEGORICAL: 'categorical'>, feature_size=1, needs_embed=True, embedding_size=20, embedding_vocab_size=4, embedding_padding_idx=None), Feature(name='registered_via', feature_type=<FeatureType.CATEGORICAL: 'categorical'>, feature_size=1, needs_embed=True, embedding_size=20, embedding_vocab_size=6, embedding_padding_idx=None), Feature(name='song_length', feature_type=<FeatureType.NUMERICAL: 'numerical'>, feature_size=1, needs_embed=False, embedding_size=None, embedding_vocab_size=None, embedding_padding_idx=None), Feature(name='genre_ids', feature_type=<FeatureType.CATEGORICAL: 'categorical'>, feature_size=1, needs_embed=True, embedding_size=20, embedding_vocab_size=562, embedding_padding_idx=None), Feature(name='artist_name', feature_type=<FeatureType.CATEGORICAL: 'categorical'>, feature_size=1, needs_embed=True, embedding_size=20, embedding_vocab_size=37649, embedding_padding_idx=None), Feature(name='language', feature_type=<FeatureType.CATEGORICAL: 'categorical'>, feature_size=1, needs_embed=True, embedding_size=20, embedding_vocab_size=12, embedding_padding_idx=None)])
# [2025-05-04 00:24:34,052]{model.py:675} - INFO - Artifacts path is /kaggle/working/dcnv2_artifacts
# [2025-05-04 00:24:34,052]{model.py:681} - INFO - Best model path is dcnv2_artifacts/best_model.pt
# [2025-05-04 00:24:34,064]{model.py:686} - INFO - Building features mappings
# [2025-05-04 00:24:34,065]{model.py:272} - INFO - Building mapping for feature msno
# [2025-05-04 00:24:34,101]{model.py:272} - INFO - Building mapping for feature song_id
# [2025-05-04 00:24:34,196]{model.py:272} - INFO - Building mapping for feature source_system_tab
# [2025-05-04 00:24:34,223]{model.py:272} - INFO - Building mapping for feature source_screen_name
# [2025-05-04 00:24:34,247]{model.py:272} - INFO - Building mapping for feature source_type
# [2025-05-04 00:24:34,271]{model.py:272} - INFO - Building mapping for feature city
# [2025-05-04 00:24:34,294]{model.py:272} - INFO - Building mapping for feature bd
# [2025-05-04 00:24:34,318]{model.py:272} - INFO - Building mapping for feature gender
# [2025-05-04 00:24:34,342]{model.py:272} - INFO - Building mapping for feature registered_via
# [2025-05-04 00:24:34,366]{model.py:272} - INFO - Building mapping for feature genre_ids
# [2025-05-04 00:24:34,398]{model.py:272} - INFO - Building mapping for feature artist_name
# [2025-05-04 00:24:34,445]{model.py:272} - INFO - Building mapping for feature language
# [2025-05-04 00:24:34,470]{model.py:689} - INFO - Building train dataloader
# [2025-05-04 00:24:34,537]{model.py:297} - INFO - Encoding feature msno
# [2025-05-04 00:24:34,692]{model.py:297} - INFO - Encoding feature song_id
# [2025-05-04 00:24:35,001]{model.py:297} - INFO - Encoding feature source_system_tab
# [2025-05-04 00:24:35,133]{model.py:297} - INFO - Encoding feature source_screen_name
# [2025-05-04 00:24:35,266]{model.py:297} - INFO - Encoding feature source_type
# [2025-05-04 00:24:35,397]{model.py:297} - INFO - Encoding feature city
# [2025-05-04 00:24:35,515]{model.py:297} - INFO - Encoding feature bd
# [2025-05-04 00:24:35,650]{model.py:297} - INFO - Encoding feature gender
# [2025-05-04 00:24:35,782]{model.py:297} - INFO - Encoding feature registered_via
# [2025-05-04 00:24:35,916]{model.py:297} - INFO - Encoding feature genre_ids
# [2025-05-04 00:24:36,049]{model.py:297} - INFO - Encoding feature artist_name
# [2025-05-04 00:24:36,194]{model.py:297} - INFO - Encoding feature language
# [2025-05-04 00:24:36,347]{model.py:702} - INFO - Building validation dataloader
# [2025-05-04 00:24:36,352]{model.py:297} - INFO - Encoding feature msno
# [2025-05-04 00:24:36,380]{model.py:297} - INFO - Encoding feature song_id
# [2025-05-04 00:24:36,539]{model.py:297} - INFO - Encoding feature source_system_tab
# [2025-05-04 00:24:36,549]{model.py:297} - INFO - Encoding feature source_screen_name
# [2025-05-04 00:24:36,559]{model.py:297} - INFO - Encoding feature source_type
# [2025-05-04 00:24:36,571]{model.py:297} - INFO - Encoding feature city
# [2025-05-04 00:24:36,583]{model.py:297} - INFO - Encoding feature bd
# [2025-05-04 00:24:36,594]{model.py:297} - INFO - Encoding feature gender
# [2025-05-04 00:24:36,605]{model.py:297} - INFO - Encoding feature registered_via
# [2025-05-04 00:24:36,616]{model.py:297} - INFO - Encoding feature genre_ids
# [2025-05-04 00:24:36,630]{model.py:297} - INFO - Encoding feature artist_name
# [2025-05-04 00:24:36,668]{model.py:297} - INFO - Encoding feature language
# [2025-05-04 00:24:36,682]{model.py:712} - INFO - Starting training process
# Train epoch #0:   0%|          | 0/1441 [00:00<?, ?it/s]
# Exception ignored in: <function _MultiProcessingDataLoaderIter.__del__ at 0x7b02afb44900>
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.11/dist-packages/torch/utils/data/dataloader.py", line 1604, in __del__
#     self._shutdown_workers()
#   File "/usr/local/lib/python3.11/dist-packages/torch/utils/data/dataloader.py", line 1587, in _shutdown_workers
#     if w.is_alive():
#        ^^^^^^^^^^^^
#   File "/usr/lib/python3.11/multiprocessing/process.py", line 160, in is_alive
#     assert self._parent_pid == os.getpid(), 'can only test a child process'
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# AssertionError: can only test a child process
# Exception ignored in: <function _MultiProcessingDataLoaderIter.__del__ at 0x7b02afb44900>
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.11/dist-packages/torch/utils/data/dataloader.py", line 1604, in __del__
#     self._shutdown_workers()
#   File "/usr/local/lib/python3.11/dist-packages/torch/utils/data/dataloader.py", line 1587, in _shutdown_workers
#     if w.is_alive():
#        ^^^^^^^^^^^^
#   File "/usr/lib/python3.11/multiprocessing/process.py", line 160, in is_alive
#     assert self._parent_pid == os.getpid(), 'can only test a child process'
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# AssertionError: can only test a child process
# Exception ignored in: <function _MultiProcessingDataLoaderIter.__del__ at 0x7b02afb44900>
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.11/dist-packages/torch/utils/data/dataloader.py", line 1604, in __del__
#     self._shutdown_workers()
#   File "/usr/local/lib/python3.11/dist-packages/torch/utils/data/dataloader.py", line 1587, in _shutdown_workers
#     if w.is_alive():
#        ^^^^^^^^^^^^
#   File "/usr/lib/python3.11/multiprocessing/process.py", line 160, in is_alive
#     assert self._parent_pid == os.getpid(), 'can only test a child process'
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# AssertionError: can only test a child process
# Exception ignored in: <function _MultiProcessingDataLoaderIter.__del__ at 0x7b02afb44900>
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.11/dist-packages/torch/utils/data/dataloader.py", line 1604, in __del__
#     self._shutdown_workers()
#   File "/usr/local/lib/python3.11/dist-packages/torch/utils/data/dataloader.py", line 1587, in _shutdown_workers
#     if w.is_alive():
#        ^^^^^^^^^^^^
#   File "/usr/lib/python3.11/multiprocessing/process.py", line 160, in is_alive
#     assert self._parent_pid == os.getpid(), 'can only test a child process'
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# AssertionError: can only test a child process
# Exception ignored in: <function _MultiProcessingDataLoaderIter.__del__ at 0x7b02afb44900>
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.11/dist-packages/torch/utils/data/dataloader.py", line 1604, in __del__
#     self._shutdown_workers()
#   File "/usr/local/lib/python3.11/dist-packages/torch/utils/data/dataloader.py", line 1587, in _shutdown_workers
#     if w.is_alive():
#        ^^^^^^^^^^^^
#   File "/usr/lib/python3.11/multiprocessing/process.py", line 160, in is_alive
#     assert self._parent_pid == os.getpid(), 'can only test a child process'
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# AssertionError: can only test a child process
# Exception ignored in: <function _MultiProcessingDataLoaderIter.__del__ at 0x7b02afb44900>
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.11/dist-packages/torch/utils/data/dataloader.py", line 1604, in __del__
#     self._shutdown_workers()
#   File "/usr/local/lib/python3.11/dist-packages/torch/utils/data/dataloader.py", line 1587, in _shutdown_workers
#     if w.is_alive():
#        ^^^^^^^^^^^^
#   File "/usr/lib/python3.11/multiprocessing/process.py", line 160, in is_alive
#     assert self._parent_pid == os.getpid(), 'can only test a child process'
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# AssertionError: can only test a child process
# Exception ignored in: <function _MultiProcessingDataLoaderIter.__del__ at 0x7b02afb44900>
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.11/dist-packages/torch/utils/data/dataloader.py", line 1604, in __del__
#     self._shutdown_workers()
#   File "/usr/local/lib/python3.11/dist-packages/torch/utils/data/dataloader.py", line 1587, in _shutdown_workers
#     if w.is_alive():
#        ^^^^^^^^^^^^
#   File "/usr/lib/python3.11/multiprocessing/process.py", line 160, in is_alive
#     assert self._parent_pid == os.getpid(), 'can only test a child process'
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# AssertionError: can only test a child process
# Exception ignored in: <function _MultiProcessingDataLoaderIter.__del__ at 0x7b02afb44900>
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.11/dist-packages/torch/utils/data/dataloader.py", line 1604, in __del__
#     self._shutdown_workers()
#   File "/usr/local/lib/python3.11/dist-packages/torch/utils/data/dataloader.py", line 1587, in _shutdown_workers
#     if w.is_alive():
#        ^^^^^^^^^^^^
#   File "/usr/lib/python3.11/multiprocessing/process.py", line 160, in is_alive
#     assert self._parent_pid == os.getpid(), 'can only test a child process'
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# AssertionError: can only test a child process
# Exception ignored in: <function _MultiProcessingDataLoaderIter.__del__ at 0x7b02afb44900>
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.11/dist-packages/torch/utils/data/dataloader.py", line 1604, in __del__
#     self._shutdown_workers()
#   File "/usr/local/lib/python3.11/dist-packages/torch/utils/data/dataloader.py", line 1587, in _shutdown_workers
#     if w.is_alive():
#        ^^^^^^^^^^^^
#   File "/usr/lib/python3.11/multiprocessing/process.py", line 160, in is_alive
#     assert self._parent_pid == os.getpid(), 'can only test a child process'
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# AssertionError: can only test a child process
# Exception ignored in: <function _MultiProcessingDataLoaderIter.__del__ at 0x7b02afb44900>
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.11/dist-packages/torch/utils/data/dataloader.py", line 1604, in __del__
#     self._shutdown_workers()
#   File "/usr/local/lib/python3.11/dist-packages/torch/utils/data/dataloader.py", line 1587, in _shutdown_workers
#     if w.is_alive():
#        ^^^^^^^^^^^^
#   File "/usr/lib/python3.11/multiprocessing/process.py", line 160, in is_alive
#     assert self._parent_pid == os.getpid(), 'can only test a child process'
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# AssertionError: can only test a child process
# [2025-05-04 00:40:01,949]{model.py:567} - INFO - Finished Train Epoch #0, average metrics - [loss: 0.59594]
# Traceback (most recent call last):
#   File "/usr/lib/python3.11/multiprocessing/queues.py", line 239, in _feed
#     reader_close()
#   File "/usr/lib/python3.11/multiprocessing/connection.py", line 178, in close
#     self._close()
#   File "/usr/lib/python3.11/multiprocessing/connection.py", line 377, in _close
#     _close(self._handle)
# OSError: [Errno 9] Bad file descriptor
# Validation epoch #0:   0%|          | 0/181 [00:00<?, ?it/s]
# [2025-05-04 00:40:30,554]{model.py:567} - INFO - Finished Validation Epoch #0, average metrics - [AUC: 0.77446, log_loss: 0.55855]
# [2025-05-04 00:40:41,447]{model.py:747} - INFO - Best model with AUC = 0.7744638398748251 was saved to dcnv2_artifacts/best_model.pt
# Train epoch #1:   0%|          | 0/1441 [00:00<?, ?it/s]
# Exception ignored in: <function _MultiProcessingDataLoaderIter.__del__ at 0x7b02afb44900>
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.11/dist-packages/torch/utils/data/dataloader.py", line 1604, in __del__
#     self._shutdown_workers()
#   File "/usr/local/lib/python3.11/dist-packages/torch/utils/data/dataloader.py", line 1587, in _shutdown_workers
#     if w.is_alive():
#        ^^^^^^^^^^^^
#   File "/usr/lib/python3.11/multiprocessing/process.py", line 160, in is_alive
#     assert self._parent_pid == os.getpid(), 'can only test a child process'
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# AssertionError: can only test a child process
# Exception ignored in: <function _MultiProcessingDataLoaderIter.__del__ at 0x7b02afb44900>
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.11/dist-packages/torch/utils/data/dataloader.py", line 1604, in __del__
#     self._shutdown_workers()
#   File "/usr/local/lib/python3.11/dist-packages/torch/utils/data/dataloader.py", line 1587, in _shutdown_workers
#     if w.is_alive():
#        ^^^^^^^^^^^^
#   File "/usr/lib/python3.11/multiprocessing/process.py", line 160, in is_alive
#     assert self._parent_pid == os.getpid(), 'can only test a child process'
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# AssertionError: can only test a child process
# [2025-05-04 00:56:10,513]{model.py:567} - INFO - Finished Train Epoch #1, average metrics - [loss: 0.55145]
# Validation epoch #1:   0%|          | 0/181 [00:00<?, ?it/s]
# [2025-05-04 00:56:39,704]{model.py:567} - INFO - Finished Validation Epoch #1, average metrics - [AUC: 0.78357, log_loss: 0.55085]
# [2025-05-04 00:56:50,605]{model.py:747} - INFO - Best model with AUC = 0.7835682800415887 was saved to dcnv2_artifacts/best_model.pt
# Train epoch #2:   0%|          | 0/1441 [00:00<?, ?it/s]
# Exception ignored in: <function _MultiProcessingDataLoaderIter.__del__ at 0x7b02afb44900>
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.11/dist-packages/torch/utils/data/dataloader.py", line 1604, in __del__
#     self._shutdown_workers()
#   File "/usr/local/lib/python3.11/dist-packages/torch/utils/data/dataloader.py", line 1587, in _shutdown_workers
#     if w.is_alive():
#        ^^^^^^^^^^^^
#   File "/usr/lib/python3.11/multiprocessing/process.py", line 160, in is_alive
#     assert self._parent_pid == os.getpid(), 'can only test a child process'
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# AssertionError: can only test a child process
# Exception ignored in: <function _MultiProcessingDataLoaderIter.__del__ at 0x7b02afb44900>
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.11/dist-packages/torch/utils/data/dataloader.py", line 1604, in __del__
#     self._shutdown_workers()
#   File "/usr/local/lib/python3.11/dist-packages/torch/utils/data/dataloader.py", line 1587, in _shutdown_workers
#     if w.is_alive():
#        ^^^^^^^^^^^^
#   File "/usr/lib/python3.11/multiprocessing/process.py", line 160, in is_alive
#     assert self._parent_pid == os.getpid(), 'can only test a child process'
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# AssertionError: can only test a child process
# [2025-05-04 01:12:17,808]{model.py:567} - INFO - Finished Train Epoch #2, average metrics - [loss: 0.53594]
# Validation epoch #2:   0%|          | 0/181 [00:00<?, ?it/s]
# [2025-05-04 01:12:47,071]{model.py:567} - INFO - Finished Validation Epoch #2, average metrics - [AUC: 0.78628, log_loss: 0.54646]
# [2025-05-04 01:12:57,989]{model.py:747} - INFO - Best model with AUC = 0.786282640119618 was saved to dcnv2_artifacts/best_model.pt
# [2025-05-04 01:12:57,990]{model.py:763} - INFO - Loading best model from dcnv2_artifacts/best_model.pt

# %%
test_metrics_dcnv2 = dcnv2_model.test(
    features=df_test.drop(columns="label"),
    target=df_test["label"],
    device="cuda:0",
    batch_size=4096,
    num_workers=2,
)
test_metrics_dcnv2
# Out:
# [2025-05-04 01:12:58,129]{model.py:789} - INFO - Building test dataloader
# [2025-05-04 01:12:58,157]{model.py:297} - INFO - Encoding feature msno
# [2025-05-04 01:12:58,228]{model.py:297} - INFO - Encoding feature song_id
# [2025-05-04 01:12:58,475]{model.py:297} - INFO - Encoding feature source_system_tab
# [2025-05-04 01:12:58,486]{model.py:297} - INFO - Encoding feature source_screen_name
# [2025-05-04 01:12:58,510]{model.py:297} - INFO - Encoding feature source_type
# [2025-05-04 01:12:58,520]{model.py:297} - INFO - Encoding feature city
# [2025-05-04 01:12:58,544]{model.py:297} - INFO - Encoding feature bd
# [2025-05-04 01:12:58,554]{model.py:297} - INFO - Encoding feature gender
# [2025-05-04 01:12:58,571]{model.py:297} - INFO - Encoding feature registered_via
# [2025-05-04 01:12:58,588]{model.py:297} - INFO - Encoding feature genre_ids
# [2025-05-04 01:12:58,611]{model.py:297} - INFO - Encoding feature artist_name
# [2025-05-04 01:12:58,713]{model.py:297} - INFO - Encoding feature language
# Test epoch #-1:   0%|          | 0/181 [00:00<?, ?it/s]
# [2025-05-04 01:13:26,249]{model.py:567} - INFO - Finished Test Epoch #-1, average metrics - [AUC: 0.78646, log_loss: 0.54609]
# {'AUC': 0.7864580833023873, 'log_loss': 0.5460870245117619}

# %% [markdown]
# # FinalNet

# %%
finalnet_model = FinalNet(
    block_type="2B",
    use_field_gate=True,
    use_batch_norm=True,
    add_bias=True,
    block1_hidden_dims=[256, 512, 1024],
    block1_hidden_activations=nn.ReLU,
    block1_dropout_rates=0.2,
    block2_hidden_dims=[256, 512, 1024],
    block2_hidden_activations=nn.ReLU,
    block2_dropout_rates=0.2,
    residual_type="concat",
    proj_output_embeddings=True,
)

# %%
train_metrics_final, val_metrics_final = finalnet_model.fit(
    features=df_train.drop(columns="label"),
    target=df_train["label"],
    val_features=df_val.drop(columns="label"),
    val_target=df_val["label"],
    optimizer_cls="torch.optim.Adam",
    optimizer_params=dict(lr=1e-2),
    scheduler_cls="torch.optim.lr_scheduler.ReduceLROnPlateau",
    scheduler_params=dict(mode="max", factor=0.1, patience=1, min_lr=1e-6),
    grad_clip_threshold=10.,
    num_epochs=3,
    seed=42,
    artifacts_path="./finalnet_artifacts",
    device="cuda:0",
    batch_size=4096,
    num_workers=4,
    eval_metric_name="AUC",
    eval_mode="max",
    oov_masking_proba=0.05,
    embedded_features=num_features,
    default_embedding_size=20, # should be equal for all features if using field gate
    l2_net_reg=0.,
    l2_embedding_reg=0,
)
# Out:
# [2025-05-04 01:15:20,476]{model.py:660} - INFO - Used features config: FeaturesConfig(features=[Feature(name='msno', feature_type=<FeatureType.CATEGORICAL: 'categorical'>, feature_size=1, needs_embed=True, embedding_size=20, embedding_vocab_size=30534, embedding_padding_idx=None), Feature(name='song_id', feature_type=<FeatureType.CATEGORICAL: 'categorical'>, feature_size=1, needs_embed=True, embedding_size=20, embedding_vocab_size=324210, embedding_padding_idx=None), Feature(name='source_system_tab', feature_type=<FeatureType.CATEGORICAL: 'categorical'>, feature_size=1, needs_embed=True, embedding_size=20, embedding_vocab_size=10, embedding_padding_idx=None), Feature(name='source_screen_name', feature_type=<FeatureType.CATEGORICAL: 'categorical'>, feature_size=1, needs_embed=True, embedding_size=20, embedding_vocab_size=22, embedding_padding_idx=None), Feature(name='source_type', feature_type=<FeatureType.CATEGORICAL: 'categorical'>, feature_size=1, needs_embed=True, embedding_size=20, embedding_vocab_size=14, embedding_padding_idx=None), Feature(name='city', feature_type=<FeatureType.CATEGORICAL: 'categorical'>, feature_size=1, needs_embed=True, embedding_size=20, embedding_vocab_size=22, embedding_padding_idx=None), Feature(name='bd', feature_type=<FeatureType.CATEGORICAL: 'categorical'>, feature_size=1, needs_embed=True, embedding_size=20, embedding_vocab_size=93, embedding_padding_idx=None), Feature(name='gender', feature_type=<FeatureType.CATEGORICAL: 'categorical'>, feature_size=1, needs_embed=True, embedding_size=20, embedding_vocab_size=4, embedding_padding_idx=None), Feature(name='registered_via', feature_type=<FeatureType.CATEGORICAL: 'categorical'>, feature_size=1, needs_embed=True, embedding_size=20, embedding_vocab_size=6, embedding_padding_idx=None), Feature(name='song_length', feature_type=<FeatureType.NUMERICAL: 'numerical'>, feature_size=1, needs_embed=True, embedding_size=20, embedding_vocab_size=None, embedding_padding_idx=None), Feature(name='genre_ids', feature_type=<FeatureType.CATEGORICAL: 'categorical'>, feature_size=1, needs_embed=True, embedding_size=20, embedding_vocab_size=562, embedding_padding_idx=None), Feature(name='artist_name', feature_type=<FeatureType.CATEGORICAL: 'categorical'>, feature_size=1, needs_embed=True, embedding_size=20, embedding_vocab_size=37649, embedding_padding_idx=None), Feature(name='language', feature_type=<FeatureType.CATEGORICAL: 'categorical'>, feature_size=1, needs_embed=True, embedding_size=20, embedding_vocab_size=12, embedding_padding_idx=None)])
# [2025-05-04 01:15:20,479]{model.py:675} - INFO - Artifacts path is /kaggle/working/finalnet_artifacts
# [2025-05-04 01:15:20,479]{model.py:681} - INFO - Best model path is finalnet_artifacts/best_model.pt
# [2025-05-04 01:15:20,493]{model.py:686} - INFO - Building features mappings
# [2025-05-04 01:15:20,493]{model.py:272} - INFO - Building mapping for feature msno
# [2025-05-04 01:15:20,531]{model.py:272} - INFO - Building mapping for feature song_id
# [2025-05-04 01:15:20,635]{model.py:272} - INFO - Building mapping for feature source_system_tab
# [2025-05-04 01:15:20,661]{model.py:272} - INFO - Building mapping for feature source_screen_name
# [2025-05-04 01:15:20,687]{model.py:272} - INFO - Building mapping for feature source_type
# [2025-05-04 01:15:20,710]{model.py:272} - INFO - Building mapping for feature city
# [2025-05-04 01:15:20,735]{model.py:272} - INFO - Building mapping for feature bd
# [2025-05-04 01:15:20,759]{model.py:272} - INFO - Building mapping for feature gender
# [2025-05-04 01:15:20,783]{model.py:272} - INFO - Building mapping for feature registered_via
# [2025-05-04 01:15:20,807]{model.py:272} - INFO - Building mapping for feature genre_ids
# [2025-05-04 01:15:20,840]{model.py:272} - INFO - Building mapping for feature artist_name
# [2025-05-04 01:15:20,920]{model.py:272} - INFO - Building mapping for feature language
# [2025-05-04 01:15:20,944]{model.py:689} - INFO - Building train dataloader
# [2025-05-04 01:15:21,013]{model.py:297} - INFO - Encoding feature msno
# [2025-05-04 01:15:21,174]{model.py:297} - INFO - Encoding feature song_id
# [2025-05-04 01:15:21,506]{model.py:297} - INFO - Encoding feature source_system_tab
# [2025-05-04 01:15:21,636]{model.py:297} - INFO - Encoding feature source_screen_name
# [2025-05-04 01:15:21,765]{model.py:297} - INFO - Encoding feature source_type
# [2025-05-04 01:15:21,888]{model.py:297} - INFO - Encoding feature city
# [2025-05-04 01:15:22,000]{model.py:297} - INFO - Encoding feature bd
# [2025-05-04 01:15:22,116]{model.py:297} - INFO - Encoding feature gender
# [2025-05-04 01:15:22,228]{model.py:297} - INFO - Encoding feature registered_via
# [2025-05-04 01:15:22,343]{model.py:297} - INFO - Encoding feature genre_ids
# [2025-05-04 01:15:22,460]{model.py:297} - INFO - Encoding feature artist_name
# [2025-05-04 01:15:22,591]{model.py:297} - INFO - Encoding feature language
# [2025-05-04 01:15:22,708]{model.py:702} - INFO - Building validation dataloader
# [2025-05-04 01:15:22,713]{model.py:297} - INFO - Encoding feature msno
# [2025-05-04 01:15:22,742]{model.py:297} - INFO - Encoding feature song_id
# [2025-05-04 01:15:22,918]{model.py:297} - INFO - Encoding feature source_system_tab
# [2025-05-04 01:15:22,928]{model.py:297} - INFO - Encoding feature source_screen_name
# [2025-05-04 01:15:22,938]{model.py:297} - INFO - Encoding feature source_type
# [2025-05-04 01:15:22,948]{model.py:297} - INFO - Encoding feature city
# [2025-05-04 01:15:22,960]{model.py:297} - INFO - Encoding feature bd
# [2025-05-04 01:15:22,972]{model.py:297} - INFO - Encoding feature gender
# [2025-05-04 01:15:22,983]{model.py:297} - INFO - Encoding feature registered_via
# [2025-05-04 01:15:22,995]{model.py:297} - INFO - Encoding feature genre_ids
# [2025-05-04 01:15:23,010]{model.py:297} - INFO - Encoding feature artist_name
# [2025-05-04 01:15:23,055]{model.py:297} - INFO - Encoding feature language
# [2025-05-04 01:15:23,068]{model.py:712} - INFO - Starting training process
# Train epoch #0:   0%|          | 0/1441 [00:00<?, ?it/s]
# [2025-05-04 01:26:38,658]{model.py:567} - INFO - Finished Train Epoch #0, average metrics - [loss: 0.58906]
# Validation epoch #0:   0%|          | 0/181 [00:00<?, ?it/s]
# [2025-05-04 01:27:05,240]{model.py:567} - INFO - Finished Validation Epoch #0, average metrics - [AUC: 0.77933, log_loss: 0.55412]
# [2025-05-04 01:27:26,183]{model.py:747} - INFO - Best model with AUC = 0.7793291453155989 was saved to finalnet_artifacts/best_model.pt
# Train epoch #1:   0%|          | 0/1441 [00:01<?, ?it/s]
# [2025-05-04 01:38:29,387]{model.py:567} - INFO - Finished Train Epoch #1, average metrics - [loss: 0.54628]
# Validation epoch #1:   0%|          | 0/181 [00:00<?, ?it/s]
# [2025-05-04 01:39:15,072]{model.py:567} - INFO - Finished Validation Epoch #1, average metrics - [AUC: 0.79569, log_loss: 0.53652]
# [2025-05-04 01:39:36,021]{model.py:747} - INFO - Best model with AUC = 0.7956929521233412 was saved to finalnet_artifacts/best_model.pt
# Train epoch #2:   0%|          | 0/1441 [00:01<?, ?it/s]
# [2025-05-04 01:50:39,839]{model.py:567} - INFO - Finished Train Epoch #2, average metrics - [loss: 0.51929]
# Validation epoch #2:   0%|          | 0/181 [00:00<?, ?it/s]
# [2025-05-04 01:51:25,788]{model.py:567} - INFO - Finished Validation Epoch #2, average metrics - [AUC: 0.80288, log_loss: 0.53150]
# [2025-05-04 01:51:46,796]{model.py:747} - INFO - Best model with AUC = 0.8028754642694195 was saved to finalnet_artifacts/best_model.pt
# [2025-05-04 01:51:46,797]{model.py:763} - INFO - Loading best model from finalnet_artifacts/best_model.pt

# %%
test_metrics_final = finalnet_model.test(
    features=df_test.drop(columns="label"),
    target=df_test["label"],
    device="cuda:0",
    batch_size=4096,
    num_workers=2,
)
test_metrics_final
# Out:
# [2025-05-04 01:51:46,909]{model.py:789} - INFO - Building test dataloader
# [2025-05-04 01:51:46,933]{model.py:297} - INFO - Encoding feature msno
# [2025-05-04 01:51:46,990]{model.py:297} - INFO - Encoding feature song_id
# [2025-05-04 01:51:47,230]{model.py:297} - INFO - Encoding feature source_system_tab
# [2025-05-04 01:51:47,241]{model.py:297} - INFO - Encoding feature source_screen_name
# [2025-05-04 01:51:47,265]{model.py:297} - INFO - Encoding feature source_type
# [2025-05-04 01:51:47,275]{model.py:297} - INFO - Encoding feature city
# [2025-05-04 01:51:47,301]{model.py:297} - INFO - Encoding feature bd
# [2025-05-04 01:51:47,312]{model.py:297} - INFO - Encoding feature gender
# [2025-05-04 01:51:47,338]{model.py:297} - INFO - Encoding feature registered_via
# [2025-05-04 01:51:47,347]{model.py:297} - INFO - Encoding feature genre_ids
# [2025-05-04 01:51:47,377]{model.py:297} - INFO - Encoding feature artist_name
# [2025-05-04 01:51:47,465]{model.py:297} - INFO - Encoding feature language
# Test epoch #-1:   0%|          | 0/181 [00:00<?, ?it/s]
# [2025-05-04 01:52:14,811]{model.py:567} - INFO - Finished Test Epoch #-1, average metrics - [AUC: 0.80282, log_loss: 0.53141]
# {'AUC': 0.8028208149455214, 'log_loss': 0.5314084704530784}
